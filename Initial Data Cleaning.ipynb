# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =  pd.read_csv('/Users/yasmeenmahomedy2/Downloads/Conflict Datasets/csv1.csv')

# %%
data2 =  pd.read_csv('/Users/yasmeenmahomedy2/Downloads/Conflict Datasets/csv2.csv')

# %%
data[data['Year']>1980].isnull().sum() * 100 / len(data[data['Year']>1980])
# Out:
# Country                                                     0.000000
# Code                                                        0.000000
# ContinentCode                                              11.029190
# Year                                                        0.000000
# Military spending percent of total government spending     37.812218
# Arms imports million constant U.S. dollars                 36.021667
# Cost of living index world average = 100                   97.472164
# Food price index world average = 100                       97.487210
# Housing and utilities price index world average  = 100     97.487210
# Healthcare price index world average = 100                 97.487210
# Happiness Index 0 (unhappy) - 10 (happy)                   81.959073
# Human Development Index (0 - 1)                            20.448390
# dtype: float64

# %%
potential_drop_1 = ['Cost of living index world average = 100', 
                    'Food price index world average = 100',
                    'Food price index world average = 100',
                    'Housing and utilities price index world average  = 100',
                    'Healthcare price index world average = 100',
                    ]

# %%
data2[data2['Year']>1980].isnull().sum() * 100 / len(data2[data2['Year']>1980])
# Out:
# Country                                                      0.000000
# Code                                                         0.000000
# ContinentCode                                               13.004428
# Year                                                         0.000000
# Economic growth: the rate of change of real GDP              8.576850
# GDP per capita current U.S. dollars                          6.755218
# GDP per capita Purchasing Power Parity                      27.387729
# Capital investment as percent of GDP                        21.062619
# Inflation: percent change in the Consumer Price Index       19.380139
# Unemployment rate                                           29.019608
# Youth unemployment ages 15-24                               29.019608
# Labor force participation rate                              26.729918
# Trade openness: exports plus imports as percent of GDP      19.696395
# ...

# %%
data2[(data2['Year'] == 2021)& (data2['Country']=='Iran') ].head()
# Out:
#      Country Code ContinentCode  Year  \
# 4663    Iran  IRN            AS  2021
#
#       Economic growth: the rate of change of real GDP  \
# 4663                                              NaN
#
#       GDP per capita current U.S. dollars  \
# 4663                                  NaN
#
#       GDP per capita Purchasing Power Parity  \
# 4663                                     NaN
#
#       Capital investment as percent of GDP  \
# 4663                                   NaN
#
#       Inflation: percent change in the Consumer Price Index  \
# 4663                                                NaN
#
#       Unemployment rate  Youth unemployment ages 15-24  \
# 4663              11.46                          27.21
#
#       Labor force participation rate  \
# 4663                           41.32
#
#       Trade openness: exports plus imports as percent of GDP  \
# 4663                                                NaN
#
#       Foreign Direct Investment percent of GDP  \
# ...

# %%
um = data2[(data2['Year'] > 1995)& (data2['Country']=='Sudan') ]

# %%
sns.lineplot(data=um, x='Year', y='Unemployment rate')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Unemployment rate'>

# %%
sns.heatmap(data2.corr())
# Out:
# <AxesSubplot:>

# %%
#data['combined'] = str(data['Year']) +str(data['Country'])

# %%
combined = pd.read_csv('/Users/yasmeenmahomedy2/Downloads/Conflict Datasets/csv_combined.csv')

# %%
combined[combined['Country_x']=="Iran"].head(2)
# Out:
#       Unnamed: 0 Country_x Code_x ContinentCode_x  Year_x  \
# 3615        3615      Iran    IRN              AS  1960.0
# 3616        3616      Iran    IRN              AS  1961.0
#
#       Military spending percent of total government spending   \
# 3615                                                NaN
# 3616                                                NaN
#
#       Arms imports million constant U.S. dollars  \
# 3615                                        11.0
# 3616                                       107.0
#
#       Cost of living index world average = 100  \
# 3615                                       NaN
# 3616                                       NaN
#
#       Food price index world average = 100  \
# 3615                                   NaN
# 3616                                   NaN
#
#       Housing and utilities price index world average  = 100  ...  \
# 3615                                                NaN       ...
# ...

# %%
combined[combined['Country_x']=='Tunisia'].head(2)
# Out:
#       Unnamed: 0 Country_x Code_x ContinentCode_x  Year_x  \
# 8003        8003   Tunisia    TUN              AF  1960.0
# 8004        8004   Tunisia    TUN              AF  1961.0
#
#       Military spending percent of total government spending   \
# 8003                                                NaN
# 8004                                                NaN
#
#       Arms imports million constant U.S. dollars  \
# 8003                                        44.0
# 8004                                         6.0
#
#       Cost of living index world average = 100  \
# 8003                                       NaN
# 8004                                       NaN
#
#       Food price index world average = 100  \
# 8003                                   NaN
# 8004                                   NaN
#
#       Housing and utilities price index world average  = 100  ...  \
# 8003                                                NaN       ...
# ...

# %%
columns_to_keep = (pd.DataFrame(combined.isnull().sum().sort_values(ascending=False) * 100 / len(combined)) < 30)[0] * 1

# %%
to_drop = list(columns_to_keep[columns_to_keep == 0].index)

# %%
cleaned_1 = combined.drop(to_drop, axis=1)
cleaned_1
# Out:
#        Unnamed: 0      CountryYear    Country_y Code_y ContinentCode_y  \
# 0               0  Afghanistan1960  Afghanistan    AFG              AS
# 1               1  Afghanistan1961  Afghanistan    AFG              AS
# 2               2  Afghanistan1962  Afghanistan    AFG              AS
# 3               3  Afghanistan1963  Afghanistan    AFG              AS
# 4               4  Afghanistan1964  Afghanistan    AFG              AS
# ...           ...              ...          ...    ...             ...
# 12559       12559       Taiwan1968          NaN    NaN             NaN
# 12560       12560       Taiwan1969          NaN    NaN             NaN
# 12561       12561       Taiwan1970          NaN    NaN             NaN
# 12562       12562       Taiwan1971          NaN    NaN             NaN
# 12563       12563        Yemen2022          NaN    NaN             NaN
#
#        Year_y  Economic growth: the rate of change of real GDP  \
# ...

# %%
cleaned_1.to_csv(initial_clean, index=True) #this is the full df, not 5 year one
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 cleaned_1.to_csv(initial_clean, index=True)
#
# NameError: name 'initial_clean' is not defined

# %%
len(cleaned_1)
# Out:
# 12564

# %%
five_year = pd.read_csv('/Users/yasmeenmahomedy2/Downloads/Conflict Datasets/conflicts_5y_data.csv')

# %%
five_year.head()
# Out:
#    Unnamed: 0           Country_x Code_x ContinentCode_x  Year_x  \
# 0        2212  Dominican Republic    DOM             NaN  1960.0
# 1        2213  Dominican Republic    DOM             NaN  1961.0
# 2        2214  Dominican Republic    DOM             NaN  1962.0
# 3        2215  Dominican Republic    DOM             NaN  1963.0
# 4        2216  Dominican Republic    DOM             NaN  1964.0
#
#    Military spending percent of total government spending   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Arms imports million constant U.S. dollars  \
# 0                                        19.0
# 1                                        11.0
# 2                                         0.0
# 3                                         7.0
# ...

# %%
columns_to_keep_2 = (pd.DataFrame(five_year.isnull().sum().sort_values(ascending=False) * 100 / len(five_year)) < 30)[0] * 1

# %%
columns_to_keep_2
# Out:
# People practicing Judaism as percent of the population    0
# Non religious people as percent of the population         0
# Housing and utilities price index world average  = 100    0
# Healthcare price index world average = 100                0
# Cost of living index world average = 100                  0
#                                                          ..
# Unnamed: 0                                                1
# Code_y.1                                                  1
# Country_y.1                                               1
# CountryYear                                               1
# Year_y.1                                                  1
# Name: 0, Length: 115, dtype: int64

# %%
to_drop_2 = list(columns_to_keep_2[columns_to_keep_2 == 0].index)

# %%
cleaned_2 = five_year.drop(to_drop_2, axis=1)

# %%
cleaned_2.head()
# Out:
#    Unnamed: 0           Country_x Code_x ContinentCode_x  Year_x  \
# 0        2212  Dominican Republic    DOM             NaN  1960.0
# 1        2213  Dominican Republic    DOM             NaN  1961.0
# 2        2214  Dominican Republic    DOM             NaN  1962.0
# 3        2215  Dominican Republic    DOM             NaN  1963.0
# 4        2216  Dominican Republic    DOM             NaN  1964.0
#
#    Arms imports million constant U.S. dollars             CountryYear  \
# 0                                        19.0  Dominican Republic1960
# 1                                        11.0  Dominican Republic1961
# 2                                         0.0  Dominican Republic1962
# 3                                         7.0  Dominican Republic1963
# 4                                         5.0  Dominican Republic1964
#
#             Country_y Code_y ContinentCode_y  ...  Year_x.2  \
# 0  Dominican Republic    DOM             NaN  ...    1960.0
# ...

# %%
cleaned_2.to_csv('five_year_clean.csv', index = None, header=True)

# %%
cleaned_3 = cleaned_2.drop(columns=['Country_y', 'ContinentCode_y', 'Code_y', 'Year_x.2', 'Country_y.2', 'ContinentCode_y.2', 'Year_y.2', 'Code_y.2' , 'Year_y', 'ContinentCode_x.2', 'Code_x.2','Country_x.2' ])

# %%
cleaned_3.head()
# Out:
#    Unnamed: 0           Country_x Code_x ContinentCode_x  Year_x  \
# 0        2212  Dominican Republic    DOM             NaN  1960.0
# 1        2213  Dominican Republic    DOM             NaN  1961.0
# 2        2214  Dominican Republic    DOM             NaN  1962.0
# 3        2215  Dominican Republic    DOM             NaN  1963.0
# 4        2216  Dominican Republic    DOM             NaN  1964.0
#
#    Arms imports million constant U.S. dollars             CountryYear  \
# 0                                        19.0  Dominican Republic1960
# 1                                        11.0  Dominican Republic1961
# 2                                         0.0  Dominican Republic1962
# 3                                         7.0  Dominican Republic1963
# 4                                         5.0  Dominican Republic1964
#
#    Economic growth: the rate of change of real GDP  \
# 0                                              NaN
# ...

# %%
rename = {'Country_x': 'Country', 'Code_x': 'Code', 'Year_x':'Year', 'ContinentCode_x':'Continent Code'}
cleaned_3.rename(columns=rename, inplace=True)

# %%
cleaned_3.head()
# Out:
#    Unnamed: 0             Country Code Continent Code    Year  \
# 0        2212  Dominican Republic  DOM            NaN  1960.0
# 1        2213  Dominican Republic  DOM            NaN  1961.0
# 2        2214  Dominican Republic  DOM            NaN  1962.0
# 3        2215  Dominican Republic  DOM            NaN  1963.0
# 4        2216  Dominican Republic  DOM            NaN  1964.0
#
#    Arms imports million constant U.S. dollars             CountryYear  \
# 0                                        19.0  Dominican Republic1960
# 1                                        11.0  Dominican Republic1961
# 2                                         0.0  Dominican Republic1962
# 3                                         7.0  Dominican Republic1963
# 4                                         5.0  Dominican Republic1964
#
#    Economic growth: the rate of change of real GDP  \
# 0                                              NaN
# 1                                            -2.31
# ...

# %%
futher_drop = ['Continent Code', 'Code']

# %%
clean_4 =  cleaned_3.drop(columns=futher_drop)

# %%
clean_4.head()
# Out:
#    Unnamed: 0             Country    Year  \
# 0        2212  Dominican Republic  1960.0
# 1        2213  Dominican Republic  1961.0
# 2        2214  Dominican Republic  1962.0
# 3        2215  Dominican Republic  1963.0
# 4        2216  Dominican Republic  1964.0
#
#    Arms imports million constant U.S. dollars             CountryYear  \
# 0                                        19.0  Dominican Republic1960
# 1                                        11.0  Dominican Republic1961
# 2                                         0.0  Dominican Republic1962
# 3                                         7.0  Dominican Republic1963
# 4                                         5.0  Dominican Republic1964
#
#    Economic growth: the rate of change of real GDP  \
# 0                                              NaN
# 1                                            -2.31
# 2                                            17.05
# 3                                             6.50
# ...
