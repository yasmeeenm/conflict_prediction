# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# features_df = pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/csv_combined (1).csv')
# features_df

# %%
# nul_df = pd.DataFrame(features_df.isnull().sum().sort_values(ascending=False)/len(features_df))
# nul_df

# %%
# features_df.groupby(features_df['Country_x']).count()

# %%
conflicts_df = pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/civil_war_dataset - Civil War (1).csv')
conflicts_df
# Out:
#                            country  start_date               Type         War
# 0               Dominican Republic        1965  Internationalised       Civil
# 1    Zimbabwe (Rhodesian Bush War)        1964           Internal       Civil
# 2                         Thailand        1965  Internationalised       Civil
# 3                         Cambodia        1967  Internationalised       Civil
# 4                          Nigeria        1967           Internal       Civil
# ..                             ...         ...                ...         ...
# 118                      Venezuela        1989           Internal  Revolution
# 119                Burma (Myanmar)        1988           Internal  Revolution
# 120                    South Korea        1987           Internal  Revolution
# 121                        Somalia        1986           Internal  Revolution
# 122                    Philippines        1986           Internal  Revolution
#
# [123 rows x 4 columns]

# %%
conflicts_df.groupby(conflicts_df['country']).sum()
# Out:
#                                start_date
# country
# Afghanistan                          9970
# Afghanistan                          2021
# Albania                              1997
# Algeria                              1991
# Angolan                              1975
# ...                                   ...
# Turkey                               2016
# Uzbekistan                           2022
# Venezuela                            4003
# Yemen                                8006
# Zimbabwe (Rhodesian Bush War)        1964
#
# [78 rows x 1 columns]

# %%
# five_years = pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/five_year_clean.csv')
# five_years

# %%
# five_years.groupby('Country_x').sum()

# %%
clean_df = pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/clean.csv')
clean_df
# Out:
#      Unnamed: 0             Country Code    Year  \
# 0          2212  Dominican Republic  DOM  1960.0
# 1          2213  Dominican Republic  DOM  1961.0
# 2          2214  Dominican Republic  DOM  1962.0
# 3          2215  Dominican Republic  DOM  1963.0
# 4          2216  Dominican Republic  DOM  1964.0
# ..          ...                 ...  ...     ...
# 588        6269         Philippines  PHL  1981.0
# 589        6270         Philippines  PHL  1982.0
# 590        6271         Philippines  PHL  1983.0
# 591        6272         Philippines  PHL  1984.0
# 592        6273         Philippines  PHL  1985.0
#
#      Arms imports million constant U.S. dollars             CountryYear  \
# 0                                          19.0  Dominican Republic1960
# 1                                          11.0  Dominican Republic1961
# 2                                           0.0  Dominican Republic1962
# 3                                           7.0  Dominican Republic1963
# ...

# %%
# clean_df.groupby('Country').count()

# %%
# GDP = clean_df[clean_df['GDP per capita current U.S. dollars']].groupby('Year').mean()
# Country = clean_df[clean_df['poverty']].groupby('Year').mean()
# plt.plot(GDP)
# plt.plot(Country)
# plt.xlabel("GDP")
# plt.ylabel("Investment")

# %%
Country
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 Country
#
# NameError: name 'Country' is not defined

# %%
# clean_df.head(50)

# %%
frames = [conflicts_df, clean_df]
result = pd.concat(frames)
result

# %%
# result.groupby('country').count()

# %%
def select_country(string):
    country_data = clean_df[clean_df['Country']==string]
    country_name = f'country_{string}'
    country_name =  country_data
    return country_data

# %%
select_country('Lebanon')

# %%
# sns.catplot(x = select_country('Lebanon'), y ='GDP per capita current U.S. dollars', data = clean_df)

# %%
gdp_df = select_country('Dominican Republic')
gdp_df[['GDP per capita current U.S. dollars']].pct_change()

# %%
def pc_change(Country):
    pct_change = f' select_country('Country')'
    gdp_df[['GDP per capita current U.S. dollars']].pct_change()
    
# select_.groupby(['GDP per capita current U.S. dollars','Country']).mean()
# gdp_pct = gdp_df.pct_change(periods= -1)
# gdp_pct

# %%
full_df = pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/full_dataset.csv')
full_df
# Out:
#      Unnamed: 0  Military spending percent of total government spending   \
# 0             0                                           4.292091
# 1             1                                           6.030000
# 2             2                                           8.609929
# 3             3                                           5.760000
# 4             4                                          12.438000
# ..          ...                                                ...
# 216         106                                           5.447500
# 217         107                                           6.227500
# 218         108                                           9.122637
# 219         109                                          10.237500
# 220         110                                           4.477500
#
#      Arms imports million constant U.S. dollars  \
# 0                                    209.322106
# 1                                     69.500000
# ...

# %%
corr_df = full_df.corr().abs()

# %%
import numpy as np
upper_tri = corr_df.where(np.triu(np.ones(corr_df.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
new_df = corr_df.drop(columns=to_drop, axis= 1)

# %%
new_df

# %%
import numpy as np

shape = (64, 64)

data = np.random.normal(size=shape)

data[:,] += data[:,]

df = pd.DataFrame(corr_df)

c = df.corr().abs()

s = c.unstack()
so = s.sort_values(kind="quicksort")

so

# %%
corr_df.style.background_gradient(cmap = 'YlOrRd')

# %%
last_df = pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/conflict_data_1970 (1).csv')
last_df

# %%
pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/csvData.csv')

# %%
poverty_df = pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/pip_dataset.csv')
poverty_df
# Out:
#        country  year reporting_level welfare_type  ppp_version  survey_year  \
# 0      Albania  1996        national  consumption         2011       1996.0
# 1      Albania  2002        national  consumption         2011       2002.0
# 2      Albania  2005        national  consumption         2011       2005.0
# 3      Albania  2008        national  consumption         2011       2008.0
# 4      Albania  2012        national  consumption         2011       2012.0
# ...        ...   ...             ...          ...          ...          ...
# 4872    Zambia  2010        national  consumption         2017       2010.0
# 4873    Zambia  2015        national  consumption         2017       2015.0
# 4874  Zimbabwe  2011        national  consumption         2017       2011.0
# 4875  Zimbabwe  2017        national  consumption         2017       2017.0
# 4876  Zimbabwe  2019        national  consumption         2017       2019.0
#
# ...

# %%
poverty_df_clean = poverty_df[['country','year','headcount_ratio_international_povline','gini']]
pverty_df_clean = poverty_df_clean.sort_values('year')

# %%
gap

# %%
poverty_df_clean.to_csv('poverty_df.csv')

# %%
poverty_df_clean.head(50)
# poverty_df_clean.drop(poverty_df_clean['country'] = 'albania'.index , inplace = True)
poverty_df_clean = poverty_df_clean[poverty_df_clean.country != 'Albania']
poverty_df_clean.head(-50)
# Out:
#       country  year  headcount_ratio_international_povline      gini
# 14    Algeria  1988                               6.250913  0.401949
# 15    Algeria  1995                               5.624111  0.353301
# 16    Algeria  2011                               0.449365  0.276157
# 17     Angola  2000                              36.374478  0.519569
# 18     Angola  2008                              34.446857  0.427155
# ...       ...   ...                                    ...       ...
# 4822  Vietnam  1997                              24.389482  0.354422
# 4823  Vietnam  2002                              29.939254  0.370296
# 4824  Vietnam  2004                              20.142012  0.367858
# 4825  Vietnam  2006                              14.901668  0.357886
# 4826  Vietnam  2008                              11.139827  0.355703
#
# [4799 rows x 4 columns]

# %%
poverty_df_clean.groupby('country').head(50).count()
# Out:
# country                                  4355
# year                                     4355
# headcount_ratio_international_povline    4355
# gini                                     3945
# dtype: int64

# %%
# Out:
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
#         ...
# 4872    False
# 4873    False
# 4874    False
# 4875    False
# 4876    False
# Name: country, Length: 4849, dtype: bool

# %%
# pov_df = pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/full_dataset.csv')

# %%
# !pip install flaml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.6/208.6 kB 3.7 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
# from flaml import AutoML

# %%
pd.read_csv('/Users/mariazoghzoghi/code/yasmeeenm/conflict_data_1970 (1).csv')
# Out:
#      Unnamed: 0      Country  Year  Year -1  Year -2  Year -3  Year -4  \
# 0           NaN      Lebanon  1975     1974     1973     1972     1971
# 1           NaN   Mozambique  1975     1974     1973     1972     1971
# 2           NaN       Angola  1975     1974     1973     1972     1971
# 3           NaN    Indonesia  1976     1975     1974     1973     1972
# 4           NaN  Afghanistan  1978     1977     1976     1975     1974
# ..          ...          ...   ...      ...      ...      ...      ...
# 107         NaN      Ecuador  2022     2021     2020     2019     2018
# 108         NaN   Uzbekistan  2022     2021     2020     2019     2018
# 109         NaN    Sri Lanka  2022     2021     2020     2019     2018
# 110         NaN   Kazakhstan  2022     2021     2020     2019     2018
# 111         NaN      Country  Year  Year -1  Year -2  Year -3  Year -4
#
#      Year -5
# 0       1970
# 1       1970
# 2       1970
# 3       1971
# 4       1973
# ..       ...
# ...
