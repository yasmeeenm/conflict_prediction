# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import MinMaxScaler
import random

# %% [markdown]
# # Imports

# %%
shit_database = pd.read_csv('https://raw.githubusercontent.com/chekirou/International-conflict-prediction/master/data/actual.csv')

# %%
features_df = pd.read_csv('./raw_data/clean.csv')
old_features = pd.read_csv('./raw_data/csv_combined.csv')

# %%
conflict_old = pd.read_csv('./raw_data/civil_war_dataset - Civil War (4).csv')
conflict_new = pd.read_csv('./raw_data/conflicts_5y_data.csv')
conflict = pd.read_csv('./raw_data/full_dataset.csv')
conflict_1990 = pd.read_csv('./raw_data/civil_war_dataset - Combined, from 1970.csv')

# %% [markdown]
# # Cleaning

# %%
conflict_df = conflict_old.drop([0,1,2,3,4,39,40,5,41,6,7,9,10, 16, 119, 21,114, 29, 31,34, 109, 44, 108, 103, 98,69, 56, 60, 110])
conflict_df = conflict_df.drop([15, 18, 20, 117, 19, 23, 25])
conflict_df = conflict_df.sort_values('start_date')
conflict_df = conflict_df.reset_index()
conflict_df = conflict_df.drop(columns = 'index')

# %%
old_features = old_features.drop(columns = ['Unnamed: 0', 'Year_y', 'Code_y.1', 'ContinentCode_y.1', 'Year_y.1', 'Country_y.1', 'Country_x.1', 'Code_x.1', 'ContinentCode_x.1', 'Year_x.1','Code_x', 'ContinentCode_x', 'CountryYear', 'Country_y', 'Code_y', 'ContinentCode_y', 'Country_y.2', 'Code_y.2', 'ContinentCode_y.2', 'Year_y.2','Code_x.2', 'ContinentCode_x.2', 'Year_x.2', 'Country_x.2'])
old_features = old_features.rename(columns={'Country_x': 'Country', 'Year_x': 'Year'})
old_features
# Out:
#            Country    Year  \
# 0      Afghanistan  1960.0
# 1      Afghanistan  1961.0
# 2      Afghanistan  1962.0
# 3      Afghanistan  1963.0
# 4      Afghanistan  1964.0
# ...            ...     ...
# 12559          NaN     NaN
# 12560          NaN     NaN
# 12561          NaN     NaN
# 12562          NaN     NaN
# 12563          NaN     NaN
#
#        Military spending percent of total government spending   \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                NaN
#
#        Arms imports million constant U.S. dollars  \
# 0                                            40.0
# 1                                            56.0
# 2                                            64.0
# 3                                            40.0
# 4                                            56.0
# ...                                           ...
# 12559                                         NaN
# 12560                                         NaN
# 12561                                         NaN
# 12562                                         NaN
# 12563                                         NaN
#
#        Cost of living index world average = 100  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 12559                                       NaN
# 12560                                       NaN
# 12561                                       NaN
# 12562                                       NaN
# 12563                                       NaN
#
#        Food price index world average = 100  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 12559                                   NaN
# 12560                                   NaN
# 12561                                   NaN
# 12562                                   NaN
# 12563                                   NaN
#
#        Housing and utilities price index world average  = 100  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                NaN
#
#        Healthcare price index world average = 100  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 12559                                         NaN
# 12560                                         NaN
# 12561                                         NaN
# 12562                                         NaN
# 12563                                         NaN
#
#        Happiness Index 0 (unhappy) - 10 (happy)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 12559                                       NaN
# 12560                                       NaN
# 12561                                       NaN
# 12562                                       NaN
# 12563                                       NaN
#
#        Human Development Index (0 - 1)  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                  NaN  ...
# 3                                  NaN  ...
# 4                                  NaN  ...
# ...                                ...  ...
# 12559                              NaN  ...
# 12560                              NaN  ...
# 12561                              NaN  ...
# 12562                              NaN  ...
# 12563                              NaN  ...
#
#        Security threats index 0 (low) - 10 (high)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 12559                                         NaN
# 12560                                         NaN
# 12561                                         NaN
# 12562                                         NaN
# 12563                                         9.1
#
#        Factionalized elites index 0 (low) - 10 (high)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 12559                                             NaN
# 12560                                             NaN
# 12561                                             NaN
# 12562                                             NaN
# 12563                                            10.0
#
#        Group grievance index 0 (low) - 10 (high)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 12559                                        NaN
# 12560                                        NaN
# 12561                                        NaN
# 12562                                        NaN
# 12563                                        9.1
#
#        Economic decline index 0 (low) - 10 (high)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 12559                                         NaN
# 12560                                         NaN
# 12561                                         NaN
# 12562                                         NaN
# 12563                                         9.9
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                8.0
#
#        State legitimacy index 0 (high) - 10 (low)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 12559                                         NaN
# 12560                                         NaN
# 12561                                         NaN
# 12562                                         NaN
# 12563                                         9.9
#
#        Human rights and rule of law index 0 (high) - 10 (low)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                9.9
#
#        Demographic pressures 0 (low) - 10 (high)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 12559                                        NaN
# 12560                                        NaN
# 12561                                        NaN
# 12562                                        NaN
# 12563                                        9.9
#
#        Refugees and displaced persons index 0 (low) - 10 (high)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                9.9
#
#        External interventions index 0 (low) - 10 (high)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 12559                                               NaN
# 12560                                               NaN
# 12561                                               NaN
# 12562                                               NaN
# 12563                                               9.4
#
# [12564 rows x 91 columns]

# %%
conflict_df.head(30)
# Out:
#         country  start_date               Type         War
# 0       Lebanon        1975           Internal       Civil
# 1     Indonesia        1976           Internal       Civil
# 2   Afghanistan        1978           Internal       Civil
# 3       Somalia        1978           Internal       Civil
# 4   El Salvador        1979           Internal       Civil
# 5         Sudan        1983           Internal       Civil
# 6       Somalia        1986           Internal  Revolution
# 7   Philippines        1986           Internal  Revolution
# 8   South Korea        1987           Internal  Revolution
# 9     Venezuela        1989           Internal  Revolution
# 10  Afghanistan        1989  Internationalised       Civil
# 11   Bangladesh        1990           Internal  Revolution
# 12         Iraq        1991           Internal       Civil
# 13      Algeria        1991           Internal       Civil
# 14     Thailand        1992           Internal  Revolution
# 15         Peru        1992           Internal       Civil
# 16  Afghanistan        1992  Internationalised       Civil
# 17      Burundi        1993           Internal       Civil
# 18        Yemen        1994           Internal       Civil
# 19      Bahrain        1994           Internal  Revolution
# 20        Nepal        1996          Internal        Civil
# 21        Nepal        1996           Internal  Revolution
# 22  Afghanistan        1996           Internal       Civil
# 23      Albania        1997          Internal        Civil
# 24    Indonesia        1998           Internal  Revolution
# 25         Iran        1999           Internal  Revolution
# 26  Philippines        2001           Internal  Revolution
# 27  Ivory Coast        2002           Internal       Civil
# 28    Argentina        2002           Internal  Revolution
# 29        Sudan        2003           Internal  Revolution

# %%
features_df = features_df.drop(columns = ['Unnamed: 0', 'Code_y.1', 'ContinentCode_y.1', 'Year_y.1', 'Country_y.1', 'Country_x.1', 'Code_x.1', 'ContinentCode_x.1', 'Year_x.1','CountryYear', 'Code'])

# %%
features_df = features_df.drop_duplicates()

# %%
all_countries = old_features['Country'].unique()
all_countries_list = list(all_countries)
del all_countries_list[-1]
all_countries_list
random.choice(tuple(all_countries_list))
# Out:
# 'Lesotho'

# %%
conflict_df.tail(20)
# Out:
#          country  start_date      Type         War
# 67          Iraq        2019  Internal  Revolution
# 68         Chile        2019  Internal  Revolution
# 69          Iran        2019  Internal  Revolution
# 70       Belarus        2020  Internal  Revolution
# 71      Thailand        2020  Internal  Revolution
# 72         India        2020  Internal  Revolution
# 73      Ethiopia        2020  Internal       Civil
# 74       Nigeria        2021  Internal       Civil
# 75          Cuba        2021  Internal  Revolution
# 76  South Africa        2021  Internal  Revolution
# 77      Colombia        2021  Internal  Revolution
# 78        Russia        2021  Internal  Revolution
# 79       Tunisia        2021  Internal  Revolution
# 80       Ecuador        2022  Internal  Revolution
# 81          Peru        2022  Internal  Revolution
# 82      Pakistan        2022  Internal  Revolution
# 83          Iran        2022  Internal  Revolution
# 84    Kazakhstan        2022  Internal  Revolution
# 85     Sri Lanka        2022  Internal  Revolution
# 86    Uzbekistan        2022  Internal  Revolution

# %% [markdown]
# # Function list

# %%
def country_info(x):
    return conflict_df['country'].iloc[x], conflict_df['start_date'].iloc[x]

# %%
def random_country(lower_bound, upper_bound):
    random_country = random.choice(tuple(all_countries_list))
    random_5year = old_features[(old_features['Country']==random_country) & ((old_features['Year'] >= lower_bound) & (old_features['Year'] <= upper_bound))].copy()
    return random_5year

# %%
def war_automater(x):
    country, start_date = country_info(x)
    start_date = start_date - 1
    five_years_before = start_date-4
    five_year_df = old_features[(old_features['Country']==country) & ((old_features['Year'] >= five_years_before) & (old_features['Year'] <= (start_date)))].copy()
    return five_year_df

# %%
def pair_automater(x):
    country, start_date = country_info(x)
    start_date = start_date - 1
    five_years_before = start_date-4
    
    country_5y = old_features[(old_features['Country']==country) & ((old_features['Year'] >= five_years_before) & (old_features['Year'] <= start_date))].copy()
    rando = random_country(five_years_before, start_date)
    while len(rando) != 5:
        rando = random_country(five_years_before, start_date)
    country_5y['Conflict'] = 1
    rando['Conflict'] = 0
    return pd.concat([country_5y, rando])

# %%
def complete_automater(x):
    df = war_automater(x)
    df = df.dropna(axis = 1)
    name = df['Country'].iloc[1]
    df = df.drop(columns = ['Country'])
    df = df.reset_index()
    df = df.drop(columns = 'index')
#     print(name)
    return df, name

# %%
def pair_complete_automater(x):
    df = pair_automater(x)
    df = df.dropna(axis = 1)
    name = df['Country'].iloc[1], df['Country'].iloc[6]
    df = df.drop(columns = ['Country'])
    df = df.reset_index()
    df = df.drop(columns = 'index')
#     print(name)
    return df, name

# %%
def graph_prod(x):
    df, name = complete_automater(x)
    print(name)
    for i in np.arange(0, len(df.columns)):
        sns.lineplot(x=df.index, y= df.iloc[:,i])
        plt.show()

# %%
# math.ceil(math.sqrt(len(df.columns)))
def graph_prod2(x):
    data, name = complete_automater(x)
    scaler = MinMaxScaler()
    df = pd.DataFrame(scaler.fit_transform(data))
    df.columns = data.columns
    df.index = years
    print(name)
    for i in np.arange(0, len(df.columns)):
        sns.lineplot(x=df.index, y= m.iloc[:,i])
        plt.show()

# %%
def catplot(x):
    df, name = complete_automater(x)
    dfm = df.melt('Year', var_name='cols', value_name='vals')
    sns.catplot(x="Year", y="vals", hue='cols', data=dfm, kind='point', palette = 'pastel')

# %%
def ca_scaled(x):
    df, name = complete_automater(x)
    scaler = MinMaxScaler()
    dfs = pd.DataFrame(scaler.fit_transform(df))
    dfs.columns = df.columns
    dfs['Year'] = df['Year']
    return dfs

# %%
def pair_scaled(x):
    df, name = pair_complete_automater(x)
    scaler = MinMaxScaler()
    dfs = pd.DataFrame(scaler.fit_transform(df))
    dfs.columns = df.columns
    dfs['Year'] = df['Year']
    return dfs

# %%
def catplot_scaled(x):
    dfs = ca_scaled(x)
    dfsm = dfs.melt('Year', var_name='cols', value_name='vals')
    sns.catplot(x="Year", y="vals", hue='cols', data=dfsm, kind='point', palette = 'pastel')

# %%
def pct(x):
    df, name = complete_automater(x)
    p_change = df.pct_change()
    p_change.drop(columns = 'Year')
    p_change['Year'] = df['Year']
    final_pct = p_change.drop(df.index[0])
    return final_pct

# %%
def pair_pct(x):
    df, name = pair_complete_automater(x)
    df_c = df[df['Conflict'] == 1]
    df_r = df[df['Conflict'] == 0]
    p_change_c = df_c.pct_change()
    p_change_r = df_r.pct_change()
    p_change = pd.concat([p_change_c, p_change_r])
    p_change.drop(columns = 'Year')
    p_change['Year'] = df['Year']
    p_change.drop(columns = 'Conflict')
    p_change['Conflict'] = df['Conflict']
    final_pct = p_change.drop(df.index[[0, -5]])
    return final_pct

# %%
def catplot_pct(x):
    df = pct(x)
    dfm = df.melt('Year', var_name='cols', value_name='vals')
    sns.catplot(x="Year", y="vals", hue='cols', data=dfm, kind='point', palette = 'pastel')

# %%
def pct_mean(x):
    df, name = complete_automater(x)
    p_change = df.pct_change()
    p_change.drop(columns = 'Year')
    p_change['Country'] = name
    final_pct = p_change.drop(df.index[0])
    final_pct = final_pct.groupby('Country').mean()
    final_pct['Year'] = df['Year'].iloc[-1]
    return final_pct

# %%
def pair_pct_mean(x):
    df, name = pair_complete_automater(x)
    df_c = df[df['Conflict'] == 1]
    df_r = df[df['Conflict'] == 0]
    p_change_c = df_c.pct_change()
    p_change_c['Country'] = name[0]
    p_change_c['Conflict'] = df_c['Conflict']
    p_change_r = df_r.pct_change()
    p_change_r['Country'] = name[1]
    p_change_r['Conflict'] = df_r['Conflict']
    p_change = pd.concat([p_change_c, p_change_r])
    p_change.drop(columns = 'Year')
    final_pct = p_change.drop(df.index[0])
    final_pct = final_pct.groupby('Country').mean()
    final_pct['Year'] = df['Year'].iloc[-1]
    return final_pct

# %%
def all_pcts():
    full_df = pd.DataFrame()
    for i in range(0, len(conflict_df)):
        x = pct_mean(i)
        full_df = pd.concat([full_df,x])
    return full_df

# %%
def pair_all_pcts():
    full_df = pd.DataFrame()
    for i in range(0, len(conflict_df)):
        x = pair_pct_mean(i)
        full_df = pd.concat([full_df, x])
    return full_df

# %%
def pair_all_complete():
    full_df = pd.DataFrame()
    for i in range(0, len(conflict_df)):
        x, y = pair_complete_automater(i)
        x['Country'] = y
        full_df = pd.concat([full_df, x])
    return full_df

# %% [markdown]
# # Playground

# %%
pair_all_complete()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 pair_all_complete()
#
# Cell In [37], line 5, in pair_all_complete()
#       3 for i in range(0, len(conflict_df)):
#       4     x, y = pair_complete_automater(i)
# ----> 5     x['Country'] = y
#       6     full_df = pd.concat([full_df, x])
#       7 return full_df
#
# File ~/.pyenv/versions/conflict_prediction/lib/python3.10/site-packages/pandas/core/frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~/.pyenv/versions/conflict_prediction/lib/python3.10/site-packages/pandas/core/frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.pyenv/versions/conflict_prediction/lib/python3.10/site-packages/pandas/core/frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/.pyenv/versions/conflict_prediction/lib/python3.10/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (2) does not match length of index (9)

# %%
full_table = pair_all_pcts()
full_table
# Out:
#                 Year  Arms imports million constant U.S. dollars  \
# Country
# Lebanon       1974.0                                    1.839887
# Vietnam       1974.0                                   -0.065672
# Indonesia     1975.0                                    2.927286
# Sweden        1975.0                                    0.388931
# Afghanistan   1977.0                                    0.440821
# ...              ...                                         ...
# Lesotho       2021.0                                         NaN
# Sri Lanka     2021.0                                         NaN
# Turkmenistan  2021.0                                         NaN
# Mongolia      2021.0                                         NaN
# Uzbekistan    2021.0                                         NaN
#
#               Foreign aid and official development assistance received  \
# Country
# Lebanon                                                4.072604
# Vietnam                                                0.152892
# Indonesia                                                   NaN
# Sweden                                                      NaN
# Afghanistan                                            0.113211
# ...                                                         ...
# Lesotho                                                     NaN
# Sri Lanka                                                   NaN
# Turkmenistan                                                NaN
# Mongolia                                                    NaN
# Uzbekistan                                                  NaN
#
#               Food production index (2004-2006 = 100)  \
# Country
# Lebanon                                      0.065699
# Vietnam                                      0.015973
# Indonesia                                    0.027411
# Sweden                                       0.012272
# Afghanistan                                 -0.011947
# ...                                               ...
# Lesotho                                           NaN
# Sri Lanka                                         NaN
# Turkmenistan                                      NaN
# Mongolia                                          NaN
# Uzbekistan                                        NaN
#
#               Population size in millions  \
# Country
# Lebanon                          0.026258
# Vietnam                          0.023685
# Indonesia                        0.026106
# Sweden                           0.002766
# Afghanistan                      0.018737
# ...                                   ...
# Lesotho                          0.008272
# Sri Lanka                        0.008295
# Turkmenistan                     0.015272
# Mongolia                         0.017236
# Uzbekistan                       0.018981
#
#               Rural population percent of total population  \
# Country
# Lebanon                                          -0.039922
# Vietnam                                          -0.001165
# Indonesia                                        -0.006043
# Sweden                                           -0.016251
# Afghanistan                                      -0.005108
# ...                                                    ...
# Lesotho                                          -0.006109
# Sri Lanka                                        -0.001473
# Turkmenistan                                     -0.009605
# Mongolia                                         -0.003335
# Uzbekistan                                        0.000606
#
#               Population growth percent  Life expectancy in years  \
# Country
# Lebanon                       -0.028028                  0.003406
# Vietnam                       -0.032802                  0.002345
# Indonesia                     -0.011514                  0.010421
# Sweden                         0.021660                  0.001204
# Afghanistan                   -0.108081                  0.014718
# ...                                 ...                       ...
# Lesotho                       -0.003085                       NaN
# Sri Lanka                      0.104186                       NaN
# Turkmenistan                  -0.038043                       NaN
# Mongolia                      -0.046061                       NaN
# Uzbekistan                     0.042175                       NaN
#
#               Death rate per 1000 people  \
# Country
# Lebanon                        -0.016689
# Vietnam                        -0.008226
# Indonesia                      -0.030794
# Sweden                          0.014403
# Afghanistan                    -0.024586
# ...                                  ...
# Lesotho                              NaN
# Sri Lanka                            NaN
# Turkmenistan                         NaN
# Mongolia                             NaN
# Uzbekistan                           NaN
#
#               Deaths of children under five years of age per 1000 live births  \
# Country
# Lebanon                                               -0.016670
# Vietnam                                               -0.012272
# Indonesia                                             -0.032617
# Sweden                                                -0.062791
# Afghanistan                                           -0.022143
# ...                                                         ...
# Lesotho                                                     NaN
# Sri Lanka                                                   NaN
# Turkmenistan                                                NaN
# Mongolia                                                    NaN
# Uzbekistan                                                  NaN
#
#               ...  Economic decline index 0 (low) - 10 (high)  \
# Country       ...
# Lebanon       ...                                         NaN
# Vietnam       ...                                         NaN
# Indonesia     ...                                         NaN
# Sweden        ...                                         NaN
# Afghanistan   ...                                         NaN
# ...           ...                                         ...
# Lesotho       ...                                    0.021199
# Sri Lanka     ...                                    0.010224
# Turkmenistan  ...                                    0.001789
# Mongolia      ...                                    0.007606
# Uzbekistan    ...                                   -0.037708
#
#               Uneven economic development index 0 (low) - 10 (high)  \
# Country
# Lebanon                                                     NaN
# Vietnam                                                     NaN
# Indonesia                                                   NaN
# Sweden                                                      NaN
# Afghanistan                                                 NaN
# ...                                                         ...
# Lesotho                                                0.003517
# Sri Lanka                                             -0.045228
# Turkmenistan                                          -0.027011
# Mongolia                                              -0.050581
# Uzbekistan                                            -0.046474
#
#               State legitimacy index 0 (high) - 10 (low)  \
# Country
# Lebanon                                              NaN
# Vietnam                                              NaN
# Indonesia                                            NaN
# Sweden                                               NaN
# Afghanistan                                          NaN
# ...                                                  ...
# Lesotho                                        -0.055256
# Sri Lanka                                      -0.021739
# Turkmenistan                                    0.002577
# Mongolia                                       -0.012043
# Uzbekistan                                     -0.005291
#
#               Human rights and rule of law index 0 (high) - 10 (low)  \
# Country
# Lebanon                                                     NaN
# Vietnam                                                     NaN
# Indonesia                                                   NaN
# Sweden                                                      NaN
# Afghanistan                                                 NaN
# ...                                                         ...
# Lesotho                                                0.005498
# Sri Lanka                                             -0.002830
# Turkmenistan                                          -0.002680
# Mongolia                                              -0.028824
# Uzbekistan                                            -0.046069
#
#               Demographic pressures 0 (low) - 10 (high)  \
# Country
# Lebanon                                             NaN
# Vietnam                                             NaN
# Indonesia                                           NaN
# Sweden                                              NaN
# Afghanistan                                         NaN
# ...                                                 ...
# Lesotho                                       -0.001867
# Sri Lanka                                     -0.018458
# Turkmenistan                                   0.001817
# Mongolia                                      -0.019702
# Uzbekistan                                    -0.037523
#
#               Refugees and displaced persons index 0 (low) - 10 (high)  \
# Country
# Lebanon                                                     NaN
# Vietnam                                                     NaN
# Indonesia                                                   NaN
# Sweden                                                      NaN
# Afghanistan                                                 NaN
# ...                                                         ...
# Lesotho                                               -0.026106
# Sri Lanka                                             -0.037803
# Turkmenistan                                          -0.042442
# Mongolia                                              -0.041366
# Uzbekistan                                            -0.054199
#
#               External interventions index 0 (low) - 10 (high)  \
# Country
# Lebanon                                                    NaN
# Vietnam                                                    NaN
# Indonesia                                                  NaN
# Sweden                                                     NaN
# Afghanistan                                                NaN
# ...                                                        ...
# Lesotho                                              -0.026409
# Sri Lanka                                            -0.023810
# Turkmenistan                                         -0.082896
# Mongolia                                             -0.017665
# Uzbekistan                                           -0.032421
#
#               Poverty percent of population  \
# Country
# Lebanon                                 NaN
# Vietnam                                 NaN
# Indonesia                               NaN
# Sweden                                  NaN
# Afghanistan                             NaN
# ...                                     ...
# Lesotho                                 NaN
# Sri Lanka                               NaN
# Turkmenistan                            NaN
# Mongolia                                NaN
# Uzbekistan                              NaN
#
#               Mobile network coverage percent of the population  \
# Country
# Lebanon                                                     NaN
# Vietnam                                                     NaN
# Indonesia                                                   NaN
# Sweden                                                      NaN
# Afghanistan                                                 NaN
# ...                                                         ...
# Lesotho                                                     NaN
# Sri Lanka                                                   NaN
# Turkmenistan                                                NaN
# Mongolia                                                    NaN
# Uzbekistan                                                  NaN
#
#               Happiness Index 0 (unhappy) - 10 (happy)
# Country
# Lebanon                                            NaN
# Vietnam                                            NaN
# Indonesia                                          NaN
# Sweden                                             NaN
# Afghanistan                                        NaN
# ...                                                ...
# Lesotho                                      -0.019735
# Sri Lanka                                    -0.004460
# Turkmenistan                                 -0.013867
# Mongolia                                      0.038840
# Uzbekistan                                    0.003864
#
# [173 rows x 79 columns]

# %%
conflicts = full_table

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer(max_iter=10, random_state=0, missing_values=np.nan)
imputer2 = IterativeImputer(max_iter=10, random_state=0, missing_values=np.nan)

conflict = ['target'] = 1
sample_full_clean['target'] = 0

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']


full_dataset = pd.concat([grouped_df,sample_full_clean])

# %%
data_numeric = full_dataset.select_dtypes(include=numerics)

imputer.fit(data_numeric)
imputed_final_df = pd.DataFrame(imputer.transform(data_numeric),columns=full_dataset.columns)
imputed_final_df.head()

# %%
data_numeric2 = grouped_df.select_dtypes(include=numerics)

imputed_conflict_df = pd.DataFrame(imputer2.fit_transform(data_numeric2),columns=data_numeric2.columns)
imputed_control_df = pd.DataFrame(imputer2.fit_transform(sample_full_clean),columns=data_numeric2.columns)

# %%
separate_impute_full_df = pd.concat([imputed_control_df,imputed_conflict_df])
separate_impute_full_df['target'] = separate_impute_full_df['target'].astype(int)
separate_impute_full_df
imputed_final_df

# %% [markdown]
# # Data exploration

# %%
conflicts_1990 = conflict_df[conflict_df['start_date'] >= 1990]
conflicts_1990 = conflicts_1990.reset_index().drop(columns = 'index')
conflicts_1990
# Out:
#        country  start_date      Type         War
# 0   Bangladesh        1990  Internal  Revolution
# 1         Iraq        1991  Internal       Civil
# 2      Algeria        1991  Internal       Civil
# 3     Thailand        1992  Internal  Revolution
# 4         Peru        1992  Internal       Civil
# ..         ...         ...       ...         ...
# 71    Pakistan        2022  Internal  Revolution
# 72        Iran        2022  Internal  Revolution
# 73  Kazakhstan        2022  Internal  Revolution
# 74   Sri Lanka        2022  Internal  Revolution
# 75  Uzbekistan        2022  Internal  Revolution
#
# [76 rows x 4 columns]

# %%
conflict_1990
# Out:
#      Unnamed: 0      Country  Year  Year -1  Year -2  Year -3  Year -4  \
# 0           NaN      Lebanon  1975     1974     1973     1972     1971
# 1           NaN   Mozambique  1975     1974     1973     1972     1971
# 2           NaN       Angola  1975     1974     1973     1972     1971
# 3           NaN    Indonesia  1976     1975     1974     1973     1972
# 4           NaN  Afghanistan  1978     1977     1976     1975     1974
# ..          ...          ...   ...      ...      ...      ...      ...
# 106         NaN         Peru  2022     2021     2020     2019     2018
# 107         NaN      Ecuador  2022     2021     2020     2019     2018
# 108         NaN   Uzbekistan  2022     2021     2020     2019     2018
# 109         NaN    Sri Lanka  2022     2021     2020     2019     2018
# 110         NaN   Kazakhstan  2022     2021     2020     2019     2018
#
#      Year -5
# 0       1970
# 1       1970
# 2       1970
# 3       1971
# 4       1973
# ..       ...
# 106     2017
# 107     2017
# 108     2017
# 109     2017
# 110     2017
#
# [111 rows x 8 columns]

# %%
def country_1990(x):
    return conflict_1990['Country'].iloc[x], conflict_1990['Year'].iloc[x]

# %%
def automater_1990(x):
    country, start_date = country_1990(x)
    start_date = start_date - 1
    five_years_before = start_date-4
    five_year_df = old_features[(old_features['Country']==country) & ((old_features['Year'] >= five_years_before) & (old_features['Year'] <= (start_date)))].copy()
    return five_year_df

# %%
def complete_1990(x):
    df = automater_1990(x)
#     df = df.dropna(axis = 1, how = 'all')
    df = df.reset_index()
    df = df.drop(columns = 'index')
#     print(name)
    return df

# %%
def all_1990s():
    full_df = pd.DataFrame()
    for i in range(0, len(conflict_1990)):
        x = complete_1990(i)
        full_df = pd.concat([full_df,x])
    return full_df

# %%
x = all_1990s()
x.tail(40)
# Out:
#       Country    Year  \
# 0     Tunisia  2016.0
# 1     Tunisia  2017.0
# 2     Tunisia  2018.0
# 3     Tunisia  2019.0
# 4     Tunisia  2020.0
# 0        Iran  2017.0
# 1        Iran  2018.0
# 2        Iran  2019.0
# 3        Iran  2020.0
# 4        Iran  2021.0
# 0    Pakistan  2017.0
# 1    Pakistan  2018.0
# 2    Pakistan  2019.0
# 3    Pakistan  2020.0
# 4    Pakistan  2021.0
# 0        Peru  2017.0
# 1        Peru  2018.0
# 2        Peru  2019.0
# 3        Peru  2020.0
# 4        Peru  2021.0
# 0     Ecuador  2017.0
# 1     Ecuador  2018.0
# 2     Ecuador  2019.0
# 3     Ecuador  2020.0
# 4     Ecuador  2021.0
# 0  Uzbekistan  2017.0
# 1  Uzbekistan  2018.0
# 2  Uzbekistan  2019.0
# 3  Uzbekistan  2020.0
# 4  Uzbekistan  2021.0
# 0   Sri Lanka  2017.0
# 1   Sri Lanka  2018.0
# 2   Sri Lanka  2019.0
# 3   Sri Lanka  2020.0
# 4   Sri Lanka  2021.0
# 0  Kazakhstan  2017.0
# 1  Kazakhstan  2018.0
# 2  Kazakhstan  2019.0
# 3  Kazakhstan  2020.0
# 4  Kazakhstan  2021.0
#
#    Military spending percent of total government spending   \
# 0                                               8.18
# 1                                               7.07
# 2                                               6.89
# 3                                               8.07
# 4                                               8.82
# 0                                              16.05
# 1                                              13.93
# 2                                              12.64
# 3                                              11.71
# 4                                                NaN
# 0                                              17.72
# 1                                              19.09
# 2                                              18.70
# 3                                              17.41
# 4                                                NaN
# 0                                               5.87
# 1                                               5.49
# 2                                               5.60
# 3                                               4.83
# 4                                                NaN
# 0                                               6.47
# 1                                               6.16
# 2                                               6.10
# 3                                               6.18
# 4                                                NaN
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                              11.05
# 1                                               9.89
# 2                                               9.71
# 3                                              10.30
# 4                                                NaN
# 0                                               3.45
# 1                                               4.65
# 2                                               5.25
# 3                                               4.56
# 4                                                NaN
#
#    Arms imports million constant U.S. dollars  \
# 0                                        35.0
# 1                                        89.0
# 2                                       180.0
# 3                                        15.0
# 4                                        15.0
# 0                                         4.0
# 1                                         4.0
# 2                                         3.0
# 3                                         2.0
# 4                                         NaN
# 0                                       837.0
# 1                                       799.0
# 2                                       521.0
# 3                                       759.0
# 4                                         NaN
# 0                                        65.0
# 1                                        94.0
# 2                                         0.0
# 3                                        19.0
# 4                                         NaN
# 0                                        20.0
# 1                                         5.0
# 2                                         3.0
# 3                                        23.0
# 4                                         NaN
# 0                                         NaN
# 1                                       131.0
# 2                                        53.0
# 3                                        46.0
# 4                                         NaN
# 0                                        45.0
# 1                                       100.0
# 2                                        59.0
# 3                                         NaN
# 4                                         NaN
# 0                                       214.0
# 1                                       310.0
# 2                                       312.0
# 3                                       268.0
# 4                                         NaN
#
#    Cost of living index world average = 100  \
# 0                                       NaN
# 1                                     43.98
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 0                                     60.16
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 0                                     45.20
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 0                                     83.26
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 0                                     82.35
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 0                                     52.19
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 0                                     55.08
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Food price index world average = 100  \
# 0                                   NaN
# 1                                61.571
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                                98.980
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                                70.188
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                               100.450
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                               103.177
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                                85.113
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                                70.570
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    Housing and utilities price index world average  = 100  \
# 0                                                NaN
# 1                                             21.847
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                             42.643
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                             32.722
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                             88.872
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                             54.991
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                             32.959
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                             63.413
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Healthcare price index world average = 100  \
# 0                                         NaN
# 1                                       42.49
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 0                                       35.59
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 0                                       31.71
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 0                                       59.47
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 0                                       67.88
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 0                                       19.65
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 0                                       30.55
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Happiness Index 0 (unhappy) - 10 (happy)  Human Development Index (0 - 1)  \
# 0                                      5.05                            0.736
# 1                                      4.80                            0.738
# 2                                      4.59                            0.739
# 3                                      4.46                            0.739
# 4                                      4.60                            0.740
# 0                                      4.69                            0.799
# 1                                      4.71                            0.797
# 2                                      4.55                            0.797
# 3                                      4.72                            0.783
# 4                                      4.89                              NaN
# 0                                      5.27                            0.558
# 1                                      5.47                            0.560
# 2                                      5.65                            0.560
# 3                                      4.93                            0.557
# 4                                      4.52                              NaN
# 0                                      5.72                            0.756
# 1                                      5.66                            0.759
# 2                                      5.70                            0.759
# 3                                      5.84                            0.777
# 4                                      5.56                              NaN
# 0                                      6.01                            0.757
# 1                                      5.97                            0.758
# 2                                      6.03                            0.758
# 3                                      5.76                            0.759
# 4                                      5.53                              NaN
# 0                                      5.97                            0.707
# 1                                      6.10                            0.710
# 2                                      6.17                            0.710
# 3                                      6.18                            0.720
# 4                                      6.06                              NaN
# 0                                      4.44                            0.776
# 1                                      4.47                            0.780
# 2                                      4.37                            0.780
# 3                                      4.33                            0.782
# 4                                      4.36                              NaN
# 0                                      5.82                            0.813
# 1                                      5.79                            0.817
# 2                                      5.81                            0.817
# 3                                      6.15                            0.825
# 4                                      6.23                              NaN
#
#    ...  Security threats index 0 (low) - 10 (high)  \
# 0  ...                                         7.9
# 1  ...                                         8.3
# 2  ...                                         8.0
# 3  ...                                         7.7
# 4  ...                                         7.4
# 0  ...                                         7.5
# 1  ...                                         7.2
# 2  ...                                         6.9
# 3  ...                                         7.2
# 4  ...                                         6.9
# 0  ...                                         9.1
# 1  ...                                         8.8
# 2  ...                                         8.5
# 3  ...                                         8.2
# 4  ...                                         7.9
# 0  ...                                         7.1
# 1  ...                                         6.8
# 2  ...                                         6.5
# 3  ...                                         6.4
# 4  ...                                         6.1
# 0  ...                                         6.8
# 1  ...                                         6.5
# 2  ...                                         6.2
# 3  ...                                         6.2
# 4  ...                                         5.9
# 0  ...                                         7.1
# 1  ...                                         7.1
# 2  ...                                         6.8
# 3  ...                                         6.5
# 4  ...                                         6.2
# 0  ...                                         7.4
# 1  ...                                         7.1
# 2  ...                                         6.8
# 3  ...                                         7.1
# 4  ...                                         6.8
# 0  ...                                         5.2
# 1  ...                                         4.9
# 2  ...                                         4.6
# 3  ...                                         4.3
# 4  ...                                         4.0
#
#    Factionalized elites index 0 (low) - 10 (high)  \
# 0                                             7.8
# 1                                             7.8
# 2                                             7.8
# 3                                             7.8
# 4                                             7.8
# 0                                             9.6
# 1                                             9.6
# 2                                             9.6
# 3                                             9.6
# 4                                             9.6
# 0                                             8.9
# 1                                             8.9
# 2                                             9.3
# 3                                             9.0
# 4                                             9.0
# 0                                             6.9
# 1                                             6.9
# 2                                             6.9
# 3                                             7.4
# 4                                             7.4
# 0                                             8.2
# 1                                             8.2
# 2                                             8.2
# 3                                             8.2
# 4                                             8.2
# 0                                             8.8
# 1                                             8.8
# 2                                             8.8
# 3                                             8.8
# 4                                             8.8
# 0                                             8.8
# 1                                             8.8
# 2                                             9.1
# 3                                             9.1
# 4                                             9.1
# 0                                             7.6
# 1                                             7.6
# 2                                             7.6
# 3                                             7.6
# 4                                             7.6
#
#    Group grievance index 0 (low) - 10 (high)  \
# 0                                        7.9
# 1                                        7.7
# 2                                        7.4
# 3                                        7.1
# 4                                        6.8
# 0                                        9.3
# 1                                        9.3
# 2                                        9.5
# 3                                        9.6
# 4                                        9.3
# 0                                       10.0
# 1                                        9.7
# 2                                        9.4
# 3                                        9.1
# 4                                        8.8
# 0                                        7.4
# 1                                        7.7
# 2                                        8.0
# 3                                        8.3
# 4                                        8.6
# 0                                        7.3
# 1                                        7.0
# 2                                        6.7
# 3                                        6.4
# 4                                        6.1
# 0                                        7.1
# 1                                        6.9
# 2                                        6.6
# 3                                        6.3
# 4                                        6.0
# 0                                        9.0
# 1                                        8.7
# 2                                        9.0
# 3                                        9.1
# 4                                        8.6
# 0                                        7.6
# 1                                        7.9
# 2                                        8.1
# 3                                        8.2
# 4                                        8.0
#
#    Economic decline index 0 (low) - 10 (high)  \
# 0                                         6.9
# 1                                         6.7
# 2                                         6.6
# 3                                         6.7
# 4                                         7.2
# 0                                         6.4
# 1                                         6.4
# 2                                         6.9
# 3                                         7.2
# 4                                         7.6
# 0                                         6.9
# 1                                         6.6
# 2                                         6.3
# 3                                         7.1
# 4                                         7.1
# 0                                         3.2
# 1                                         3.5
# 2                                         3.6
# 3                                         3.3
# 4                                         4.8
# 0                                         6.0
# 1                                         6.0
# 2                                         5.7
# 3                                         5.4
# 4                                         6.3
# 0                                         6.3
# 1                                         6.1
# 2                                         5.8
# 3                                         5.5
# 4                                         5.4
# 0                                         5.4
# 1                                         5.5
# 2                                         5.5
# 3                                         5.2
# 4                                         5.6
# 0                                         6.4
# 1                                         5.9
# 2                                         5.6
# 3                                         5.3
# 4                                         5.5
#
#    Uneven economic development index 0 (low) - 10 (high)  \
# 0                                                5.1
# 1                                                4.9
# 2                                                5.0
# 3                                                4.9
# 4                                                4.6
# 0                                                5.6
# 1                                                5.6
# 2                                                5.3
# 3                                                5.0
# 4                                                4.9
# 0                                                6.5
# 1                                                6.2
# 2                                                5.9
# 3                                                5.6
# 4                                                5.3
# 0                                                7.4
# 1                                                7.1
# 2                                                6.8
# 3                                                6.5
# 4                                                6.4
# 0                                                6.7
# 1                                                6.7
# 2                                                6.4
# 3                                                6.1
# 4                                                6.0
# 0                                                6.9
# 1                                                6.7
# 2                                                6.2
# 3                                                5.9
# 4                                                5.7
# 0                                                7.1
# 1                                                6.8
# 2                                                6.5
# 3                                                6.2
# 4                                                5.9
# 0                                                4.2
# 1                                                3.9
# 2                                                3.6
# 3                                                3.3
# 4                                                3.2
#
#    State legitimacy index 0 (high) - 10 (low)  \
# 0                                         6.7
# 1                                         6.5
# 2                                         6.6
# 3                                         6.7
# 4                                         6.2
# 0                                         9.0
# 1                                         9.2
# 2                                         9.0
# 3                                         9.2
# 4                                         9.2
# 0                                         8.1
# 1                                         7.8
# 2                                         7.9
# 3                                         7.6
# 4                                         7.3
# 0                                         7.2
# 1                                         6.9
# 2                                         6.6
# 3                                         7.1
# 4                                         7.2
# 0                                         6.5
# 1                                         6.2
# 2                                         5.7
# 3                                         6.0
# 4                                         5.7
# 0                                         9.5
# 1                                         9.5
# 2                                         9.5
# 3                                         9.4
# 4                                         9.3
# 0                                         6.9
# 1                                         6.6
# 2                                         6.9
# 3                                         6.6
# 4                                         6.3
# 0                                         8.3
# 1                                         8.4
# 2                                         8.5
# 3                                         8.5
# 4                                         8.2
#
#    Human rights and rule of law index 0 (high) - 10 (low)  \
# 0                                                6.7
# 1                                                6.5
# 2                                                6.2
# 3                                                5.9
# 4                                                5.6
# 0                                                9.5
# 1                                                9.2
# 2                                                8.9
# 3                                                9.2
# 4                                                9.5
# 0                                                8.0
# 1                                                7.7
# 2                                                7.4
# 3                                                7.1
# 4                                                7.3
# 0                                                4.3
# 1                                                4.0
# 2                                                3.7
# 3                                                3.4
# 4                                                3.5
# 0                                                5.0
# 1                                                4.5
# 2                                                4.2
# 3                                                3.9
# 4                                                4.2
# 0                                                9.2
# 1                                                8.7
# 2                                                7.9
# 3                                                7.6
# 4                                                7.6
# 0                                                8.3
# 1                                                8.4
# 2                                                8.4
# 3                                                8.1
# 4                                                8.2
# 0                                                7.3
# 1                                                7.0
# 2                                                6.7
# 3                                                6.4
# 4                                                6.7
#
#    Demographic pressures 0 (low) - 10 (high)  \
# 0                                        4.4
# 1                                        4.2
# 2                                        3.9
# 3                                        3.6
# 4                                        3.3
# 0                                        4.9
# 1                                        5.0
# 2                                        4.5
# 3                                        4.5
# 4                                        5.5
# 0                                        8.4
# 1                                        8.1
# 2                                        7.8
# 3                                        7.9
# 4                                        7.9
# 0                                        5.0
# 1                                        6.5
# 2                                        6.2
# 3                                        5.9
# 4                                        7.4
# 0                                        6.5
# 1                                        6.0
# 2                                        5.7
# 3                                        5.4
# 4                                        6.9
# 0                                        5.6
# 1                                        5.4
# 2                                        5.1
# 3                                        4.8
# 4                                        4.8
# 0                                        6.2
# 1                                        6.7
# 2                                        6.0
# 3                                        5.7
# 4                                        5.7
# 0                                        4.5
# 1                                        4.2
# 2                                        3.9
# 3                                        3.6
# 4                                        4.1
#
#    Refugees and displaced persons index 0 (low) - 10 (high)  \
# 0                                                4.2
# 1                                                4.7
# 2                                                4.4
# 3                                                4.1
# 4                                                3.8
# 0                                                6.5
# 1                                                6.2
# 2                                                5.9
# 3                                                5.6
# 4                                                5.3
# 0                                                8.7
# 1                                                8.4
# 2                                                8.1
# 3                                                7.8
# 4                                                7.5
# 0                                                4.3
# 1                                                4.0
# 2                                                4.1
# 3                                                3.8
# 4                                                4.1
# 0                                                5.7
# 1                                                5.4
# 2                                                5.5
# 3                                                5.9
# 4                                                5.6
# 0                                                5.5
# 1                                                5.3
# 2                                                5.0
# 3                                                4.7
# 4                                                4.4
# 0                                                8.4
# 1                                                8.1
# 2                                                7.8
# 3                                                7.5
# 4                                                7.2
# 0                                                3.0
# 1                                                2.7
# 2                                                2.4
# 3                                                2.3
# 4                                                2.1
#
#    External interventions index 0 (low) - 10 (high)
# 0                                               6.6
# 1                                               6.4
# 2                                               6.1
# 3                                               5.8
# 4                                               5.5
# 0                                               6.5
# 1                                               6.2
# 2                                               6.7
# 3                                               7.0
# 4                                               6.7
# 0                                               9.4
# 1                                               9.1
# 2                                               8.8
# 3                                               8.5
# 4                                               8.2
# 0                                               3.5
# 1                                               3.2
# 2                                               2.9
# 3                                               2.6
# 4                                               2.3
# 0                                               6.3
# 1                                               6.0
# 2                                               5.7
# 3                                               5.4
# 4                                               5.1
# 0                                               4.6
# 1                                               4.1
# 2                                               4.1
# 3                                               4.3
# 4                                               4.0
# 0                                               6.3
# 1                                               6.0
# 2                                               6.3
# 3                                               6.0
# 4                                               5.7
# 0                                               4.2
# 1                                               3.9
# 2                                               3.6
# 3                                               3.3
# 4                                               3.0
#
# [40 rows x 91 columns]

# %%
y = x.describe().T
z = pd.DataFrame(y['count']/len(x))
z.sort_values('count').head(50)
# Out:
#                                                        count
# People practicing Judaism as percent of the pop...  0.026423
# Non religious people as percent of the population   0.030488
# Cost of living index world average = 100            0.042683
# Food price index world average = 100                0.042683
# Housing and utilities price index world average...  0.042683
# Healthcare price index world average = 100          0.042683
# Doctors per 1000 people                             0.052846
# Eastern Orthodox Christians as percent of the t...  0.060976
# People practicing Hinduism as percent of the po...  0.060976
# Buddhists as percent of the total population        0.101626
# Mobile network coverage percent of the population   0.107724
# Migrant population percent of total population      0.107724
# Poverty percent of population                       0.160569
# Shia Muslims as percent of the total population     0.172764
# Protestant Christians as percent of the total p...  0.180894
# Literacy rate                                       0.195122
# Catholic Christians as percent of the total pop...  0.195122
# Happiness Index 0 (unhappy) - 10 (happy)            0.256098
# Number of prisoners per 100000 people               0.258130
# Poverty ratio percent living on less than 5.50 ...  0.266260
# Poverty ratio percent living on less than 1.90 ...  0.266260
# Percent income earned by the top 10 percent of ...  0.266260
# Gini income inequality index                        0.266260
# Diesel prices at the pump in dollars per liter      0.276423
# Gasoline prices at the pump in dollars per liter    0.278455
# Sunni Muslims as percent of the total population    0.310976
# Homicides per 100000 people                         0.351626
# Shadow economy percent of GDP                       0.495935
# Real interest rate: Bank lending rate minus inf...  0.524390
# Public spending on education percent of GDP         0.528455
# Refugees and displaced persons index 0 (low) - ...  0.532520
# Security threats index 0 (low) - 10 (high)          0.532520
# Factionalized elites index 0 (low) - 10 (high)      0.532520
# Group grievance index 0 (low) - 10 (high)           0.532520
# Economic decline index 0 (low) - 10 (high)          0.532520
# Uneven economic development index 0 (low) - 10 ...  0.532520
# State legitimacy index 0 (high) - 10 (low)          0.532520
# Human rights and rule of law index 0 (high) - 1...  0.532520
# Demographic pressures 0 (low) - 10 (high)           0.532520
# External interventions index 0 (low) - 10 (high)    0.532520
# Labor freedom index (0-100)                         0.540650
# Banking system z-scores                             0.544715
# Corruption Perceptions Index 100 = no corruption    0.550813
# Christians as percent of the total population       0.556911
# Suicide mortality rate per 100000 population        0.581301
# Government debt as percent of GDP                   0.611789
# Economic freedom overall index (0-100)              0.615854
# Military spending percent of total government s...  0.630081
# Voice and accountability index (-2.5 weak; 2.5 ...  0.636179
# Regulatory quality index (-2.5 weak; 2.5 strong)    0.636179

# %%
y.sort_values('count').head(50)
# Out:
#                                                     count        mean  \
# Cost of living index world average = 100              0.0         NaN
# Food price index world average = 100                  0.0         NaN
# Housing and utilities price index world average...    0.0         NaN
# Healthcare price index world average = 100            0.0         NaN
# Happiness Index 0 (unhappy) - 10 (happy)              1.0    4.560000
# Mobile network coverage percent of the population     6.0   59.450000
# Doctors per 1000 people                              10.0    1.036000
# People practicing Judaism as percent of the pop...   10.0    0.820000
# Non religious people as percent of the population    15.0   17.100000
# Poverty percent of population                        28.0   29.082143
# People practicing Hinduism as percent of the po...   30.0   38.203333
# Eastern Orthodox Christians as percent of the t...   30.0   53.333333
# Migrant population percent of total population       37.0    7.378378
# Literacy rate                                        41.0   73.082683
# Buddhists as percent of the total population         50.0   37.056000
# Number of prisoners per 100000 people                64.0  152.609375
# Shia Muslims as percent of the total population      67.0   43.089552
# Poverty ratio percent living on less than 1.90 ...   71.0   16.132394
# Gini income inequality index                         71.0   39.122535
# Percent income earned by the top 10 percent of ...   71.0   30.750704
# Poverty ratio percent living on less than 5.50 ...   71.0   54.497183
# Protestant Christians as percent of the total p...   77.0    9.644156
# Catholic Christians as percent of the total pop...   84.0   49.822619
# Refugees and displaced persons index 0 (low) - ...   87.0    5.895402
# External interventions index 0 (low) - 10 (high)     87.0    6.581609
# Demographic pressures 0 (low) - 10 (high)            87.0    7.243678
# Human rights and rule of law index 0 (high) - 1...   87.0    7.205747
# State legitimacy index 0 (high) - 10 (low)           87.0    7.503448
# Uneven economic development index 0 (low) - 10 ...   87.0    7.377011
# Economic decline index 0 (low) - 10 (high)           87.0    6.381609
# Group grievance index 0 (low) - 10 (high)            87.0    7.006897
# Security threats index 0 (low) - 10 (high)           87.0    6.825287
# Factionalized elites index 0 (low) - 10 (high)       87.0    7.142529
# Gasoline prices at the pump in dollars per liter     88.0    0.795114
# Diesel prices at the pump in dollars per liter       88.0    0.635909
# Corruption Perceptions Index 100 = no corruption     98.0   31.418367
# Labor freedom index (0-100)                          99.0   58.989899
# Homicides per 100000 people                         103.0    5.730097
# Banking system z-scores                             121.0   17.521322
# Sunni Muslims as percent of the total population    129.0   69.348837
# Suicide mortality rate per 100000 population        137.0    6.875912
# Real interest rate: Bank lending rate minus inf...  138.0    2.842899
# Government debt as percent of GDP                   139.0   61.635540
# Political stability index (-2.5 weak; 2.5 strong)   143.0   -0.816434
# Voice and accountability index (-2.5 weak; 2.5 ...  143.0   -0.808252
# Regulatory quality index (-2.5 weak; 2.5 strong)    143.0   -0.483706
# Control of corruption (-2.5 weak; 2.5 strong)       143.0   -0.715664
# Government effectiveness index (-2.5 weak; 2.5 ...  143.0   -0.594336
# Rule of law index (-2.5 weak; 2.5 strong)           143.0   -0.666224
# Public spending on education percent of GDP         149.0    3.545436
#
#                                                            std    min     25%  \
# Cost of living index world average = 100                   NaN    NaN     NaN
# Food price index world average = 100                       NaN    NaN     NaN
# Housing and utilities price index world average...         NaN    NaN     NaN
# Healthcare price index world average = 100                 NaN    NaN     NaN
# Happiness Index 0 (unhappy) - 10 (happy)                   NaN   4.56   4.560
# Mobile network coverage percent of the population    45.175292  10.00  16.950
# Doctors per 1000 people                               0.478799   0.54   0.580
# People practicing Judaism as percent of the pop...    0.549343   0.30   0.300
# Non religious people as percent of the population    23.920374   0.50   0.500
# Poverty percent of population                        14.459728  12.60  20.100
# People practicing Hinduism as percent of the po...   39.516897   1.40   2.300
# Eastern Orthodox Christians as percent of the t...   40.595849  11.00  11.000
# Migrant population percent of total population       10.168992   1.00   2.000
# Literacy rate                                        22.330920  30.62  58.940
# Buddhists as percent of the total population         41.567085   0.60   1.600
# Number of prisoners per 100000 people               100.558696  25.00  70.000
# Shia Muslims as percent of the total population      26.041186   5.00  15.000
# Poverty ratio percent living on less than 1.90 ...   20.434123   0.00   2.850
# Gini income inequality index                          8.188043  26.90  33.250
# Percent income earned by the top 10 percent of ...    6.198914  21.20  26.050
# Poverty ratio percent living on less than 5.50 ...   30.652224   1.20  27.700
# Protestant Christians as percent of the total p...    8.404267   1.80   5.100
# Catholic Christians as percent of the total pop...   39.688775   0.60   5.075
# Refugees and displaced persons index 0 (low) - ...    2.301613   2.00   3.550
# External interventions index 0 (low) - 10 (high)      1.967972   3.00   5.250
# Demographic pressures 0 (low) - 10 (high)             1.462135   4.50   5.900
# Human rights and rule of law index 0 (high) - 1...    1.664636   3.60   5.600
# State legitimacy index 0 (high) - 10 (low)            1.441853   4.00   6.450
# Uneven economic development index 0 (low) - 10 ...    1.223577   4.80   6.750
# Economic decline index 0 (low) - 10 (high)            1.724619   3.30   4.950
# Group grievance index 0 (low) - 10 (high)             1.589997   3.50   5.600
# Security threats index 0 (low) - 10 (high)            1.785160   3.10   5.900
# Factionalized elites index 0 (low) - 10 (high)        1.917158   1.60   6.000
# Gasoline prices at the pump in dollars per liter      0.412748   0.08   0.480
# Diesel prices at the pump in dollars per liter        0.407602   0.01   0.260
# Corruption Perceptions Index 100 = no corruption      9.311254  15.00  24.250
# Labor freedom index (0-100)                          13.543953  20.00  55.500
# Homicides per 100000 people                           6.140317   0.40   2.100
# Banking system z-scores                               9.461664   2.21  10.130
# Sunni Muslims as percent of the total population     28.047574   7.00  37.000
# Suicide mortality rate per 100000 population          3.814032   1.40   3.800
# Real interest rate: Bank lending rate minus inf...   17.405509 -63.79  -0.975
# Government debt as percent of GDP                    43.607294   4.80  37.010
# Political stability index (-2.5 weak; 2.5 strong)     0.956657  -3.18  -1.585
# Voice and accountability index (-2.5 weak; 2.5 ...    0.763136  -2.05  -1.320
# Regulatory quality index (-2.5 weak; 2.5 strong)      0.711059  -2.10  -1.000
# Control of corruption (-2.5 weak; 2.5 strong)         0.497369  -1.65  -1.120
# Government effectiveness index (-2.5 weak; 2.5 ...    0.635893  -1.96  -1.080
# Rule of law index (-2.5 weak; 2.5 strong)             0.673883  -1.92  -1.250
# Public spending on education percent of GDP           1.510326   0.90   2.690
#
#                                                         50%       75%     max
# Cost of living index world average = 100                NaN       NaN     NaN
# Food price index world average = 100                    NaN       NaN     NaN
# Housing and utilities price index world average...      NaN       NaN     NaN
# Healthcare price index world average = 100              NaN       NaN     NaN
# Happiness Index 0 (unhappy) - 10 (happy)              4.560    4.5600    4.56
# Mobile network coverage percent of the population    68.400   99.6750  100.00
# Doctors per 1000 people                               1.030    1.4900    1.55
# People practicing Judaism as percent of the pop...    0.800    1.3000    1.40
# Non religious people as percent of the population     1.000   49.7500   49.80
# Poverty percent of population                        22.600   35.0500   73.20
# People practicing Hinduism as percent of the po...   13.650   85.2250   86.90
# Eastern Orthodox Christians as percent of the t...   52.500   95.0000   98.00
# Migrant population percent of total population        4.000    8.0000   52.00
# Literacy rate                                        77.710   91.3400   99.24
# Buddhists as percent of the total population          8.000   94.4750   94.70
# Number of prisoners per 100000 people               107.000  250.0000  348.00
# Shia Muslims as percent of the total population      45.000   62.0000   92.00
# Poverty ratio percent living on less than 1.90 ...    5.600   27.6500   81.90
# Gini income inequality index                         36.400   43.7000   56.40
# Percent income earned by the top 10 percent of ...   29.000   34.0500   46.20
# Poverty ratio percent living on less than 5.50 ...   57.000   82.0000   98.90
# Protestant Christians as percent of the total p...    5.900   13.7000   34.90
# Catholic Christians as percent of the total pop...   61.250   90.5250   95.40
# Refugees and displaced persons index 0 (low) - ...    6.000    8.0000    9.80
# External interventions index 0 (low) - 10 (high)      6.600    7.8500    9.90
# Demographic pressures 0 (low) - 10 (high)             7.500    8.6000    9.70
# Human rights and rule of law index 0 (high) - 1...    7.700    8.5000   10.00
# State legitimacy index 0 (high) - 10 (low)            7.700    8.6500   10.00
# Uneven economic development index 0 (low) - 10 ...    7.400    8.1500    9.60
# Economic decline index 0 (low) - 10 (high)            6.900    7.8500    8.90
# Group grievance index 0 (low) - 10 (high)             6.900    8.2000   10.00
# Security threats index 0 (low) - 10 (high)            6.700    8.0500    9.90
# Factionalized elites index 0 (low) - 10 (high)        7.500    8.7000    9.90
# Gasoline prices at the pump in dollars per liter      0.740    1.0800    1.71
# Diesel prices at the pump in dollars per liter        0.565    0.9425    1.69
# Corruption Perceptions Index 100 = no corruption     29.500   37.0000   57.00
# Labor freedom index (0-100)                          60.000   65.0000   90.00
# Homicides per 100000 people                           3.100    7.8000   34.10
# Banking system z-scores                              17.210   22.7100   51.32
# Sunni Muslims as percent of the total population     82.000   90.0000  100.00
# Suicide mortality rate per 100000 population          5.700    9.2000   16.00
# Real interest rate: Bank lending rate minus inf...    3.630    9.2975   61.19
# Government debt as percent of GDP                    51.270   71.0850  344.32
# Political stability index (-2.5 weak; 2.5 strong)    -0.560   -0.0650    0.83
# Voice and accountability index (-2.5 weak; 2.5 ...   -0.990   -0.2750    1.10
# Regulatory quality index (-2.5 weak; 2.5 strong)     -0.410    0.0750    0.96
# Control of corruption (-2.5 weak; 2.5 strong)        -0.750   -0.3300    0.36
# Government effectiveness index (-2.5 weak; 2.5 ...   -0.620   -0.1600    0.71
# Rule of law index (-2.5 weak; 2.5 strong)            -0.680   -0.1600    0.86
# Public spending on education percent of GDP           3.490    4.5000    7.55

# %%
y.sort_values('count').tail(50)
# Out:
#                                                     count           mean  \
# Suicide mortality rate per 100000 population        137.0       6.875912
# Real interest rate: Bank lending rate minus inf...  138.0       2.842899
# Government debt as percent of GDP                   139.0      61.635540
# Political stability index (-2.5 weak; 2.5 strong)   143.0      -0.816434
# Voice and accountability index (-2.5 weak; 2.5 ...  143.0      -0.808252
# Regulatory quality index (-2.5 weak; 2.5 strong)    143.0      -0.483706
# Control of corruption (-2.5 weak; 2.5 strong)       143.0      -0.715664
# Government effectiveness index (-2.5 weak; 2.5 ...  143.0      -0.594336
# Rule of law index (-2.5 weak; 2.5 strong)           143.0      -0.666224
# Public spending on education percent of GDP         149.0       3.545436
# Freedom from corruption index (0-100)               149.0      27.872483
# Economic freedom overall index (0-100)              149.0      55.114094
# Military spending percent of total government s...  163.0       9.611472
# Access to electricity percent of the population     165.0      72.596121
# Fiscal balance percent of GDP                       176.0      -3.317216
# Shadow economy percent of GDP                       191.0      34.893979
# GDP per capita Purchasing Power Parity              205.0    9095.995707
# Youth unemployment ages 15-24                       215.0      14.892837
# Unemployment rate                                   215.0       7.525907
# Human Development Index (0 - 1)                     223.0       0.551570
# Internet users percent of population                226.0       7.688363
# Labor force participation rate                      226.0      61.663938
# Arms imports million constant U.S. dollars          232.0     240.762931
# External debt percent of Gross National Income      243.0      73.670494
# Christians as percent of the total population       245.0      37.361633
# Government spending as percent of GDP               252.0      12.628810
# Inflation: percent change in the Consumer Price...  258.0     407.014341
# Refugee population                                  259.0  206130.343629
# Capital investment as percent of GDP                269.0      21.724052
# Trade balance as percent of GDP                     272.0      -5.142206
# Trade openness: exports plus imports as percent...  272.0      61.364044
# Economic growth: the rate of change of real GDP     291.0       4.135636
# Income from natural resources percent of GDP        292.0      10.595411
# Foreign Direct Investment percent of GDP            292.0       2.322877
# GDP per capita current U.S. dollars                 295.0    2918.398000
# Foreign aid and official development assistance...  300.0     554.968167
# Economic globalization index (0-100)                305.0      43.233639
# Globalization index (0-100)                         305.0      44.617967
# Political rights index 7 (weak) - 1 (strong)        310.0       5.012903
# Deaths of children under five years of age per ...  310.0      88.606452
# Civil liberties index 7 (weak) - 1 (strong)         313.0       4.846645
# Political globalization index (0-100)               315.0      54.729175
# Food production index (2004-2006 = 100)             315.0      70.481905
# Social globalization index (0-100)                  315.0      33.952921
# Population growth percent                           317.0       2.239748
# Rural population percent of total population        317.0      57.050315
# Death rate per 1000 people                          317.0      10.241136
# Life expectancy in years                            317.0      61.678297
# Population size in millions                         317.0      30.492397
# Year                                                317.0    1996.296530
#
#                                                               std      min  \
# Suicide mortality rate per 100000 population             3.814032     1.40
# Real interest rate: Bank lending rate minus inf...      17.405509   -63.79
# Government debt as percent of GDP                       43.607294     4.80
# Political stability index (-2.5 weak; 2.5 strong)        0.956657    -3.18
# Voice and accountability index (-2.5 weak; 2.5 ...       0.763136    -2.05
# Regulatory quality index (-2.5 weak; 2.5 strong)         0.711059    -2.10
# Control of corruption (-2.5 weak; 2.5 strong)            0.497369    -1.65
# Government effectiveness index (-2.5 weak; 2.5 ...       0.635893    -1.96
# Rule of law index (-2.5 weak; 2.5 strong)                0.673883    -1.92
# Public spending on education percent of GDP              1.510326     0.90
# Freedom from corruption index (0-100)                   10.926838    10.00
# Economic freedom overall index (0-100)                  10.007112    16.00
# Military spending percent of total government s...       7.179559     1.08
# Access to electricity percent of the population         32.012319     6.70
# Fiscal balance percent of GDP                            4.802716   -24.50
# Shadow economy percent of GDP                            9.228037    15.65
# GDP per capita Purchasing Power Parity               11046.697400   715.45
# Youth unemployment ages 15-24                           10.722744     0.60
# Unemployment rate                                        5.145344     0.51
# Human Development Index (0 - 1)                          0.157213     0.27
# Internet users percent of population                    12.864828     0.00
# Labor force participation rate                          13.503639    38.77
# Arms imports million constant U.S. dollars             465.598437     0.00
# External debt percent of Gross National Income          69.081216     2.23
# Christians as percent of the total population           39.308052     0.00
# Government spending as percent of GDP                    5.569300     2.06
# Inflation: percent change in the Consumer Price...    2624.048385    -4.10
# Refugee population                                  425651.944753    19.00
# Capital investment as percent of GDP                     8.813105   -12.88
# Trade balance as percent of GDP                         13.045664   -83.79
# Trade openness: exports plus imports as percent...      35.250417     0.54
# Economic growth: the rate of change of real GDP          9.284842   -64.05
# Income from natural resources percent of GDP            12.908831     0.00
# Foreign Direct Investment percent of GDP                 3.153720    -5.29
# GDP per capita current U.S. dollars                   5048.824574    22.80
# Foreign aid and official development assistance...    1439.992885  -615.51
# Economic globalization index (0-100)                    15.271813    15.65
# Globalization index (0-100)                             14.185604    20.34
# Political rights index 7 (weak) - 1 (strong)             1.900390     1.00
# Deaths of children under five years of age per ...      65.508862     4.00
# Civil liberties index 7 (weak) - 1 (strong)              1.470478     2.00
# Political globalization index (0-100)                   18.334660    15.31
# Food production index (2004-2006 = 100)                 25.030302    19.30
# Social globalization index (0-100)                      18.405464     6.46
# Population growth percent                                1.709066    -2.70
# Rural population percent of total population            21.868519    10.67
# Death rate per 1000 people                               4.979524     2.33
# Life expectancy in years                                10.234657    38.56
# Population size in millions                             39.380155     0.33
# Year                                                    10.924674  1971.00
#
#                                                           25%        50%  \
# Suicide mortality rate per 100000 population           3.8000      5.700
# Real interest rate: Bank lending rate minus inf...    -0.9750      3.630
# Government debt as percent of GDP                     37.0100     51.270
# Political stability index (-2.5 weak; 2.5 strong)     -1.5850     -0.560
# Voice and accountability index (-2.5 weak; 2.5 ...    -1.3200     -0.990
# Regulatory quality index (-2.5 weak; 2.5 strong)      -1.0000     -0.410
# Control of corruption (-2.5 weak; 2.5 strong)         -1.1200     -0.750
# Government effectiveness index (-2.5 weak; 2.5 ...    -1.0800     -0.620
# Rule of law index (-2.5 weak; 2.5 strong)             -1.2500     -0.680
# Public spending on education percent of GDP            2.6900      3.490
# Freedom from corruption index (0-100)                 21.0000     27.000
# Economic freedom overall index (0-100)                51.0000     56.000
# Military spending percent of total government s...     5.2000      7.510
# Access to electricity percent of the population       48.2000     93.560
# Fiscal balance percent of GDP                         -5.4000     -2.545
# Shadow economy percent of GDP                         26.9050     35.420
# GDP per capita Purchasing Power Parity              2022.6100   4312.150
# Youth unemployment ages 15-24                          5.2000     12.570
# Unemployment rate                                      2.9250      6.920
# Human Development Index (0 - 1)                        0.4030      0.574
# Internet users percent of population                   0.0000      0.900
# Labor force participation rate                        47.9075     62.770
# Arms imports million constant U.S. dollars            10.0000     71.000
# External debt percent of Gross National Income        32.6400     54.690
# Christians as percent of the total population          3.4000     15.900
# Government spending as percent of GDP                  8.6750     11.310
# Inflation: percent change in the Consumer Price...     3.8250      7.700
# Refugee population                                  2359.0000  24802.000
# Capital investment as percent of GDP                  16.5300     21.660
# Trade balance as percent of GDP                       -9.8875     -3.460
# Trade openness: exports plus imports as percent...    35.3750     53.105
# Economic growth: the rate of change of real GDP        1.1350      4.330
# Income from natural resources percent of GDP           1.8650      5.765
# Foreign Direct Investment percent of GDP               0.0600      1.295
# GDP per capita current U.S. dollars                  282.0550    950.880
# Foreign aid and official development assistance...   126.3975    252.085
# Economic globalization index (0-100)                  30.5000     41.080
# Globalization index (0-100)                           32.9500     43.280
# Political rights index 7 (weak) - 1 (strong)           3.0000      6.000
# Deaths of children under five years of age per ...    32.0000     70.000
# Civil liberties index 7 (weak) - 1 (strong)            4.0000      5.000
# Political globalization index (0-100)                 44.1600     53.740
# Food production index (2004-2006 = 100)               51.5500     68.500
# Social globalization index (0-100)                    17.2950     29.650
# Population growth percent                              1.3800      2.280
# Rural population percent of total population          38.4900     62.750
# Death rate per 1000 people                             6.2500      8.440
# Life expectancy in years                              52.1400     64.250
# Population size in millions                            6.6200     17.770
# Year                                                1988.0000   1996.000
#
#                                                             75%          max
# Suicide mortality rate per 100000 population             9.2000       16.000
# Real interest rate: Bank lending rate minus inf...       9.2975       61.190
# Government debt as percent of GDP                       71.0850      344.320
# Political stability index (-2.5 weak; 2.5 strong)       -0.0650        0.830
# Voice and accountability index (-2.5 weak; 2.5 ...      -0.2750        1.100
# Regulatory quality index (-2.5 weak; 2.5 strong)         0.0750        0.960
# Control of corruption (-2.5 weak; 2.5 strong)           -0.3300        0.360
# Government effectiveness index (-2.5 weak; 2.5 ...      -0.1600        0.710
# Rule of law index (-2.5 weak; 2.5 strong)               -0.1600        0.860
# Public spending on education percent of GDP              4.5000        7.550
# Freedom from corruption index (0-100)                   33.0000       58.000
# Economic freedom overall index (0-100)                  61.0000       76.000
# Military spending percent of total government s...      11.8600       47.760
# Access to electricity percent of the population         99.5000      100.000
# Fiscal balance percent of GDP                           -0.6975       19.210
# Shadow economy percent of GDP                           42.6050       59.870
# GDP per capita Purchasing Power Parity               10386.1200    47819.430
# Youth unemployment ages 15-24                           21.0400       48.620
# Unemployment rate                                       10.4900       30.010
# Human Development Index (0 - 1)                          0.6765        0.859
# Internet users percent of population                     9.9150       55.000
# Labor force participation rate                          72.1900       90.320
# Arms imports million constant U.S. dollars             268.2500     3459.000
# External debt percent of Gross National Income          79.0650      384.840
# Christians as percent of the total population           89.2000      100.100
# Government spending as percent of GDP                   16.1825       35.850
# Inflation: percent change in the Consumer Price...      18.9250    23773.100
# Refugee population                                  183209.5000  2236350.000
# Capital investment as percent of GDP                    27.0300       59.340
# Trade balance as percent of GDP                          0.2825       45.940
# Trade openness: exports plus imports as percent...      74.3300      210.160
# Economic growth: the rate of change of real GDP          6.8450       57.820
# Income from natural resources percent of GDP            15.2925       67.890
# Foreign Direct Investment percent of GDP                 3.3625       18.280
# GDP per capita current U.S. dollars                   2782.2300    32127.980
# Foreign aid and official development assistance...     554.4250    22057.090
# Economic globalization index (0-100)                    55.7600       85.490
# Globalization index (0-100)                             52.9300       80.750
# Political rights index 7 (weak) - 1 (strong)             7.0000        7.000
# Deaths of children under five years of age per ...     146.0000      274.000
# Civil liberties index 7 (weak) - 1 (strong)              6.0000        7.000
# Political globalization index (0-100)                   66.6200       92.100
# Food production index (2004-2006 = 100)                 87.5000      148.100
# Social globalization index (0-100)                      48.8800       79.670
# Population growth percent                                2.8000       11.530
# Rural population percent of total population            71.9300       94.940
# Death rate per 1000 people                              13.8100       25.390
# Life expectancy in years                                70.1600       80.190
# Population size in millions                             37.3300      202.830
# Year                                                  2007.0000     2013.000
