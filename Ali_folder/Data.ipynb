# %% [markdown]
# # Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

url = 'https://raw.githubusercontent.com/chekirou/International-conflict-prediction/master/data/actual.csv'

# %%
df = pd.read_csv(url)

# %%
csv1 = pd.read_csv('csv1.csv')
csv2 = pd.read_csv('csv2.csv')
csv3 = pd.read_csv('csv3.csv')
csv4 = pd.read_csv('csv4.csv')
csv5 = pd.read_csv('csv5.csv')
csv6 = pd.read_csv('csv6.csv')
csv_pov = pd.read_csv('poverty_df.csv')

# %%
csv1['CountryYear'] = csv1['Country']+csv1['Year'].astype(str)
csv2['CountryYear'] = csv2['Country']+csv2['Year'].astype(str)
csv3['CountryYear'] = csv3['Country']+csv3['Year'].astype(str)
csv4['CountryYear'] = csv4['Country']+csv4['Year'].astype(str)
csv5['CountryYear'] = csv5['Country']+csv5['Year'].astype(str)
csv6['CountryYear'] = csv6['Country']+csv6['Year'].astype(str)

# %%
csv_12 = pd.merge(csv1,csv2,on='CountryYear',how='outer')
csv_123 = pd.merge(csv_12,csv3,on='CountryYear',how='outer')
csv_1234 = pd.merge(csv_123,csv4,on='CountryYear',how='outer')
csv_12345 = pd.merge(csv_1234,csv5,on='CountryYear',how='outer')
csv_full = pd.merge(csv_12345,csv6,on='CountryYear',how='outer')
# Out:
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_42674/2404285424.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Year_x', 'ContinentCode_x', 'Code_x', 'Country_x'} in the result is deprecated and will raise a MergeError in a future version.
#   csv_1234 = pd.merge(csv_123,csv4,on='CountryYear',how='outer')
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_42674/2404285424.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Year_x', 'ContinentCode_x', 'Code_x', 'Country_x'} in the result is deprecated and will raise a MergeError in a future version.
#   csv_full = pd.merge(csv_12345,csv6,on='CountryYear',how='outer')

# %%
csv_full.isna().sum()
# Out:
# Country_x                                                   3796
# Code_x                                                      3796
# ContinentCode_x                                             4716
# Year_x                                                      3796
# Military spending percent of total government spending      8431
#                                                             ...
# State legitimacy index 0 (high) - 10 (low)                  9751
# Human rights and rule of law index 0 (high) - 10 (low)      9750
# Demographic pressures 0 (low) - 10 (high)                   9750
# Refugees and displaced persons index 0 (low) - 10 (high)    9750
# External interventions index 0 (low) - 10 (high)            9750
# Length: 114, dtype: int64

# %%
conflicts = pd.read_csv('./conflict_data/conflict_data_1970.csv')

# %%
def get_year(row):
    
    year_value = row['CountryYear'][-4:]
    
    return int(year_value)

# %%
def get_country(row):
    
    country_name = row['CountryYear'][:-4]

    return country_name

# %%
def get_code(row):
    
    code_value = row['CountryYear'][-4:]
    
    return int(year_value)

# %%
csv_full['year_all'] = csv_full.apply(lambda x: get_year(x),axis=1)

# %%
csv_full['country_all'] = csv_full.apply(lambda x: get_country(x), axis=1)

# %%
csv_full['conflict_id'] =0
conflicts

csv_full[(csv_full['country_all']=='USA') & (csv_full['year_all']>1994)]

conflicts_1990 = conflicts[conflicts['Year']>1989]

# %%
my_list = []

def get_hist_data(country,year,lookback):
    
    early_year = lookback
    hist_data = csv_full[(csv_full['country_all']==country) & (csv_full['year_all'] <= (year -1)) & (csv_full['year_all'] > (year -1 - early_year))]
    while hist_data.shape[0] < lookback:
        early_year += 1
        hist_data = csv_full[(csv_full['country_all']==country) & (csv_full['year_all'] <= (year -1)) & (csv_full['year_all'] > (year -1 - early_year))]
    return hist_data

for index, row in conflicts_1990.iterrows():

    my_list.append(get_hist_data(row['Country'],row['Year'],5))


get_hist_data('USA',2010,10)    
    
len(my_list)
# Out:
# 94

# %%
for i in range(len(my_list)):
    my_list[i]['conflict_id'] = i
# Out:
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_42674/729059741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_list[i]['conflict_id'] = i

# %%
for i in range(len(my_list)):
    if len(my_list[i]) < 5:
        print(i)

# %%
final_df = pd.DataFrame(columns=my_list[50].columns)

# %%
final_df
# Out:
# Empty DataFrame
# Columns: [Country_x, Code_x, ContinentCode_x, Year_x, Military spending percent of total government spending , Arms imports million constant U.S. dollars, Cost of living index world average = 100, Food price index world average = 100, Housing and utilities price index world average  = 100, Healthcare price index world average = 100, Happiness Index 0 (unhappy) - 10 (happy), Human Development Index (0 - 1), CountryYear, Country_y, Code_y, ContinentCode_y, Year_y, Economic growth: the rate of change of real GDP, GDP per capita current U.S. dollars, GDP per capita Purchasing Power Parity, Capital investment as percent of GDP, Inflation: percent change in the Consumer Price Index, Unemployment rate, Youth unemployment ages 15-24, Labor force participation rate, Trade openness: exports plus imports as percent of GDP, Foreign Direct Investment percent of GDP, Trade balance as percent of GDP, External debt percent of Gross National Income, Government spending as percent of GDP, Fiscal balance percent of GDP, Government debt as percent of GDP, Foreign aid and official development assistance received, Country_x, Code_x, ContinentCode_x, Year_x, Rule of law index (-2.5 weak; 2.5 strong), Government effectiveness index (-2.5 weak; 2.5 strong), Control of corruption (-2.5 weak; 2.5 strong), Regulatory quality index (-2.5 weak; 2.5 strong), Voice and accountability index (-2.5 weak; 2.5 strong), Political stability index (-2.5 weak; 2.5 strong), Corruption Perceptions Index 100 = no corruption, Political rights index 7 (weak) - 1 (strong), Civil liberties index 7 (weak) - 1 (strong) , Shadow economy percent of GDP, Internet users percent of population, Mobile network coverage percent of the population, Gasoline prices at the pump in dollars per liter, Diesel prices at the pump in dollars per liter, Income from natural resources percent of GDP, Access to electricity percent of the population, Country_y, Code_y, ContinentCode_y, Year_y, Food production index (2004-2006 = 100), Banking system z-scores, Real interest rate: Bank lending rate minus inflation, Freedom from corruption index (0-100), Labor freedom index (0-100), Economic freedom overall index (0-100), Population size in millions, Rural population percent of total population, Refugee population, Migrant population percent of total population, Population growth percent, Life expectancy in years, Death rate per 1000 people, Suicide mortality rate per 100000 population, Country_x, Code_x, ContinentCode_x, Year_x, Deaths of children under five years of age per 1000 live births, Doctors per 1000 people, Gini income inequality index, Poverty percent of population, Poverty ratio percent living on less than 1.90 USD a day, Poverty ratio percent living on less than 5.50 USD a day, Percent income earned by the top 10 percent of earners, Public spending on education percent of GDP, Literacy rate, Globalization index (0-100), Economic globalization index (0-100), Political globalization index (0-100), Social globalization index (0-100), Number of prisoners per 100000 people, Homicides per 100000 people, Country_y, Code_y, ContinentCode_y, Year_y, People practicing Judaism as percent of the population, Buddhists as percent of the total population, People practicing Hinduism as percent of the population, Shia Muslims as percent of the total population, Sunni Muslims as percent of the total population, Christians as percent of the total population, ...]
# Index: []
#
# [0 rows x 117 columns]

# %%
for i in range(len(my_list)):
    
    final_df = pd.concat([final_df,my_list[i]])

# %%
final_df.shape
# Out:
# (470, 117)

# %%
final_df
# Out:
#         Country_x Code_x ContinentCode_x  Year_x  \
# 6643       Rwanda    RWA              AF  1985.0
# 6644       Rwanda    RWA              AF  1986.0
# 6645       Rwanda    RWA              AF  1988.0
# 10638         NaN    NaN             NaN     NaN
# 10639         NaN    NaN             NaN     NaN
# ...           ...    ...             ...     ...
# 4163   Kazakhstan    KAZ              AS  2017.0
# 4164   Kazakhstan    KAZ              AS  2018.0
# 4165   Kazakhstan    KAZ              AS  2019.0
# 4166   Kazakhstan    KAZ              AS  2020.0
# 4167   Kazakhstan    KAZ              AS  2021.0
#
#        Military spending percent of total government spending   \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                3.45
# 4164                                                4.65
# 4165                                                5.25
# 4166                                                4.56
# 4167                                                 NaN
#
#        Arms imports million constant U.S. dollars  \
# 6643                                          3.0
# 6644                                          2.0
# 6645                                          2.0
# 10638                                         NaN
# 10639                                         NaN
# ...                                           ...
# 4163                                        214.0
# 4164                                        310.0
# 4165                                        312.0
# 4166                                        268.0
# 4167                                          NaN
#
#        Cost of living index world average = 100  \
# 6643                                        NaN
# 6644                                        NaN
# 6645                                        NaN
# 10638                                       NaN
# 10639                                       NaN
# ...                                         ...
# 4163                                      55.08
# 4164                                        NaN
# 4165                                        NaN
# 4166                                        NaN
# 4167                                        NaN
#
#        Food price index world average = 100  \
# 6643                                    NaN
# 6644                                    NaN
# 6645                                    NaN
# 10638                                   NaN
# 10639                                   NaN
# ...                                     ...
# 4163                                  70.57
# 4164                                    NaN
# 4165                                    NaN
# 4166                                    NaN
# 4167                                    NaN
#
#        Housing and utilities price index world average  = 100  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                              63.413
# 4164                                                 NaN
# 4165                                                 NaN
# 4166                                                 NaN
# 4167                                                 NaN
#
#        Healthcare price index world average = 100  ...  \
# 6643                                          NaN  ...
# 6644                                          NaN  ...
# 6645                                          NaN  ...
# 10638                                         NaN  ...
# 10639                                         NaN  ...
# ...                                           ...  ...
# 4163                                        30.55  ...
# 4164                                          NaN  ...
# 4165                                          NaN  ...
# 4166                                          NaN  ...
# 4167                                          NaN  ...
#
#        Economic decline index 0 (low) - 10 (high)  \
# 6643                                          NaN
# 6644                                          NaN
# 6645                                          NaN
# 10638                                         NaN
# 10639                                         NaN
# ...                                           ...
# 4163                                          6.4
# 4164                                          5.9
# 4165                                          5.6
# 4166                                          5.3
# 4167                                          5.5
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 4.2
# 4164                                                 3.9
# 4165                                                 3.6
# 4166                                                 3.3
# 4167                                                 3.2
#
#       State legitimacy index 0 (high) - 10 (low)  \
# 6643                                         NaN
# 6644                                         NaN
# 6645                                         NaN
# 10638                                        NaN
# 10639                                        NaN
# ...                                          ...
# 4163                                         8.3
# 4164                                         8.4
# 4165                                         8.5
# 4166                                         8.5
# 4167                                         8.2
#
#       Human rights and rule of law index 0 (high) - 10 (low)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 7.3
# 4164                                                 7.0
# 4165                                                 6.7
# 4166                                                 6.4
# 4167                                                 6.7
#
#       Demographic pressures 0 (low) - 10 (high)  \
# 6643                                        NaN
# 6644                                        NaN
# 6645                                        NaN
# 10638                                       NaN
# 10639                                       NaN
# ...                                         ...
# 4163                                        4.5
# 4164                                        4.2
# 4165                                        3.9
# 4166                                        3.6
# 4167                                        4.1
#
#       Refugees and displaced persons index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 3.0
# 4164                                                 2.7
# 4165                                                 2.4
# 4166                                                 2.3
# 4167                                                 2.1
#
#        External interventions index 0 (low) - 10 (high)  year_all  \
# 6643                                                NaN      1985
# 6644                                                NaN      1986
# 6645                                                NaN      1988
# 10638                                               NaN      1987
# 10639                                               NaN      1989
# ...                                                 ...       ...
# 4163                                                4.2      2017
# 4164                                                3.9      2018
# 4165                                                3.6      2019
# 4166                                                3.3      2020
# 4167                                                3.0      2021
#
#        country_all  conflict_id
# 6643        Rwanda            0
# 6644        Rwanda            0
# 6645        Rwanda            0
# 10638       Rwanda            0
# 10639       Rwanda            0
# ...            ...          ...
# 4163    Kazakhstan           93
# 4164    Kazakhstan           93
# 4165    Kazakhstan           93
# 4166    Kazakhstan           93
# 4167    Kazakhstan           93
#
# [470 rows x 117 columns]

# %% [markdown]
# # Dropping features

# %%
final_df.shape
# Out:
# (470, 117)

# %%
to_drop  = pd.DataFrame(final_df.isna().sum()/470)
len(to_drop)
# Out:
# 117

# %%
to_drop_list = to_drop[to_drop[0]>0.7].index.values.tolist()
len(to_drop_list)
# Out:
# 26

# %%
for i in to_drop_list:
    final_df.drop(columns=i, axis=1, inplace=True)

# %%
final_df['CountryYear']
# Out:
# 6643         Rwanda1985
# 6644         Rwanda1986
# 6645         Rwanda1988
# 10638        Rwanda1987
# 10639        Rwanda1989
#               ...
# 4163     Kazakhstan2017
# 4164     Kazakhstan2018
# 4165     Kazakhstan2019
# 4166     Kazakhstan2020
# 4167     Kazakhstan2021
# Name: CountryYear, Length: 470, dtype: object

# %% [markdown]
# # Dropping data for the imputer

# %%
bin_list = ['Country_x','Code_x','Country_y','Year_x','Year_y','Code_y','ContinentCode_y','ContinentCode_x','Christians as percent of the total population']
final_df.head()
# Out:
#       Country_x Code_x ContinentCode_x  Year_x  \
# 6643     Rwanda    RWA              AF  1985.0
# 6644     Rwanda    RWA              AF  1986.0
# 6645     Rwanda    RWA              AF  1988.0
# 10638       NaN    NaN             NaN     NaN
# 10639       NaN    NaN             NaN     NaN
#
#        Military spending percent of total government spending   \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
#
#        Arms imports million constant U.S. dollars  \
# 6643                                          3.0
# 6644                                          2.0
# 6645                                          2.0
# 10638                                         NaN
# 10639                                         NaN
#
#        Human Development Index (0 - 1) CountryYear Country_y Code_y  ...  \
# 6643                               NaN  Rwanda1985    Rwanda    RWA  ...
# 6644                               NaN  Rwanda1986    Rwanda    RWA  ...
# 6645                               NaN  Rwanda1988    Rwanda    RWA  ...
# 10638                              NaN  Rwanda1987    Rwanda    RWA  ...
# 10639                              NaN  Rwanda1989    Rwanda    RWA  ...
#
#       Economic decline index 0 (low) - 10 (high)  \
# 6643                                         NaN
# 6644                                         NaN
# 6645                                         NaN
# 10638                                        NaN
# 10639                                        NaN
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
#
#        State legitimacy index 0 (high) - 10 (low)  \
# 6643                                          NaN
# 6644                                          NaN
# 6645                                          NaN
# 10638                                         NaN
# 10639                                         NaN
#
#        Human rights and rule of law index 0 (high) - 10 (low)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
#
#        Demographic pressures 0 (low) - 10 (high)  \
# 6643                                         NaN
# 6644                                         NaN
# 6645                                         NaN
# 10638                                        NaN
# 10639                                        NaN
#
#        Refugees and displaced persons index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
#
#        External interventions index 0 (low) - 10 (high)  year_all  \
# 6643                                                NaN      1985
# 6644                                                NaN      1986
# 6645                                                NaN      1988
# 10638                                               NaN      1987
# 10639                                               NaN      1989
#
#        country_all  conflict_id
# 6643        Rwanda            0
# 6644        Rwanda            0
# 6645        Rwanda            0
# 10638       Rwanda            0
# 10639       Rwanda            0
#
# [5 rows x 91 columns]

# %%
cleaner_df = final_df.drop(columns=bin_list)

# %%
cleaner_df['conflict_id']=cleaner_df['conflict_id'].astype(int)

# %%
cleaner_df
# Out:
#        Military spending percent of total government spending   \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                3.45
# 4164                                                4.65
# 4165                                                5.25
# 4166                                                4.56
# 4167                                                 NaN
#
#        Arms imports million constant U.S. dollars  \
# 6643                                          3.0
# 6644                                          2.0
# 6645                                          2.0
# 10638                                         NaN
# 10639                                         NaN
# ...                                           ...
# 4163                                        214.0
# 4164                                        310.0
# 4165                                        312.0
# 4166                                        268.0
# 4167                                          NaN
#
#        Human Development Index (0 - 1)     CountryYear  \
# 6643                               NaN      Rwanda1985
# 6644                               NaN      Rwanda1986
# 6645                               NaN      Rwanda1988
# 10638                              NaN      Rwanda1987
# 10639                              NaN      Rwanda1989
# ...                                ...             ...
# 4163                             0.813  Kazakhstan2017
# 4164                             0.817  Kazakhstan2018
# 4165                             0.817  Kazakhstan2019
# 4166                             0.825  Kazakhstan2020
# 4167                               NaN  Kazakhstan2021
#
#        Economic growth: the rate of change of real GDP  \
# 6643                                              4.40
# 6644                                              5.47
# 6645                                              4.50
# 10638                                            -0.02
# 10639                                            -0.04
# ...                                                ...
# 4163                                              4.10
# 4164                                              4.10
# 4165                                              4.50
# 4166                                             -2.50
# 4167                                              4.00
#
#        GDP per capita current U.S. dollars  \
# 6643                                279.10
# 6644                                301.80
# 6645                                337.96
# 10638                               318.21
# 10639                               330.50
# ...                                    ...
# 4163                               9247.58
# 4164                               9812.63
# 4165                               9812.60
# 4166                               9121.64
# 4167                              10041.49
#
#        GDP per capita Purchasing Power Parity  \
# 6643                                      NaN
# 6644                                      NaN
# 6645                                      NaN
# 10638                                     NaN
# 10639                                     NaN
# ...                                       ...
# 4163                                 24862.97
# 4164                                 25544.35
# 4165                                 26351.80
# 4166                                 25361.51
# 4167                                 26033.24
#
#        Capital investment as percent of GDP  \
# 6643                                  17.31
# 6644                                  15.87
# 6645                                  14.49
# 10638                                 15.66
# 10639                                 13.43
# ...                                     ...
# 4163                                  26.35
# 4164                                  25.26
# 4165                                  27.63
# 4166                                  28.52
# 4167                                    NaN
#
#        Inflation: percent change in the Consumer Price Index  \
# 6643                                                 1.8
# 6644                                                -1.1
# 6645                                                 3.0
# 10638                                                4.1
# 10639                                                1.0
# ...                                                  ...
# 4163                                                 7.4
# 4164                                                 6.0
# 4165                                                 5.2
# 4166                                                 6.7
# 4167                                                 NaN
#
#        Unemployment rate  ...  Economic decline index 0 (low) - 10 (high)  \
# 6643                 NaN  ...                                         NaN
# 6644                 NaN  ...                                         NaN
# 6645                 NaN  ...                                         NaN
# 10638                NaN  ...                                         NaN
# 10639                NaN  ...                                         NaN
# ...                  ...  ...                                         ...
# 4163                4.90  ...                                         6.4
# 4164                4.85  ...                                         5.9
# 4165                4.80  ...                                         5.6
# 4166                4.89  ...                                         5.3
# 4167                4.90  ...                                         5.5
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 4.2
# 4164                                                 3.9
# 4165                                                 3.6
# 4166                                                 3.3
# 4167                                                 3.2
#
#        State legitimacy index 0 (high) - 10 (low)  \
# 6643                                          NaN
# 6644                                          NaN
# 6645                                          NaN
# 10638                                         NaN
# 10639                                         NaN
# ...                                           ...
# 4163                                          8.3
# 4164                                          8.4
# 4165                                          8.5
# 4166                                          8.5
# 4167                                          8.2
#
#        Human rights and rule of law index 0 (high) - 10 (low)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 7.3
# 4164                                                 7.0
# 4165                                                 6.7
# 4166                                                 6.4
# 4167                                                 6.7
#
#        Demographic pressures 0 (low) - 10 (high)  \
# 6643                                         NaN
# 6644                                         NaN
# 6645                                         NaN
# 10638                                        NaN
# 10639                                        NaN
# ...                                          ...
# 4163                                         4.5
# 4164                                         4.2
# 4165                                         3.9
# 4166                                         3.6
# 4167                                         4.1
#
#        Refugees and displaced persons index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 3.0
# 4164                                                 2.7
# 4165                                                 2.4
# 4166                                                 2.3
# 4167                                                 2.1
#
#        External interventions index 0 (low) - 10 (high)  year_all  \
# 6643                                                NaN      1985
# 6644                                                NaN      1986
# 6645                                                NaN      1988
# 10638                                               NaN      1987
# 10639                                               NaN      1989
# ...                                                 ...       ...
# 4163                                                4.2      2017
# 4164                                                3.9      2018
# 4165                                                3.6      2019
# 4166                                                3.3      2020
# 4167                                                3.0      2021
#
#        country_all  conflict_id
# 6643        Rwanda            0
# 6644        Rwanda            0
# 6645        Rwanda            0
# 10638       Rwanda            0
# 10639       Rwanda            0
# ...            ...          ...
# 4163    Kazakhstan           93
# 4164    Kazakhstan           93
# 4165    Kazakhstan           93
# 4166    Kazakhstan           93
# 4167    Kazakhstan           93
#
# [470 rows x 66 columns]

# %% [markdown]
# # Grouping the data

# %%
grouped_df = cleaner_df.groupby(by='conflict_id').mean()
# Out:
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_42674/2490057627.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = cleaner_df.groupby(by='conflict_id').mean()

# %%
grouped_df.columns
# Out:
# Index(['Military spending percent of total government spending ',
#        'Arms imports million constant U.S. dollars',
#        'Human Development Index (0 - 1)',
#        'Economic growth: the rate of change of real GDP',
#        'GDP per capita current U.S. dollars',
#        'GDP per capita Purchasing Power Parity',
#        'Capital investment as percent of GDP',
#        'Inflation: percent change in the Consumer Price Index',
#        'Unemployment rate', 'Youth unemployment ages 15-24',
#        'Labor force participation rate',
#        'Trade openness: exports plus imports as percent of GDP',
#        'Foreign Direct Investment percent of GDP',
#        'Trade balance as percent of GDP',
#        'External debt percent of Gross National Income',
#        'Government spending as percent of GDP',
#        'Fiscal balance percent of GDP', 'Government debt as percent of GDP',
#        'Foreign aid and official development assistance received',
#        'Rule of law index (-2.5 weak; 2.5 strong)',
#        'Government effectiveness index (-2.5 weak; 2.5 strong)',
#        'Control of corruption (-2.5 weak; 2.5 strong)',
#        'Regulatory quality index (-2.5 weak; 2.5 strong)',
#        'Voice and accountability index (-2.5 weak; 2.5 strong)',
#        'Political stability index (-2.5 weak; 2.5 strong)',
#        'Corruption Perceptions Index 100 = no corruption',
#        'Political rights index 7 (weak) - 1 (strong)',
#        'Civil liberties index 7 (weak) - 1 (strong) ',
#        'Shadow economy percent of GDP', 'Internet users percent of population',
#        'Income from natural resources percent of GDP',
#        'Access to electricity percent of the population',
#        'Food production index (2004-2006 = 100)', 'Banking system z-scores',
#        'Real interest rate: Bank lending rate minus inflation',
#        'Freedom from corruption index (0-100)', 'Labor freedom index (0-100)',
#        'Economic freedom overall index (0-100)', 'Population size in millions',
#        'Rural population percent of total population', 'Refugee population',
#        'Population growth percent', 'Life expectancy in years',
#        'Death rate per 1000 people',
#        'Suicide mortality rate per 100000 population',
#        'Deaths of children under five years of age per 1000 live births',
#        'Public spending on education percent of GDP',
#        'Globalization index (0-100)', 'Economic globalization index (0-100)',
#        'Political globalization index (0-100)',
#        'Social globalization index (0-100)', 'Homicides per 100000 people',
#        'Security threats index 0 (low) - 10 (high)',
#        'Factionalized elites index 0 (low) - 10 (high)',
#        'Group grievance index 0 (low) - 10 (high)',
#        'Economic decline index 0 (low) - 10 (high)',
#        'Uneven economic development index 0 (low) - 10 (high)',
#        'State legitimacy index 0 (high) - 10 (low)',
#        'Human rights and rule of law index 0 (high) - 10 (low)',
#        'Demographic pressures 0 (low) - 10 (high)',
#        'Refugees and displaced persons index 0 (low) - 10 (high)',
#        'External interventions index 0 (low) - 10 (high)'],
#       dtype='object')

# %% [markdown]
# # Create the control dataset

# %%
conflict_years = final_df['CountryYear']

# %%
csv4_after_1980 = csv_full[csv_full['year_all'] > 1985]
csv4_after_1980_noconflict = csv4_after_1980[csv4_after_1980.CountryYear.isin(conflict_years)==False]
csv4_after_1980.shape[0] - csv4_after_1980_noconflict.shape[0]
# Out:
# 437

# %%
def slice_fn(sample):
    year = int(sample[-4:])
    words = [sample[:-4]+str(year-i-1) for i in range(4)]
    words.append(sample)
    return words

# %%
from itertools import chain

sample_list = []

control_sample = csv4_after_1980.sample(270)

for index,row in control_sample.iterrows():
    sample_list.append(get_hist_data(row['country_all'],row['year_all'],5))

sample_full = sample_list[0]

for i in range(1,len(sample_list)):
    
    sample_full = pd.concat([sample_full,sample_list[i]])

# %%
id_list = list(range(95,365))*5

# %%
id_list = sorted(id_list)

# %%
sample_full['conflict_id'] = id_list
sample_full['country_all'].unique()
# Out:
# array(['Somalia', 'Uganda', 'Malaysia', 'Denmark', 'Bangladesh',
#        'Honduras', 'Benin', 'Montserrat', 'Bhutan', 'Mexico', 'Czechia',
#        'Croatia', 'Taiwan', 'Sierra Leone', 'Colombia', 'Andorra',
#        'Rwanda', 'Fiji', 'Netherlands', 'Kyrgyzstan', 'Burkina Faso',
#        'Tajikistan', 'Turkmenistan', 'Georgia',
#        'Democratic Republic of the Congo', 'Moldova', 'Syria',
#        'Montenegro', 'China', 'Kenya', 'Lebanon', 'Hungary', 'Armenia',
#        'Swaziland', 'Equatorial Guinea', 'Comoros', 'Israel', 'Malawi',
#        'Tanzania', 'Tunisia', 'Tuvalu', 'Guinea', 'Sweden', 'Brunei',
#        'Kiribati', 'Austria', 'Philippines', 'Belize', 'Uzbekistan',
#        'Mauritius', 'Faroe Islands', 'Ireland', 'Panama', 'South Korea',
#        'Laos', 'Liberia', 'Bulgaria', 'USA', 'Barbados', 'Kazakhstan',
#        'Vanuatu', 'Serbia', 'Japan', 'Madagascar', 'Iran', 'Suriname',
#        'Cambodia', 'Australia', 'New Zealand', 'Bermuda', 'Mali',
#        'Cyprus', 'Lesotho', 'Sudan', 'Gabon', 'Morocco', 'Mozambique',
#        'Greece', 'Germany', 'Gibraltar', 'Nepal', 'Latvia', 'Eritrea',
#        'Cuba', 'Portugal', 'Ethiopia', 'Algeria', 'Romania', 'Spain',
#        'Ivory Coast', 'Bosnia and Herzegovina', 'United Arab Emirates',
#        'Nigeria', 'Thailand', 'Bahamas', 'North Korea', 'Costa Rica',
#        'Brazil', 'Egypt', 'Bahrain', 'Chad', 'El Salvador', 'Singapore',
#        'Belgium', 'Maldives', 'Dominica', 'Malta', 'Togo', 'Saudi Arabia',
#        'Cameroon', 'Burundi', 'Bolivia', 'Iraq', 'Grenada', 'Cape Verde',
#        'Turkey', 'Slovenia', 'Jamaica', 'Azerbaijan', 'Yemen',
#        'Seychelles', 'Indonesia', 'Euro area', 'Puerto Rico', 'Djibouti',
#        'Jordan', 'Tonga', 'Guyana', 'Norway', 'Republic of the Congo',
#        'Albania', 'Kuwait', 'India', 'Micronesia', 'Mongolia', 'Estonia',
#        'Solomon Islands', 'Macao', 'Dominican Republic', 'Belarus',
#        'Uruguay', 'Central African Republic', 'Haiti', 'Niger', 'Gambia',
#        'Qatar', 'Luxembourg', 'United Kingdom', 'Burma (Myanmar)',
#        'Aruba', 'Chile'], dtype=object)

# %%
control_groupedby = sample_full.groupby('conflict_id').mean()
# Out:
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_42674/3478027142.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   control_groupedby = sample_full.groupby('conflict_id').mean()

# %%
columns_to_keep = list(grouped_df.columns)

# %%
sample_full_clean = control_groupedby.drop(columns=[col for col in control_groupedby if col not in columns_to_keep])

sample_full_clean.isna().sum()

sample_full_clean
# Out:
#              Military spending percent of total government spending   \
# conflict_id
# 95                                                         NaN
# 96                                                         NaN
# 97                                                       6.700
# 98                                                         NaN
# 99                                                      11.056
# ...                                                        ...
# 360                                                      8.190
# 361                                                        NaN
# 362                                                     10.130
# 363                                                        NaN
# 364                                                        NaN
#
#              Arms imports million constant U.S. dollars  \
# conflict_id
# 95                                                  NaN
# 96                                                 15.5
# 97                                                669.8
# 98                                                193.6
# 99                                                 96.8
# ...                                                 ...
# 360                                                88.2
# 361                                                 NaN
# 362                                                 6.0
# 363                                                 NaN
# 364                                                 NaN
#
#              Human Development Index (0 - 1)  \
# conflict_id
# 95                                       NaN
# 96                                       NaN
# 97                                    0.7580
# 98                                       NaN
# 99                                    0.4032
# ...                                      ...
# 360                                   0.8328
# 361                                   0.4260
# 362                                   0.4875
# 363                                   0.6850
# 364                                      NaN
#
#              Economic growth: the rate of change of real GDP  \
# conflict_id
# 95                                                       NaN
# 96                                                     3.134
# 97                                                     4.524
# 98                                                     3.870
# 99                                                     4.630
# ...                                                      ...
# 360                                                    3.032
# 361                                                    0.810
# 362                                                    5.630
# 363                                                   -8.150
# 364                                                   -0.232
#
#              GDP per capita current U.S. dollars  \
# conflict_id
# 95                                           NaN
# 96                                    324.138000
# 97                                   7652.050000
# 98                                  12935.886000
# 99                                    298.632000
# ...                                          ...
# 360                                 14585.064000
# 361                                   319.332000
# 362                                   318.446000
# 363                                  1559.373333
# 364                                  1428.038000
#
#              GDP per capita Purchasing Power Parity  \
# conflict_id
# 95                                              NaN
# 96                                              NaN
# 97                                     19676.476000
# 98                                              NaN
# 99                                      1871.876000
# ...                                             ...
# 360                                    24035.110000
# 361                                     1719.600000
# 362                                     1367.280000
# 363                                    12229.363333
# 364                                     2919.840000
#
#              Capital investment as percent of GDP  \
# conflict_id
# 95                                            NaN
# 96                                          9.766
# 97                                         21.760
# 98                                         20.622
# 99                                         17.404
# ...                                           ...
# 360                                        26.152
# 361                                        15.682
# 362                                           NaN
# 363                                        31.510
# 364                                        18.788
#
#              Inflation: percent change in the Consumer Price Index  \
# conflict_id
# 95                                                         NaN
# 96                                                         NaN
# 97                                                        2.64
# 98                                                        6.34
# 99                                                        4.88
# ...                                                        ...
# 360                                                       3.52
# 361                                                       1.96
# 362                                                      13.46
# 363                                                        NaN
# 364                                                       2.68
#
#              Unemployment rate  Youth unemployment ages 15-24  ...  \
# conflict_id                                                    ...
# 95                     19.2000                         33.162  ...
# 96                         NaN                            NaN  ...
# 97                      3.3820                         11.046  ...
# 98                         NaN                            NaN  ...
# 99                      2.3175                          5.790  ...
# ...                        ...                            ...  ...
# 360                     6.5560                         16.462  ...
# 361                     3.9780                          7.204  ...
# 362                    36.1200                         47.820  ...
# 363                     0.9500                          1.845  ...
# 364                     1.8060                          4.206  ...
#
#              Security threats index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                  NaN
# 96                                                  NaN
# 97                                                 6.15
# 98                                                  NaN
# 99                                                  NaN
# ...                                                 ...
# 360                                                2.90
# 361                                                 NaN
# 362                                                 NaN
# 363                                                 NaN
# 364                                                 NaN
#
#              Factionalized elites index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                      NaN
# 96                                                      NaN
# 97                                                     5.85
# 98                                                      NaN
# 99                                                      NaN
# ...                                                     ...
# 360                                                    1.68
# 361                                                     NaN
# 362                                                     NaN
# 363                                                     NaN
# 364                                                     NaN
#
#              Group grievance index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                 NaN
# 96                                                 NaN
# 97                                                6.05
# 98                                                 NaN
# 99                                                 NaN
# ...                                                ...
# 360                                               3.80
# 361                                                NaN
# 362                                                NaN
# 363                                                NaN
# 364                                                NaN
#
#              Economic decline index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                  NaN
# 96                                                  NaN
# 97                                                 4.65
# 98                                                  NaN
# 99                                                  NaN
# ...                                                 ...
# 360                                                3.90
# 361                                                 NaN
# 362                                                 NaN
# 363                                                 NaN
# 364                                                 NaN
#
#              Uneven economic development index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                         NaN
# 96                                                         NaN
# 97                                                        6.85
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                       5.38
# 361                                                        NaN
# 362                                                        NaN
# 363                                                        NaN
# 364                                                        NaN
#
#              State legitimacy index 0 (high) - 10 (low)  \
# conflict_id
# 95                                                  NaN
# 96                                                  NaN
# 97                                                 5.95
# 98                                                  NaN
# 99                                                  NaN
# ...                                                 ...
# 360                                                3.46
# 361                                                 NaN
# 362                                                 NaN
# 363                                                 NaN
# 364                                                 NaN
#
#              Human rights and rule of law index 0 (high) - 10 (low)  \
# conflict_id
# 95                                                         NaN
# 96                                                         NaN
# 97                                                       6.575
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                      3.400
# 361                                                        NaN
# 362                                                        NaN
# 363                                                        NaN
# 364                                                        NaN
#
#              Demographic pressures 0 (low) - 10 (high)  \
# conflict_id
# 95                                                 NaN
# 96                                                 NaN
# 97                                                6.35
# 98                                                 NaN
# 99                                                 NaN
# ...                                                ...
# 360                                               4.92
# 361                                                NaN
# 362                                                NaN
# 363                                                NaN
# 364                                                NaN
#
#              Refugees and displaced persons index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                         NaN
# 96                                                         NaN
# 97                                                       4.825
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                      2.400
# 361                                                        NaN
# 362                                                        NaN
# 363                                                        NaN
# 364                                                        NaN
#
#              External interventions index 0 (low) - 10 (high)
# conflict_id
# 95                                                        NaN
# 96                                                        NaN
# 97                                                       5.65
# 98                                                        NaN
# 99                                                        NaN
# ...                                                       ...
# 360                                                      2.94
# 361                                                       NaN
# 362                                                       NaN
# 363                                                       NaN
# 364                                                       NaN
#
# [270 rows x 62 columns]

# %%
# sample_full_clean

# sara_conflict = pd.read_csv('imputed_final_df.csv',index_col=0)
# sara_control = pd.read_csv('imputed_control.csv')


# test_sara_conflict_ali_control = pd.concat([sara_conflict,imputed_control_df])
# test_sara_control_ali_conflict = pd.concat([imputed_conflict_df,sara_control])

# %% [markdown]
# # Merging dataset and imputing all

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer(max_iter=10, random_state=0, missing_values=np.nan)
imputer2 = IterativeImputer(max_iter=10, random_state=0, missing_values=np.nan)

grouped_df['target'] = 1
sample_full_clean['target'] = 0

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']


full_dataset = pd.concat([grouped_df,sample_full_clean])

# %%
data_numeric = full_dataset.select_dtypes(include=numerics)

imputer.fit(data_numeric)
imputed_final_df = pd.DataFrame(imputer.transform(data_numeric),columns=full_dataset.columns)
imputed_final_df.head()
# Out:
#    Military spending percent of total government spending   \
# 0                                          11.022810
# 1                                           8.454911
# 2                                          10.390000
# 3                                           9.311509
# 4                                           9.304557
#
#    Arms imports million constant U.S. dollars  \
# 0                                    2.333333
# 1                                   16.000000
# 2                                  122.200000
# 3                                    2.000000
# 4                                   97.303528
#
#    Human Development Index (0 - 1)  \
# 0                         0.310879
# 1                         0.367812
# 2                         0.307886
# 3                         0.310354
# 4                         0.631546
#
#    Economic growth: the rate of change of real GDP  \
# 0                                            2.862
# 1                                            3.200
# 2                                            3.308
# 3                                            4.888
# 4                                           -4.666
#
#    GDP per capita current U.S. dollars  \
# 0                              313.514
# 1                              823.864
# 2                              257.922
# 3                              174.638
# 4                             1614.640
#
#    GDP per capita Purchasing Power Parity  \
# 0                            -2946.911335
# 1                             -940.400692
# 2                            -4795.040659
# 3                            -5485.737086
# 4                            11135.460000
#
#    Capital investment as percent of GDP  \
# 0                                15.352
# 1                                13.258
# 2                                15.868
# 3                                21.562
# 4                                29.614
#
#    Inflation: percent change in the Consumer Price Index  Unemployment rate  \
# 0                                           1.760000               9.494638
# 1                                           2.740000               8.672927
# 2                                           7.766667               7.717502
# 3                                          11.140000               8.272512
# 4                                          82.619474               7.048020
#
#    Youth unemployment ages 15-24  ...  \
# 0                      13.466476  ...
# 1                      15.433306  ...
# 2                      12.663662  ...
# 3                      12.451821  ...
# 4                      14.567017  ...
#
#    Factionalized elites index 0 (low) - 10 (high)  \
# 0                                        8.362155
# 1                                        7.775074
# 2                                        8.590521
# 3                                        8.123308
# 4                                        5.671670
#
#    Group grievance index 0 (low) - 10 (high)  \
# 0                                   7.534308
# 1                                   7.446773
# 2                                   8.243813
# 3                                   7.646465
# 4                                   5.431247
#
#    Economic decline index 0 (low) - 10 (high)  \
# 0                                    9.713386
# 1                                    9.102548
# 2                                    9.724656
# 3                                    9.815473
# 4                                    6.210332
#
#    Uneven economic development index 0 (low) - 10 (high)  \
# 0                                           9.026137
# 1                                           8.674804
# 2                                           9.218760
# 3                                           8.844696
# 4                                           7.385429
#
#    State legitimacy index 0 (high) - 10 (low)  \
# 0                                    8.584133
# 1                                    7.031400
# 2                                    7.811634
# 3                                    7.742780
# 4                                    6.871955
#
#    Human rights and rule of law index 0 (high) - 10 (low)  \
# 0                                           8.219773
# 1                                           6.181477
# 2                                           7.409300
# 3                                           6.987679
# 4                                           6.258850
#
#    Demographic pressures 0 (low) - 10 (high)  \
# 0                                   9.887509
# 1                                   9.247226
# 2                                  10.054381
# 3                                   9.501362
# 4                                   7.006003
#
#    Refugees and displaced persons index 0 (low) - 10 (high)  \
# 0                                           8.043133
# 1                                           7.829547
# 2                                           8.952847
# 3                                           7.880250
# 4                                           5.022173
#
#    External interventions index 0 (low) - 10 (high)  target
# 0                                          9.642197     1.0
# 1                                          9.094863     1.0
# 2                                          9.883836     1.0
# 3                                          9.494491     1.0
# 4                                          6.723778     1.0
#
# [5 rows x 63 columns]

# %%
# data_numeric2 = grouped_df.select_dtypes(include=numerics)

# imputed_conflict_df = pd.DataFrame(imputer2.fit_transform(data_numeric2),columns=data_numeric2.columns)
# imputed_control_df = pd.DataFrame(imputer2.fit_transform(sample_full_clean),columns=data_numeric2.columns)
# Out:
# /Users/Ali/.pyenv/versions/3.10.6/envs/conflict_prediction/lib/python3.10/site-packages/sklearn/impute/_iterative.py:713: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
# imputed_control_df

# %%
separate_impute_full_df = pd.concat([imputed_control_df,imputed_conflict_df])
separate_impute_full_df['target'] = separate_impute_full_df['target'].astype(int)
separate_impute_full_df
imputed_final_df
# Out:
#      Military spending percent of total government spending   \
# 0                                            11.022810
# 1                                             8.454911
# 2                                            10.390000
# 3                                             9.311509
# 4                                             9.304557
# ..                                                 ...
# 359                                           8.190000
# 360                                          10.110694
# 361                                          10.130000
# 362                                          15.096690
# 363                                           7.584005
#
#      Arms imports million constant U.S. dollars  \
# 0                                      2.333333
# 1                                     16.000000
# 2                                    122.200000
# 3                                      2.000000
# 4                                     97.303528
# ..                                          ...
# 359                                   88.200000
# 360                                   -6.949607
# 361                                    6.000000
# 362                                  208.367736
# 363                                   37.815257
#
#      Human Development Index (0 - 1)  \
# 0                           0.310879
# 1                           0.367812
# 2                           0.307886
# 3                           0.310354
# 4                           0.631546
# ..                               ...
# 359                         0.832800
# 360                         0.426000
# 361                         0.487500
# 362                         0.685000
# 363                         0.527345
#
#      Economic growth: the rate of change of real GDP  \
# 0                                              2.862
# 1                                              3.200
# 2                                              3.308
# 3                                              4.888
# 4                                             -4.666
# ..                                               ...
# 359                                            3.032
# 360                                            0.810
# 361                                            5.630
# 362                                           -8.150
# 363                                           -0.232
#
#      GDP per capita current U.S. dollars  \
# 0                             313.514000
# 1                             823.864000
# 2                             257.922000
# 3                             174.638000
# 4                            1614.640000
# ..                                   ...
# 359                         14585.064000
# 360                           319.332000
# 361                           318.446000
# 362                          1559.373333
# 363                          1428.038000
#
#      GDP per capita Purchasing Power Parity  \
# 0                              -2946.911335
# 1                               -940.400692
# 2                              -4795.040659
# 3                              -5485.737086
# 4                              11135.460000
# ..                                      ...
# 359                            24035.110000
# 360                             1719.600000
# 361                             1367.280000
# 362                            12229.363333
# 363                             2919.840000
#
#      Capital investment as percent of GDP  \
# 0                               15.352000
# 1                               13.258000
# 2                               15.868000
# 3                               21.562000
# 4                               29.614000
# ..                                    ...
# 359                             26.152000
# 360                             15.682000
# 361                             24.114618
# 362                             31.510000
# 363                             18.788000
#
#      Inflation: percent change in the Consumer Price Index  Unemployment rate  \
# 0                                             1.760000               9.494638
# 1                                             2.740000               8.672927
# 2                                             7.766667               7.717502
# 3                                            11.140000               8.272512
# 4                                            82.619474               7.048020
# ..                                                 ...                    ...
# 359                                           3.520000               6.556000
# 360                                           1.960000               3.978000
# 361                                          13.460000              36.120000
# 362                                         277.222612               0.950000
# 363                                           2.680000               1.806000
#
#      Youth unemployment ages 15-24  ...  \
# 0                        13.466476  ...
# 1                        15.433306  ...
# 2                        12.663662  ...
# 3                        12.451821  ...
# 4                        14.567017  ...
# ..                             ...  ...
# 359                      16.462000  ...
# 360                       7.204000  ...
# 361                      47.820000  ...
# 362                       1.845000  ...
# 363                       4.206000  ...
#
#      Factionalized elites index 0 (low) - 10 (high)  \
# 0                                          8.362155
# 1                                          7.775074
# 2                                          8.590521
# 3                                          8.123308
# 4                                          5.671670
# ..                                              ...
# 359                                        1.680000
# 360                                        8.886464
# 361                                        5.863847
# 362                                        5.963096
# 363                                        5.881826
#
#      Group grievance index 0 (low) - 10 (high)  \
# 0                                     7.534308
# 1                                     7.446773
# 2                                     8.243813
# 3                                     7.646465
# 4                                     5.431247
# ..                                         ...
# 359                                   3.800000
# 360                                   8.002068
# 361                                   5.194049
# 362                                   3.505013
# 363                                   5.655256
#
#      Economic decline index 0 (low) - 10 (high)  \
# 0                                      9.713386
# 1                                      9.102548
# 2                                      9.724656
# 3                                      9.815473
# 4                                      6.210332
# ..                                          ...
# 359                                    3.900000
# 360                                    9.310071
# 361                                    8.160334
# 362                                    6.285873
# 363                                    7.400904
#
#      Uneven economic development index 0 (low) - 10 (high)  \
# 0                                             9.026137
# 1                                             8.674804
# 2                                             9.218760
# 3                                             8.844696
# 4                                             7.385429
# ..                                                 ...
# 359                                           5.380000
# 360                                           8.340478
# 361                                           7.517593
# 362                                           7.230423
# 363                                           7.572784
#
#      State legitimacy index 0 (high) - 10 (low)  \
# 0                                      8.584133
# 1                                      7.031400
# 2                                      7.811634
# 3                                      7.742780
# 4                                      6.871955
# ..                                          ...
# 359                                    3.460000
# 360                                    8.725250
# 361                                    6.792259
# 362                                    8.236399
# 363                                    5.681330
#
#      Human rights and rule of law index 0 (high) - 10 (low)  \
# 0                                             8.219773
# 1                                             6.181477
# 2                                             7.409300
# 3                                             6.987679
# 4                                             6.258850
# ..                                                 ...
# 359                                           3.400000
# 360                                           7.730140
# 361                                           6.461245
# 362                                           8.085678
# 363                                           4.585670
#
#      Demographic pressures 0 (low) - 10 (high)  \
# 0                                     9.887509
# 1                                     9.247226
# 2                                    10.054381
# 3                                     9.501362
# 4                                     7.006003
# ..                                         ...
# 359                                   4.920000
# 360                                   8.969141
# 361                                   8.396800
# 362                                   7.410177
# 363                                   7.624783
#
#      Refugees and displaced persons index 0 (low) - 10 (high)  \
# 0                                             8.043133
# 1                                             7.829547
# 2                                             8.952847
# 3                                             7.880250
# 4                                             5.022173
# ..                                                 ...
# 359                                           2.400000
# 360                                           7.404833
# 361                                           5.741718
# 362                                           4.034611
# 363                                           5.658029
#
#      External interventions index 0 (low) - 10 (high)  target
# 0                                            9.642197     1.0
# 1                                            9.094863     1.0
# 2                                            9.883836     1.0
# 3                                            9.494491     1.0
# 4                                            6.723778     1.0
# ..                                                ...     ...
# 359                                          2.940000     0.0
# 360                                          9.535016     0.0
# 361                                          7.782069     0.0
# 362                                          7.315290     0.0
# 363                                          7.639014     0.0
#
# [364 rows x 63 columns]

# %%
# scaler2 = MinMaxScaler()
# separate_scaled = pd.DataFrame(scaler2.fit_transform(separate_impute_full_df), columns=separate_impute_full_df.columns)

# X2 = separate_scaled.drop(columns=['target'])
# y2 = separate_scaled['target']
# X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2,test_size = 0.3, random_state=5)

# %%
# bst2 = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
# bst2.fit(X_train2, y_train2)

# %%
# preds2 = bst2.predict(X_test2)

# accuracy_score(preds2,y_test2)

# %%
# print(imputed_final_df.shape)
# imputed_final_df.columns

imputed_final_df.describe()
# Out:
#        Military spending percent of total government spending   \
# count                                         364.000000
# mean                                            9.144366
# std                                             5.611811
# min                                             0.000000
# 25%                                             5.139750
# 50%                                             8.757657
# 75%                                            12.008500
# max                                            39.482000
#
#        Arms imports million constant U.S. dollars  \
# count                                  364.000000
# mean                                   201.010159
# std                                    387.788515
# min                                   -144.197539
# 25%                                     10.150000
# 50%                                     71.200000
# 75%                                    206.621967
# max                                   3925.800000
#
#        Human Development Index (0 - 1)  \
# count                       364.000000
# mean                          0.617606
# std                           0.174779
# min                           0.167762
# 25%                           0.474150
# 50%                           0.640100
# 75%                           0.758050
# max                           0.952000
#
#        Economic growth: the rate of change of real GDP  \
# count                                       364.000000
# mean                                          3.519214
# std                                           3.217523
# min                                         -11.480000
# 25%                                           1.778500
# 50%                                           3.450911
# 75%                                           5.130500
# max                                          20.324000
#
#        GDP per capita current U.S. dollars  \
# count                           364.000000
# mean                           7765.762044
# std                           12028.292199
# min                             138.586000
# 25%                             810.061500
# 50%                            2949.189000
# 75%                            9266.704089
# max                           75660.080000
#
#        GDP per capita Purchasing Power Parity  \
# count                              364.000000
# mean                             14409.512777
# std                              16164.134743
# min                              -7414.818628
# 25%                               3071.083500
# 50%                               8860.789584
# 75%                              19430.515000
# max                              89141.308000
#
#        Capital investment as percent of GDP  \
# count                            364.000000
# mean                              24.091745
# std                                7.460230
# min                                0.000000
# 25%                               19.840608
# 50%                               23.515000
# 75%                               28.161000
# max                               54.414000
#
#        Inflation: percent change in the Consumer Price Index  \
# count                                         364.000000
# mean                                           96.182298
# std                                           572.558403
# min                                          -861.761734
# 25%                                             2.542500
# 50%                                             5.920000
# 75%                                            14.995000
# max                                          6517.100000
#
#        Unemployment rate  Youth unemployment ages 15-24  ...  \
# count         364.000000                     364.000000  ...
# mean            8.170407                      16.563017  ...
# std             5.647768                      11.066871  ...
# min             0.380000                       0.545000  ...
# 25%             4.169500                       8.413500  ...
# 50%             7.579159                      15.823674  ...
# 75%            10.140380                      21.088642  ...
# max            36.120000                      78.004000  ...
#
#        Factionalized elites index 0 (low) - 10 (high)  \
# count                                      364.000000
# mean                                         6.313280
# std                                          3.757713
# min                                        -29.367166
# 25%                                          5.289011
# 50%                                          6.988561
# 75%                                          8.246973
# max                                         13.845717
#
#        Group grievance index 0 (low) - 10 (high)  \
# count                                 364.000000
# mean                                    5.717015
# std                                     5.737461
# min                                   -56.348428
# 25%                                     5.095152
# 50%                                     6.186378
# 75%                                     7.780000
# max                                    14.954042
#
#        Economic decline index 0 (low) - 10 (high)  \
# count                                  364.000000
# mean                                     6.369058
# std                                      2.208580
# min                                     -4.910661
# 25%                                      5.140794
# 50%                                      6.508349
# 75%                                      8.090308
# max                                     11.147420
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# count                                         364.000000
# mean                                            6.841726
# std                                             1.940575
# min                                            -7.774708
# 25%                                             6.139557
# 50%                                             7.219435
# 75%                                             8.078244
# max                                            10.262569
#
#        State legitimacy index 0 (high) - 10 (low)  \
# count                                  364.000000
# mean                                     6.771532
# std                                      2.384796
# min                                     -7.874445
# 25%                                      5.834625
# 50%                                      7.150727
# 75%                                      8.364301
# max                                     12.813838
#
#        Human rights and rule of law index 0 (high) - 10 (low)  \
# count                                         364.000000
# mean                                            6.459646
# std                                             2.287478
# min                                            -6.877977
# 25%                                             5.396705
# 50%                                             6.840000
# 75%                                             7.946333
# max                                            12.219182
#
#        Demographic pressures 0 (low) - 10 (high)  \
# count                                 364.000000
# mean                                    6.720072
# std                                     2.539209
# min                                   -12.276979
# 25%                                     5.695000
# 50%                                     7.022650
# 75%                                     8.523333
# max                                    12.602004
#
#        Refugees and displaced persons index 0 (low) - 10 (high)  \
# count                                         364.000000
# mean                                            5.250802
# std                                             3.998376
# min                                           -33.363698
# 25%                                             4.000000
# 50%                                             5.449020
# 75%                                             7.476390
# max                                            12.360515
#
#        External interventions index 0 (low) - 10 (high)      target
# count                                        364.000000  364.000000
# mean                                           6.673497    0.258242
# std                                            2.358672    0.438270
# min                                           -2.035144    0.000000
# 25%                                            5.326427    0.000000
# 50%                                            6.909249    0.000000
# 75%                                            8.324378    1.000000
# max                                           12.120484    1.000000
#
# [8 rows x 63 columns]

# %% [markdown]
# # Scaler on whole dataset

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
full_dataset_scaled = pd.DataFrame(scaler.fit_transform(imputed_final_df), columns=imputed_final_df.columns)

# %% [markdown]
# # LET'S MODEL

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV


X = full_dataset_scaled.drop(columns=['target'])
y = full_dataset_scaled['target']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state=5)

# %%
y_train.value_counts()
# Out:
# 0.0    191
# 1.0     63
# Name: target, dtype: int64

# %%
bst = XGBClassifier(n_estimators=100,max_depth=30,learning_rate=1, 
                    objective='binary:logistic')

# %%
bst.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=30, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
preds = bst.predict(X_test)

accuracy_score(preds,y_test)
bst.predict_proba(X_test)
accuracy_score(preds,y_test)
# Out:
# 0.6636363636363637

# %%
import pandas as pd

features = bst.get_booster().feature_names
importances = bst.feature_importances_
feature_importances_df = pd.DataFrame(zip(features, importances), columns=['feature', 'importance']).set_index('feature')
feature_importances_df.sort_values('importance', ascending=False).head(10)
# Out:
#                                                    importance
# feature
# Civil liberties index 7 (weak) - 1 (strong)          0.148449
# External interventions index 0 (low) - 10 (high)     0.068990
# Rule of law index (-2.5 weak; 2.5 strong)            0.059072
# Government spending as percent of GDP                0.047661
# Foreign Direct Investment percent of GDP             0.047010
# Control of corruption (-2.5 weak; 2.5 strong)        0.042909
# Refugee population                                   0.039871
# Political stability index (-2.5 weak; 2.5 strong)    0.029803
# Corruption Perceptions Index 100 = no corruption     0.028450
# Labor force participation rate                       0.026170

# %%
def get_imputed_df(country,year,lookback=5):
    df = get_hist_data(country,year,lookback).groupby('country_all').mean(numeric_only=True)
    df.drop(columns=[col for col in df if col not in columns_to_keep],inplace=True)
    df['target'] = 0.5
    imputed_df = pd.DataFrame(imputer.transform(df),columns=df.columns)
    imputed_df.drop(columns='target',inplace=True)
    
    
    return imputed_df




def get_prob(country,year,lookback=5):
    
    prob = bst.predict_proba(get_imputed_df(country,year,lookback))[0][1]
    return prob

def prob_series(country,start_year,end_year,lookback=5):
    my_list =[]
    for year in range(start_year,end_year+1):
        my_list.append(get_prob(country,year,lookback))
    return my_list

# NEXT STEPS:
#     - FINE TUNE MODEL PARAMS WITH GRID SEARCH / FEATURE SET TO IMPROVE PERFORMANCE 
#     - DELETE FEATURES SO LESS IMPUTATION/SOME ACTUAL TIME PROGRESS
#     - MORE STREAMLIT/START PUTTING PRESENTATION TOGETHER
#     - TRY GET GRAPH WORKING
#     - LOOK AT OTHER METRICS FOR MODEL - RECALL AND PRECISION
# AUTOML For hyperparams
# delete pre 1990 data
# add more non conflicts.. 1:3 or 1:4 - but be sure to look at recall and precision as well

    
prob_series('USA',1990,2020)
get_imputed_df('Iran',2019)
# Out:
#    Military spending percent of total government spending   \
# 0                                             15.084
#
#    Arms imports million constant U.S. dollars  \
# 0                                        89.4
#
#    Human Development Index (0 - 1)  \
# 0                           0.7944
#
#    Economic growth: the rate of change of real GDP  \
# 0                                            2.578
#
#    GDP per capita current U.S. dollars  \
# 0                             5395.586
#
#    GDP per capita Purchasing Power Parity  \
# 0                                15294.85
#
#    Capital investment as percent of GDP  \
# 0                                32.274
#
#    Inflation: percent change in the Consumer Price Index  Unemployment rate  \
# 0                                              12.46                 11.778
#
#    Youth unemployment ages 15-24  ...  \
# 0                         27.074  ...
#
#    Security threats index 0 (low) - 10 (high)  \
# 0                                        7.74
#
#    Factionalized elites index 0 (low) - 10 (high)  \
# 0                                            9.52
#
#    Group grievance index 0 (low) - 10 (high)  \
# 0                                       8.94
#
#    Economic decline index 0 (low) - 10 (high)  \
# 0                                        6.54
#
#    Uneven economic development index 0 (low) - 10 (high)  \
# 0                                                5.9
#
#    State legitimacy index 0 (high) - 10 (low)  \
# 0                                         9.0
#
#    Human rights and rule of law index 0 (high) - 10 (low)  \
# 0                                               9.36
#
#    Demographic pressures 0 (low) - 10 (high)  \
# 0                                       5.14
#
#    Refugees and displaced persons index 0 (low) - 10 (high)  \
# 0                                               6.54
#
#    External interventions index 0 (low) - 10 (high)
# 0                                               6.7
#
# [1 rows x 62 columns]

# %%
sns.lineplot(x = list(range(1990,2021)),y=prob_series('Somalia',1990,2020))
# Out:
# <AxesSubplot: >

# %%
codes = pd.read_csv('country_code_example.csv')
codes.head()

code_dict = dict(codes['Country from our model']:codes['Code'])
# Out:
#   Cell In [130], line 4
#     code_dict = dict(codes['Country from our model']:codes['Code'])
#                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Downloading the data
