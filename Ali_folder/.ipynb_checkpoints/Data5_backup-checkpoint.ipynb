# %% [markdown]
# # Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

url = 'https://raw.githubusercontent.com/chekirou/International-conflict-prediction/master/data/actual.csv'

# %%
df = pd.read_csv(url)

# %%
csv1 = pd.read_csv('../raw_data/csv1.csv')
csv2 = pd.read_csv('../raw_data/csv2.csv')
csv3 = pd.read_csv('../raw_data/csv3.csv')
csv4 = pd.read_csv('../raw_data/csv4.csv')
csv5 = pd.read_csv('../raw_data/csv5.csv')
csv6 = pd.read_csv('../raw_data/csv6.csv')

# %%
csv1['CountryYear'] = csv1['Country']+csv1['Year'].astype(str)
csv2['CountryYear'] = csv2['Country']+csv2['Year'].astype(str)
csv3['CountryYear'] = csv3['Country']+csv3['Year'].astype(str)
csv4['CountryYear'] = csv4['Country']+csv4['Year'].astype(str)
csv5['CountryYear'] = csv5['Country']+csv5['Year'].astype(str)
csv6['CountryYear'] = csv6['Country']+csv6['Year'].astype(str)

# %%
csv_12 = pd.merge(csv1,csv2,on='CountryYear',how='outer')
csv_123 = pd.merge(csv_12,csv3,on='CountryYear',how='outer')
csv_1234 = pd.merge(csv_123,csv4,on='CountryYear',how='outer')
csv_12345 = pd.merge(csv_1234,csv5,on='CountryYear',how='outer')
csv_full = pd.merge(csv_12345,csv6,on='CountryYear',how='outer')
# Out:
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_60485/2404285424.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Year_x', 'Country_x', 'ContinentCode_x', 'Code_x'} in the result is deprecated and will raise a MergeError in a future version.
#   csv_1234 = pd.merge(csv_123,csv4,on='CountryYear',how='outer')
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_60485/2404285424.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Year_x', 'Country_x', 'ContinentCode_x', 'Code_x'} in the result is deprecated and will raise a MergeError in a future version.
#   csv_full = pd.merge(csv_12345,csv6,on='CountryYear',how='outer')

# %%
csv_full.isna().sum()
# Out:
# Country_x                                                   3796
# Code_x                                                      3796
# ContinentCode_x                                             4716
# Year_x                                                      3796
# Military spending percent of total government spending      8431
#                                                             ...
# State legitimacy index 0 (high) - 10 (low)                  9751
# Human rights and rule of law index 0 (high) - 10 (low)      9750
# Demographic pressures 0 (low) - 10 (high)                   9750
# Refugees and displaced persons index 0 (low) - 10 (high)    9750
# External interventions index 0 (low) - 10 (high)            9750
# Length: 114, dtype: int64

# %%
conflicts = pd.read_csv('../raw_data/conflict_data/conflict_data_1970.csv')

# %%
def get_year(row):
    
    year_value = row['CountryYear'][-4:]
    
    return int(year_value)

# %%
def get_country(row):
    
    country_name = row['CountryYear'][:-4]

    return country_name

# %%
def get_code(row):
    
    code_value = row['CountryYear'][-4:]
    
    return int(year_value)

# %%
csv_full['year_all'] = csv_full.apply(lambda x: get_year(x),axis=1)

# %%
csv_full['country_all'] = csv_full.apply(lambda x: get_country(x), axis=1)

# %%
csv_full['conflict_id'] =0
conflicts

csv_full[(csv_full['country_all']=='USA') & (csv_full['year_all']>1994)]

conflicts_1990 = conflicts[conflicts['Year']>1989]

# %%
my_list = []

def get_hist_data(country,year,lookback):
    
    early_year = lookback
    hist_data = csv_full[(csv_full['country_all']==country) & (csv_full['year_all'] <= (year -1)) & (csv_full['year_all'] > (year -1 - early_year))]
    while hist_data.shape[0] < lookback:
        early_year += 1
        hist_data = csv_full[(csv_full['country_all']==country) & (csv_full['year_all'] <= (year -1)) & (csv_full['year_all'] > (year -1 - early_year))]
    return hist_data

for index, row in conflicts_1990.iterrows():

    my_list.append(get_hist_data(row['Country'],row['Year'],5))


get_hist_data('USA',2010,10)    
    
len(my_list)
# Out:
# 94

# %%
for i in range(len(my_list)):
    my_list[i]['conflict_id'] = i
# Out:
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_60485/729059741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_list[i]['conflict_id'] = i

# %%
for i in range(len(my_list)):
    if len(my_list[i]) < 5:
        print(i)

# %%
final_df = pd.DataFrame(columns=my_list[50].columns)

# %%
final_df
# Out:
# Empty DataFrame
# Columns: [Country_x, Code_x, ContinentCode_x, Year_x, Military spending percent of total government spending , Arms imports million constant U.S. dollars, Cost of living index world average = 100, Food price index world average = 100, Housing and utilities price index world average  = 100, Healthcare price index world average = 100, Happiness Index 0 (unhappy) - 10 (happy), Human Development Index (0 - 1), CountryYear, Country_y, Code_y, ContinentCode_y, Year_y, Economic growth: the rate of change of real GDP, GDP per capita current U.S. dollars, GDP per capita Purchasing Power Parity, Capital investment as percent of GDP, Inflation: percent change in the Consumer Price Index, Unemployment rate, Youth unemployment ages 15-24, Labor force participation rate, Trade openness: exports plus imports as percent of GDP, Foreign Direct Investment percent of GDP, Trade balance as percent of GDP, External debt percent of Gross National Income, Government spending as percent of GDP, Fiscal balance percent of GDP, Government debt as percent of GDP, Foreign aid and official development assistance received, Country_x, Code_x, ContinentCode_x, Year_x, Rule of law index (-2.5 weak; 2.5 strong), Government effectiveness index (-2.5 weak; 2.5 strong), Control of corruption (-2.5 weak; 2.5 strong), Regulatory quality index (-2.5 weak; 2.5 strong), Voice and accountability index (-2.5 weak; 2.5 strong), Political stability index (-2.5 weak; 2.5 strong), Corruption Perceptions Index 100 = no corruption, Political rights index 7 (weak) - 1 (strong), Civil liberties index 7 (weak) - 1 (strong) , Shadow economy percent of GDP, Internet users percent of population, Mobile network coverage percent of the population, Gasoline prices at the pump in dollars per liter, Diesel prices at the pump in dollars per liter, Income from natural resources percent of GDP, Access to electricity percent of the population, Country_y, Code_y, ContinentCode_y, Year_y, Food production index (2004-2006 = 100), Banking system z-scores, Real interest rate: Bank lending rate minus inflation, Freedom from corruption index (0-100), Labor freedom index (0-100), Economic freedom overall index (0-100), Population size in millions, Rural population percent of total population, Refugee population, Migrant population percent of total population, Population growth percent, Life expectancy in years, Death rate per 1000 people, Suicide mortality rate per 100000 population, Country_x, Code_x, ContinentCode_x, Year_x, Deaths of children under five years of age per 1000 live births, Doctors per 1000 people, Gini income inequality index, Poverty percent of population, Poverty ratio percent living on less than 1.90 USD a day, Poverty ratio percent living on less than 5.50 USD a day, Percent income earned by the top 10 percent of earners, Public spending on education percent of GDP, Literacy rate, Globalization index (0-100), Economic globalization index (0-100), Political globalization index (0-100), Social globalization index (0-100), Number of prisoners per 100000 people, Homicides per 100000 people, Country_y, Code_y, ContinentCode_y, Year_y, People practicing Judaism as percent of the population, Buddhists as percent of the total population, People practicing Hinduism as percent of the population, Shia Muslims as percent of the total population, Sunni Muslims as percent of the total population, Christians as percent of the total population, ...]
# Index: []
#
# [0 rows x 117 columns]

# %%
for i in range(len(my_list)):
    
    final_df = pd.concat([final_df,my_list[i]])

# %%
final_df.shape
# Out:
# (470, 117)

# %%
final_df
# Out:
#         Country_x Code_x ContinentCode_x  Year_x  \
# 6643       Rwanda    RWA              AF  1985.0
# 6644       Rwanda    RWA              AF  1986.0
# 6645       Rwanda    RWA              AF  1988.0
# 10638         NaN    NaN             NaN     NaN
# 10639         NaN    NaN             NaN     NaN
# ...           ...    ...             ...     ...
# 4163   Kazakhstan    KAZ              AS  2017.0
# 4164   Kazakhstan    KAZ              AS  2018.0
# 4165   Kazakhstan    KAZ              AS  2019.0
# 4166   Kazakhstan    KAZ              AS  2020.0
# 4167   Kazakhstan    KAZ              AS  2021.0
#
#        Military spending percent of total government spending   \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                3.45
# 4164                                                4.65
# 4165                                                5.25
# 4166                                                4.56
# 4167                                                 NaN
#
#        Arms imports million constant U.S. dollars  \
# 6643                                          3.0
# 6644                                          2.0
# 6645                                          2.0
# 10638                                         NaN
# 10639                                         NaN
# ...                                           ...
# 4163                                        214.0
# 4164                                        310.0
# 4165                                        312.0
# 4166                                        268.0
# 4167                                          NaN
#
#        Cost of living index world average = 100  \
# 6643                                        NaN
# 6644                                        NaN
# 6645                                        NaN
# 10638                                       NaN
# 10639                                       NaN
# ...                                         ...
# 4163                                      55.08
# 4164                                        NaN
# 4165                                        NaN
# 4166                                        NaN
# 4167                                        NaN
#
#        Food price index world average = 100  \
# 6643                                    NaN
# 6644                                    NaN
# 6645                                    NaN
# 10638                                   NaN
# 10639                                   NaN
# ...                                     ...
# 4163                                  70.57
# 4164                                    NaN
# 4165                                    NaN
# 4166                                    NaN
# 4167                                    NaN
#
#        Housing and utilities price index world average  = 100  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                              63.413
# 4164                                                 NaN
# 4165                                                 NaN
# 4166                                                 NaN
# 4167                                                 NaN
#
#        Healthcare price index world average = 100  ...  \
# 6643                                          NaN  ...
# 6644                                          NaN  ...
# 6645                                          NaN  ...
# 10638                                         NaN  ...
# 10639                                         NaN  ...
# ...                                           ...  ...
# 4163                                        30.55  ...
# 4164                                          NaN  ...
# 4165                                          NaN  ...
# 4166                                          NaN  ...
# 4167                                          NaN  ...
#
#        Economic decline index 0 (low) - 10 (high)  \
# 6643                                          NaN
# 6644                                          NaN
# 6645                                          NaN
# 10638                                         NaN
# 10639                                         NaN
# ...                                           ...
# 4163                                          6.4
# 4164                                          5.9
# 4165                                          5.6
# 4166                                          5.3
# 4167                                          5.5
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 4.2
# 4164                                                 3.9
# 4165                                                 3.6
# 4166                                                 3.3
# 4167                                                 3.2
#
#       State legitimacy index 0 (high) - 10 (low)  \
# 6643                                         NaN
# 6644                                         NaN
# 6645                                         NaN
# 10638                                        NaN
# 10639                                        NaN
# ...                                          ...
# 4163                                         8.3
# 4164                                         8.4
# 4165                                         8.5
# 4166                                         8.5
# 4167                                         8.2
#
#       Human rights and rule of law index 0 (high) - 10 (low)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 7.3
# 4164                                                 7.0
# 4165                                                 6.7
# 4166                                                 6.4
# 4167                                                 6.7
#
#       Demographic pressures 0 (low) - 10 (high)  \
# 6643                                        NaN
# 6644                                        NaN
# 6645                                        NaN
# 10638                                       NaN
# 10639                                       NaN
# ...                                         ...
# 4163                                        4.5
# 4164                                        4.2
# 4165                                        3.9
# 4166                                        3.6
# 4167                                        4.1
#
#       Refugees and displaced persons index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 3.0
# 4164                                                 2.7
# 4165                                                 2.4
# 4166                                                 2.3
# 4167                                                 2.1
#
#        External interventions index 0 (low) - 10 (high)  year_all  \
# 6643                                                NaN      1985
# 6644                                                NaN      1986
# 6645                                                NaN      1988
# 10638                                               NaN      1987
# 10639                                               NaN      1989
# ...                                                 ...       ...
# 4163                                                4.2      2017
# 4164                                                3.9      2018
# 4165                                                3.6      2019
# 4166                                                3.3      2020
# 4167                                                3.0      2021
#
#        country_all  conflict_id
# 6643        Rwanda            0
# 6644        Rwanda            0
# 6645        Rwanda            0
# 10638       Rwanda            0
# 10639       Rwanda            0
# ...            ...          ...
# 4163    Kazakhstan           93
# 4164    Kazakhstan           93
# 4165    Kazakhstan           93
# 4166    Kazakhstan           93
# 4167    Kazakhstan           93
#
# [470 rows x 117 columns]

# %% [markdown]
# # Dropping features

# %%
final_df.shape
# Out:
# (470, 117)

# %%
to_drop  = pd.DataFrame(final_df.isna().sum()/470)
len(to_drop)
# Out:
# 117

# %%
to_drop_list = to_drop[to_drop[0]>0.7].index.values.tolist()
len(to_drop_list)
# Out:
# 26

# %%
for i in to_drop_list:
    final_df.drop(columns=i, axis=1, inplace=True)

# %%
final_df['CountryYear']
# Out:
# 6643         Rwanda1985
# 6644         Rwanda1986
# 6645         Rwanda1988
# 10638        Rwanda1987
# 10639        Rwanda1989
#               ...
# 4163     Kazakhstan2017
# 4164     Kazakhstan2018
# 4165     Kazakhstan2019
# 4166     Kazakhstan2020
# 4167     Kazakhstan2021
# Name: CountryYear, Length: 470, dtype: object

# %% [markdown]
# # Dropping data for the imputer

# %%
bin_list = ['Country_x','Code_x','Country_y','Year_x','Year_y','Code_y','ContinentCode_y','ContinentCode_x','Christians as percent of the total population']
final_df.head()
# Out:
#       Country_x Code_x ContinentCode_x  Year_x  \
# 6643     Rwanda    RWA              AF  1985.0
# 6644     Rwanda    RWA              AF  1986.0
# 6645     Rwanda    RWA              AF  1988.0
# 10638       NaN    NaN             NaN     NaN
# 10639       NaN    NaN             NaN     NaN
#
#        Military spending percent of total government spending   \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
#
#        Arms imports million constant U.S. dollars  \
# 6643                                          3.0
# 6644                                          2.0
# 6645                                          2.0
# 10638                                         NaN
# 10639                                         NaN
#
#        Human Development Index (0 - 1) CountryYear Country_y Code_y  ...  \
# 6643                               NaN  Rwanda1985    Rwanda    RWA  ...
# 6644                               NaN  Rwanda1986    Rwanda    RWA  ...
# 6645                               NaN  Rwanda1988    Rwanda    RWA  ...
# 10638                              NaN  Rwanda1987    Rwanda    RWA  ...
# 10639                              NaN  Rwanda1989    Rwanda    RWA  ...
#
#       Economic decline index 0 (low) - 10 (high)  \
# 6643                                         NaN
# 6644                                         NaN
# 6645                                         NaN
# 10638                                        NaN
# 10639                                        NaN
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
#
#        State legitimacy index 0 (high) - 10 (low)  \
# 6643                                          NaN
# 6644                                          NaN
# 6645                                          NaN
# 10638                                         NaN
# 10639                                         NaN
#
#        Human rights and rule of law index 0 (high) - 10 (low)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
#
#        Demographic pressures 0 (low) - 10 (high)  \
# 6643                                         NaN
# 6644                                         NaN
# 6645                                         NaN
# 10638                                        NaN
# 10639                                        NaN
#
#        Refugees and displaced persons index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
#
#        External interventions index 0 (low) - 10 (high)  year_all  \
# 6643                                                NaN      1985
# 6644                                                NaN      1986
# 6645                                                NaN      1988
# 10638                                               NaN      1987
# 10639                                               NaN      1989
#
#        country_all  conflict_id
# 6643        Rwanda            0
# 6644        Rwanda            0
# 6645        Rwanda            0
# 10638       Rwanda            0
# 10639       Rwanda            0
#
# [5 rows x 91 columns]

# %%
cleaner_df = final_df.drop(columns=bin_list)

# %%
cleaner_df['conflict_id']=cleaner_df['conflict_id'].astype(int)

# %%
cleaner_df
# Out:
#        Military spending percent of total government spending   \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                3.45
# 4164                                                4.65
# 4165                                                5.25
# 4166                                                4.56
# 4167                                                 NaN
#
#        Arms imports million constant U.S. dollars  \
# 6643                                          3.0
# 6644                                          2.0
# 6645                                          2.0
# 10638                                         NaN
# 10639                                         NaN
# ...                                           ...
# 4163                                        214.0
# 4164                                        310.0
# 4165                                        312.0
# 4166                                        268.0
# 4167                                          NaN
#
#        Human Development Index (0 - 1)     CountryYear  \
# 6643                               NaN      Rwanda1985
# 6644                               NaN      Rwanda1986
# 6645                               NaN      Rwanda1988
# 10638                              NaN      Rwanda1987
# 10639                              NaN      Rwanda1989
# ...                                ...             ...
# 4163                             0.813  Kazakhstan2017
# 4164                             0.817  Kazakhstan2018
# 4165                             0.817  Kazakhstan2019
# 4166                             0.825  Kazakhstan2020
# 4167                               NaN  Kazakhstan2021
#
#        Economic growth: the rate of change of real GDP  \
# 6643                                              4.40
# 6644                                              5.47
# 6645                                              4.50
# 10638                                            -0.02
# 10639                                            -0.04
# ...                                                ...
# 4163                                              4.10
# 4164                                              4.10
# 4165                                              4.50
# 4166                                             -2.50
# 4167                                              4.00
#
#        GDP per capita current U.S. dollars  \
# 6643                                279.10
# 6644                                301.80
# 6645                                337.96
# 10638                               318.21
# 10639                               330.50
# ...                                    ...
# 4163                               9247.58
# 4164                               9812.63
# 4165                               9812.60
# 4166                               9121.64
# 4167                              10041.49
#
#        GDP per capita Purchasing Power Parity  \
# 6643                                      NaN
# 6644                                      NaN
# 6645                                      NaN
# 10638                                     NaN
# 10639                                     NaN
# ...                                       ...
# 4163                                 24862.97
# 4164                                 25544.35
# 4165                                 26351.80
# 4166                                 25361.51
# 4167                                 26033.24
#
#        Capital investment as percent of GDP  \
# 6643                                  17.31
# 6644                                  15.87
# 6645                                  14.49
# 10638                                 15.66
# 10639                                 13.43
# ...                                     ...
# 4163                                  26.35
# 4164                                  25.26
# 4165                                  27.63
# 4166                                  28.52
# 4167                                    NaN
#
#        Inflation: percent change in the Consumer Price Index  \
# 6643                                                 1.8
# 6644                                                -1.1
# 6645                                                 3.0
# 10638                                                4.1
# 10639                                                1.0
# ...                                                  ...
# 4163                                                 7.4
# 4164                                                 6.0
# 4165                                                 5.2
# 4166                                                 6.7
# 4167                                                 NaN
#
#        Unemployment rate  ...  Economic decline index 0 (low) - 10 (high)  \
# 6643                 NaN  ...                                         NaN
# 6644                 NaN  ...                                         NaN
# 6645                 NaN  ...                                         NaN
# 10638                NaN  ...                                         NaN
# 10639                NaN  ...                                         NaN
# ...                  ...  ...                                         ...
# 4163                4.90  ...                                         6.4
# 4164                4.85  ...                                         5.9
# 4165                4.80  ...                                         5.6
# 4166                4.89  ...                                         5.3
# 4167                4.90  ...                                         5.5
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 4.2
# 4164                                                 3.9
# 4165                                                 3.6
# 4166                                                 3.3
# 4167                                                 3.2
#
#        State legitimacy index 0 (high) - 10 (low)  \
# 6643                                          NaN
# 6644                                          NaN
# 6645                                          NaN
# 10638                                         NaN
# 10639                                         NaN
# ...                                           ...
# 4163                                          8.3
# 4164                                          8.4
# 4165                                          8.5
# 4166                                          8.5
# 4167                                          8.2
#
#        Human rights and rule of law index 0 (high) - 10 (low)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 7.3
# 4164                                                 7.0
# 4165                                                 6.7
# 4166                                                 6.4
# 4167                                                 6.7
#
#        Demographic pressures 0 (low) - 10 (high)  \
# 6643                                         NaN
# 6644                                         NaN
# 6645                                         NaN
# 10638                                        NaN
# 10639                                        NaN
# ...                                          ...
# 4163                                         4.5
# 4164                                         4.2
# 4165                                         3.9
# 4166                                         3.6
# 4167                                         4.1
#
#        Refugees and displaced persons index 0 (low) - 10 (high)  \
# 6643                                                 NaN
# 6644                                                 NaN
# 6645                                                 NaN
# 10638                                                NaN
# 10639                                                NaN
# ...                                                  ...
# 4163                                                 3.0
# 4164                                                 2.7
# 4165                                                 2.4
# 4166                                                 2.3
# 4167                                                 2.1
#
#        External interventions index 0 (low) - 10 (high)  year_all  \
# 6643                                                NaN      1985
# 6644                                                NaN      1986
# 6645                                                NaN      1988
# 10638                                               NaN      1987
# 10639                                               NaN      1989
# ...                                                 ...       ...
# 4163                                                4.2      2017
# 4164                                                3.9      2018
# 4165                                                3.6      2019
# 4166                                                3.3      2020
# 4167                                                3.0      2021
#
#        country_all  conflict_id
# 6643        Rwanda            0
# 6644        Rwanda            0
# 6645        Rwanda            0
# 10638       Rwanda            0
# 10639       Rwanda            0
# ...            ...          ...
# 4163    Kazakhstan           93
# 4164    Kazakhstan           93
# 4165    Kazakhstan           93
# 4166    Kazakhstan           93
# 4167    Kazakhstan           93
#
# [470 rows x 66 columns]

# %% [markdown]
# # Grouping the data

# %%
grouped_df = cleaner_df.groupby(by='conflict_id').mean()
# Out:
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_60485/2490057627.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = cleaner_df.groupby(by='conflict_id').mean()

# %%
grouped_df.columns
# Out:
# Index(['Military spending percent of total government spending ',
#        'Arms imports million constant U.S. dollars',
#        'Human Development Index (0 - 1)',
#        'Economic growth: the rate of change of real GDP',
#        'GDP per capita current U.S. dollars',
#        'GDP per capita Purchasing Power Parity',
#        'Capital investment as percent of GDP',
#        'Inflation: percent change in the Consumer Price Index',
#        'Unemployment rate', 'Youth unemployment ages 15-24',
#        'Labor force participation rate',
#        'Trade openness: exports plus imports as percent of GDP',
#        'Foreign Direct Investment percent of GDP',
#        'Trade balance as percent of GDP',
#        'External debt percent of Gross National Income',
#        'Government spending as percent of GDP',
#        'Fiscal balance percent of GDP', 'Government debt as percent of GDP',
#        'Foreign aid and official development assistance received',
#        'Rule of law index (-2.5 weak; 2.5 strong)',
#        'Government effectiveness index (-2.5 weak; 2.5 strong)',
#        'Control of corruption (-2.5 weak; 2.5 strong)',
#        'Regulatory quality index (-2.5 weak; 2.5 strong)',
#        'Voice and accountability index (-2.5 weak; 2.5 strong)',
#        'Political stability index (-2.5 weak; 2.5 strong)',
#        'Corruption Perceptions Index 100 = no corruption',
#        'Political rights index 7 (weak) - 1 (strong)',
#        'Civil liberties index 7 (weak) - 1 (strong) ',
#        'Shadow economy percent of GDP', 'Internet users percent of population',
#        'Income from natural resources percent of GDP',
#        'Access to electricity percent of the population',
#        'Food production index (2004-2006 = 100)', 'Banking system z-scores',
#        'Real interest rate: Bank lending rate minus inflation',
#        'Freedom from corruption index (0-100)', 'Labor freedom index (0-100)',
#        'Economic freedom overall index (0-100)', 'Population size in millions',
#        'Rural population percent of total population', 'Refugee population',
#        'Population growth percent', 'Life expectancy in years',
#        'Death rate per 1000 people',
#        'Suicide mortality rate per 100000 population',
#        'Deaths of children under five years of age per 1000 live births',
#        'Public spending on education percent of GDP',
#        'Globalization index (0-100)', 'Economic globalization index (0-100)',
#        'Political globalization index (0-100)',
#        'Social globalization index (0-100)', 'Homicides per 100000 people',
#        'Security threats index 0 (low) - 10 (high)',
#        'Factionalized elites index 0 (low) - 10 (high)',
#        'Group grievance index 0 (low) - 10 (high)',
#        'Economic decline index 0 (low) - 10 (high)',
#        'Uneven economic development index 0 (low) - 10 (high)',
#        'State legitimacy index 0 (high) - 10 (low)',
#        'Human rights and rule of law index 0 (high) - 10 (low)',
#        'Demographic pressures 0 (low) - 10 (high)',
#        'Refugees and displaced persons index 0 (low) - 10 (high)',
#        'External interventions index 0 (low) - 10 (high)'],
#       dtype='object')

# %% [markdown]
# # Create the control dataset

# %%
conflict_years = final_df['CountryYear']

# %%
csv4_after_1980 = csv_full[csv_full['year_all'] > 1985]
csv4_after_1980_noconflict = csv4_after_1980[csv4_after_1980.CountryYear.isin(conflict_years)==False]
csv4_after_1980.shape[0] - csv4_after_1980_noconflict.shape[0]
# Out:
# 437

# %%
def slice_fn(sample):
    year = int(sample[-4:])
    words = [sample[:-4]+str(year-i-1) for i in range(4)]
    words.append(sample)
    return words

# %%
from itertools import chain

sample_list = []

control_sample = csv4_after_1980.sample(270,random_state=5)

for index,row in control_sample.iterrows():
    sample_list.append(get_hist_data(row['country_all'],row['year_all'],5))

sample_full = sample_list[0]

for i in range(1,len(sample_list)):
    
    sample_full = pd.concat([sample_full,sample_list[i]])

# %%
id_list = list(range(95,365))*5

# %%
id_list = sorted(id_list)

# %%
sample_full['conflict_id'] = id_list
sample_full['country_all'].unique()
# Out:
# array(['Saudi Arabia', 'Seychelles', 'Tonga', 'Sao Tome and Principe',
#        'Djibouti', 'Samoa', 'Vanuatu', 'Luxembourg', 'Vietnam', 'Jordan',
#        'Croatia', 'Trinidad and Tobago', 'Nigeria', 'Estonia',
#        'Bosnia and Herzegovina', 'South Korea', 'Brunei', 'Euro area',
#        'Albania', 'Macao', 'Slovakia', 'United Arab Emirates',
#        'Kyrgyzstan', 'Angola', 'Swaziland', 'South Africa', 'Portugal',
#        'Netherlands', 'Spain', 'Burundi', 'Sri Lanka', 'Tajikistan',
#        'Afghanistan', 'Rwanda', 'Sierra Leone', 'Faroe Islands', 'Syria',
#        'Venezuela', 'Cape Verde', 'Hong Kong', 'Paraguay', 'Belarus',
#        'Suriname', 'Kenya', 'Kiribati', 'Czechia', 'Palau',
#        'Central African Republic', 'Belize', 'Chile', 'Singapore',
#        'Bahrain', 'Peru', 'Madagascar', 'Bhutan', 'Papua New Guinea',
#        'Haiti', 'Canada', 'Israel', 'Zambia', 'Sweden', 'Cyprus',
#        'Republic of the Congo', 'Benin', 'USA', 'Georgia', 'Poland',
#        'Niger', 'New Zealand', 'Serbia', 'Saint Lucia', 'Montenegro',
#        'Lithuania', 'Palestine', 'Comoros', 'Tanzania', 'Turkmenistan',
#        'Germany', 'Namibia', 'Gibraltar', 'Malawi', 'Uganda', 'Cameroon',
#        'Maldives', 'Algeria', 'Equatorial Guinea', 'Bulgaria',
#        'Guatemala', 'Cambodia', 'Fiji', 'United Kingdom',
#        'Solomon Islands', 'Botswana', 'Morocco', 'France', 'Ethiopia',
#        'Malaysia', 'Kazakhstan', 'Barbados', 'Philippines',
#        'Guinea-Bissau', 'New Caledonia', 'Mozambique', 'Iraq', 'Laos',
#        'Bangladesh', 'Monaco', 'Switzerland', 'Italy', 'Greece',
#        'Costa Rica', 'Ireland', 'Oman', 'Nepal', 'Egypt', 'China',
#        'Micronesia', 'Senegal', 'Ecuador', 'Colombia', 'Dominica',
#        'Lebanon', 'Tunisia', 'Burkina Faso', 'Pakistan', 'Eritrea',
#        'Thailand', 'Zimbabwe', 'Nicaragua', 'Russia', 'Ukraine',
#        'Armenia', 'Chad', 'Kuwait', 'Somalia', 'Slovenia', 'Jamaica',
#        'Austria', 'Liberia', 'Puerto Rico', 'Cuba', 'Gabon', 'Mauritania',
#        'Denmark', 'Mongolia', 'Iceland'], dtype=object)

# %%
control_groupedby = sample_full.groupby('conflict_id').mean()
# Out:
# /var/folders/_s/vshzgsh90qdgm6zwx2gfmpv80000gn/T/ipykernel_60485/3478027142.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   control_groupedby = sample_full.groupby('conflict_id').mean()

# %%
columns_to_keep = list(grouped_df.columns)

# %%
sample_full_clean = control_groupedby.drop(columns=[col for col in control_groupedby if col not in columns_to_keep])

sample_full_clean.isna().sum()

sample_full_clean
# Out:
#              Military spending percent of total government spending   \
# conflict_id
# 95                                                   28.262000
# 96                                                    3.976000
# 97                                                         NaN
# 98                                                         NaN
# 99                                                   15.108000
# ...                                                        ...
# 360                                                   6.658000
# 361                                                   1.622500
# 362                                                   7.280000
# 363                                                        NaN
# 364                                                   5.846667
#
#              Arms imports million constant U.S. dollars  \
# conflict_id
# 95                                              3264.80
# 96                                                15.00
# 97                                                 0.00
# 98                                                  NaN
# 99                                                 6.75
# ...                                                 ...
# 360                                               41.00
# 361                                               24.75
# 362                                              138.00
# 363                                                 NaN
# 364                                               15.00
#
#              Human Development Index (0 - 1)  \
# conflict_id
# 95                                    0.8560
# 96                                    0.7316
# 97                                    0.6670
# 98                                    0.5352
# 99                                    0.3530
# ...                                      ...
# 360                                   0.7510
# 361                                   0.7052
# 362                                   0.6022
# 363                                      NaN
# 364                                   0.6256
#
#              Economic growth: the rate of change of real GDP  \
# conflict_id
# 95                                                     2.240
# 96                                                     4.768
# 97                                                     3.564
# 98                                                     5.932
# 99                                                       NaN
# ...                                                      ...
# 360                                                    2.650
# 361                                                    5.160
# 362                                                    6.900
# 363                                                    2.454
# 364                                                    2.700
#
#              GDP per capita current U.S. dollars  \
# conflict_id
# 95                                     22000.440
# 96                                     11312.252
# 97                                      2145.858
# 98                                      1007.380
# 99                                       774.476
# ...                                          ...
# 360                                     6060.010
# 361                                     2247.610
# 362                                      509.966
# 363                                    95638.882
# 364                                     3212.612
#
#              GDP per capita Purchasing Power Parity  \
# conflict_id
# 95                                        48138.468
# 96                                        19756.672
# 97                                         4666.736
# 98                                         3194.840
# 99                                              NaN
# ...                                             ...
# 360                                       11755.288
# 361                                       10957.500
# 362                                        4312.406
# 363                                             NaN
# 364                                       11009.996
#
#              Capital investment as percent of GDP  \
# conflict_id
# 95                                      29.816000
# 96                                      28.786667
# 97                                      22.258000
# 98                                            NaN
# 99                                            NaN
# ...                                           ...
# 360                                     27.286000
# 361                                     21.950000
# 362                                           NaN
# 363                                           NaN
# 364                                     15.352000
#
#              Inflation: percent change in the Consumer Price Index  \
# conflict_id
# 95                                                        1.44
# 96                                                        9.34
# 97                                                        2.18
# 98                                                       20.78
# 99                                                         NaN
# ...                                                        ...
# 360                                                       3.42
# 361                                                     313.52
# 362                                                       4.54
# 363                                                        NaN
# 364                                                       6.52
#
#              Unemployment rate  Youth unemployment ages 15-24  ...  \
# conflict_id                                                    ...
# 95                       5.778                         28.530  ...
# 96                         NaN                            NaN  ...
# 97                       2.452                          6.388  ...
# 98                      15.662                         22.844  ...
# 99                      29.142                         51.372  ...
# ...                        ...                            ...  ...
# 360                      3.602                          9.030  ...
# 361                     12.548                         22.654  ...
# 362                      2.274                          4.906  ...
# 363                        NaN                            NaN  ...
# 364                     30.744                         53.916  ...
#
#              Security threats index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                 6.42
# 96                                                 6.10
# 97                                                  NaN
# 98                                                 5.80
# 99                                                  NaN
# ...                                                 ...
# 360                                                6.56
# 361                                                 NaN
# 362                                                 NaN
# 363                                                 NaN
# 364                                                 NaN
#
#              Factionalized elites index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                    8.180
# 96                                                    6.600
# 97                                                      NaN
# 98                                                    6.275
# 99                                                      NaN
# ...                                                     ...
# 360                                                   8.200
# 361                                                     NaN
# 362                                                     NaN
# 363                                                     NaN
# 364                                                     NaN
#
#              Group grievance index 0 (low) - 10 (high)  \
# conflict_id
# 95                                               7.700
# 96                                               5.450
# 97                                                 NaN
# 98                                               5.075
# 99                                                 NaN
# ...                                                ...
# 360                                              7.380
# 361                                                NaN
# 362                                                NaN
# 363                                                NaN
# 364                                                NaN
#
#              Economic decline index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                 4.38
# 96                                                 3.95
# 97                                                  NaN
# 98                                                 8.00
# 99                                                  NaN
# ...                                                 ...
# 360                                                5.58
# 361                                                 NaN
# 362                                                 NaN
# 363                                                 NaN
# 364                                                 NaN
#
#              Uneven economic development index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                        5.42
# 96                                                        6.85
# 97                                                         NaN
# 98                                                        6.05
# 99                                                         NaN
# ...                                                        ...
# 360                                                       7.18
# 361                                                        NaN
# 362                                                        NaN
# 363                                                        NaN
# 364                                                        NaN
#
#              State legitimacy index 0 (high) - 10 (low)  \
# conflict_id
# 95                                                8.060
# 96                                                7.750
# 97                                                  NaN
# 98                                                7.325
# 99                                                  NaN
# ...                                                 ...
# 360                                               7.060
# 361                                                 NaN
# 362                                                 NaN
# 363                                                 NaN
# 364                                                 NaN
#
#              Human rights and rule of law index 0 (high) - 10 (low)  \
# conflict_id
# 95                                                        9.00
# 96                                                        6.50
# 97                                                         NaN
# 98                                                        5.25
# 99                                                         NaN
# ...                                                        ...
# 360                                                       5.08
# 361                                                        NaN
# 362                                                        NaN
# 363                                                        NaN
# 364                                                        NaN
#
#              Demographic pressures 0 (low) - 10 (high)  \
# conflict_id
# 95                                               5.520
# 96                                               6.800
# 97                                                 NaN
# 98                                               7.825
# 99                                                 NaN
# ...                                                ...
# 360                                              5.800
# 361                                                NaN
# 362                                                NaN
# 363                                                NaN
# 364                                                NaN
#
#              Refugees and displaced persons index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                        4.70
# 96                                                        4.90
# 97                                                         NaN
# 98                                                        4.35
# 99                                                         NaN
# ...                                                        ...
# 360                                                       5.60
# 361                                                        NaN
# 362                                                        NaN
# 363                                                        NaN
# 364                                                        NaN
#
#              External interventions index 0 (low) - 10 (high)
# conflict_id
# 95                                                      4.820
# 96                                                      6.700
# 97                                                        NaN
# 98                                                      6.425
# 99                                                        NaN
# ...                                                       ...
# 360                                                     5.960
# 361                                                       NaN
# 362                                                       NaN
# 363                                                       NaN
# 364                                                       NaN
#
# [270 rows x 62 columns]

# %%
# sample_full_clean

# sara_conflict = pd.read_csv('imputed_final_df.csv',index_col=0)
# sara_control = pd.read_csv('imputed_control.csv')


# test_sara_conflict_ali_control = pd.concat([sara_conflict,imputed_control_df])
# test_sara_control_ali_conflict = pd.concat([imputed_conflict_df,sara_control])

# %% [markdown]
# # Merging dataset and imputing all

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer(max_iter=10, random_state=0, missing_values=np.nan)
imputer2 = IterativeImputer(max_iter=10, random_state=0, missing_values=np.nan)

grouped_df['target'] = 1
sample_full_clean['target'] = 0

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']


full_dataset = pd.concat([grouped_df,sample_full_clean])

# %%
data_numeric = full_dataset.select_dtypes(include=numerics)

imputer.fit(data_numeric)
imputed_final_df = pd.DataFrame(imputer.transform(data_numeric),columns=full_dataset.columns)
imputed_final_df.head()
# Out:
#    Military spending percent of total government spending   \
# 0                                          11.514428
# 1                                           8.825699
# 2                                          10.390000
# 3                                           9.759190
# 4                                           8.731980
#
#    Arms imports million constant U.S. dollars  \
# 0                                    2.333333
# 1                                   16.000000
# 2                                  122.200000
# 3                                    2.000000
# 4                                   40.782717
#
#    Human Development Index (0 - 1)  \
# 0                         0.312113
# 1                         0.370561
# 2                         0.324188
# 3                         0.313510
# 4                         0.630355
#
#    Economic growth: the rate of change of real GDP  \
# 0                                            2.862
# 1                                            3.200
# 2                                            3.308
# 3                                            4.888
# 4                                           -4.666
#
#    GDP per capita current U.S. dollars  \
# 0                              313.514
# 1                              823.864
# 2                              257.922
# 3                              174.638
# 4                             1614.640
#
#    GDP per capita Purchasing Power Parity  \
# 0                             1805.909316
# 1                            -1245.925892
# 2                             -409.724896
# 3                            -2402.529065
# 4                            11135.460000
#
#    Capital investment as percent of GDP  \
# 0                                15.352
# 1                                13.258
# 2                                15.868
# 3                                21.562
# 4                                29.614
#
#    Inflation: percent change in the Consumer Price Index  Unemployment rate  \
# 0                                           1.760000               7.258303
# 1                                           2.740000               9.416043
# 2                                           7.766667               5.628955
# 3                                          11.140000               6.661470
# 4                                          86.596417               7.356395
#
#    Youth unemployment ages 15-24  ...  \
# 0                      11.853684  ...
# 1                      16.399486  ...
# 2                       8.021525  ...
# 3                      11.207033  ...
# 4                      14.062587  ...
#
#    Factionalized elites index 0 (low) - 10 (high)  \
# 0                                        8.540161
# 1                                        8.250708
# 2                                        9.657661
# 3                                        9.382054
# 4                                        6.118855
#
#    Group grievance index 0 (low) - 10 (high)  \
# 0                                   6.878944
# 1                                   7.343167
# 2                                   8.362923
# 3                                   7.474488
# 4                                   6.128167
#
#    Economic decline index 0 (low) - 10 (high)  \
# 0                                    9.163663
# 1                                    8.461313
# 2                                    8.935214
# 3                                    9.095309
# 4                                    6.414535
#
#    Uneven economic development index 0 (low) - 10 (high)  \
# 0                                           8.795369
# 1                                           8.254767
# 2                                           8.930171
# 3                                           8.705284
# 4                                           7.233441
#
#    State legitimacy index 0 (high) - 10 (low)  \
# 0                                    8.999092
# 1                                    7.728333
# 2                                    8.910818
# 3                                    9.071218
# 4                                    6.629376
#
#    Human rights and rule of law index 0 (high) - 10 (low)  \
# 0                                           8.854587
# 1                                           7.378541
# 2                                           8.887513
# 3                                           8.798744
# 4                                           6.125762
#
#    Demographic pressures 0 (low) - 10 (high)  \
# 0                                   9.825009
# 1                                   8.739944
# 2                                   9.518954
# 3                                   9.303570
# 4                                   7.132132
#
#    Refugees and displaced persons index 0 (low) - 10 (high)  \
# 0                                           7.103202
# 1                                           6.993745
# 2                                           7.866861
# 3                                           7.125936
# 4                                           5.574929
#
#    External interventions index 0 (low) - 10 (high)  target
# 0                                          8.951248     1.0
# 1                                          8.032011     1.0
# 2                                          8.862492     1.0
# 3                                          8.854523     1.0
# 4                                          6.841663     1.0
#
# [5 rows x 63 columns]

# %%
#  data_numeric2 = grouped_df.select_dtypes(include=numerics)

# imputed_conflict_df = pd.DataFrame(imputer2.fit_transform(data_numeric2),columns=data_numeric2.columns)
# imputed_control_df = pd.DataFrame(imputer2.fit_transform(sample_full_clean),columns=data_numeric2.columns)

# %%
# imputed_control_df

# %%
# separate_impute_full_df = pd.concat([imputed_control_df,imputed_conflict_df])
# separate_impute_full_df['target'] = separate_impute_full_df['target'].astype(int)
# separate_impute_full_df
# imputed_final_df

# %%
# scaler2 = MinMaxScaler()
# separate_scaled = pd.DataFrame(scaler2.fit_transform(separate_impute_full_df), columns=separate_impute_full_df.columns)

# X2 = separate_scaled.drop(columns=['target'])
# y2 = separate_scaled['target']
# X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2,test_size = 0.3, random_state=5)

# %%
# bst2 = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
# bst2.fit(X_train2, y_train2)

# %%
# preds2 = bst2.predict(X_test2)

# accuracy_score(preds2,y_test2)

# %%
# print(imputed_final_df.shape)
# imputed_final_df.columns

imputed_final_df.describe()
# Out:
#        Military spending percent of total government spending   \
# count                                         364.000000
# mean                                            9.440025
# std                                             6.219699
# min                                            -3.569309
# 25%                                             5.371671
# 50%                                             8.459433
# 75%                                            11.802500
# max                                            41.000000
#
#        Arms imports million constant U.S. dollars  \
# count                                  364.000000
# mean                                   194.104234
# std                                    417.940858
# min                                   -690.894897
# 25%                                      7.000000
# 50%                                     57.875000
# 75%                                    220.363876
# max                                   3264.800000
#
#        Human Development Index (0 - 1)  \
# count                       364.000000
# mean                          0.626576
# std                           0.169483
# min                           0.254800
# 25%                           0.497350
# 50%                           0.644900
# 75%                           0.758550
# max                           1.046568
#
#        Economic growth: the rate of change of real GDP  \
# count                                       364.000000
# mean                                          3.969200
# std                                           4.518247
# min                                         -10.326000
# 25%                                           2.120000
# 50%                                           3.576000
# 75%                                           5.427500
# max                                          48.050000
#
#        GDP per capita current U.S. dollars  \
# count                           364.000000
# mean                           8634.983146
# std                           14724.169405
# min                             138.586000
# 25%                             821.871000
# 50%                            2574.381000
# 75%                            9420.972109
# max                           95638.882000
#
#        GDP per capita Purchasing Power Parity  \
# count                              364.000000
# mean                             15615.074426
# std                              19228.439546
# min                             -11340.531609
# 25%                               3186.207994
# 50%                               8941.112500
# 75%                              19292.799616
# max                             129929.162000
#
#        Capital investment as percent of GDP  \
# count                            364.000000
# mean                              23.596881
# std                                7.407080
# min                                0.000000
# 25%                               19.838500
# 50%                               23.396790
# 75%                               26.530539
# max                               59.576000
#
#        Inflation: percent change in the Consumer Price Index  \
# count                                         364.000000
# mean                                           93.097979
# std                                           562.922230
# min                                          -358.205882
# 25%                                             2.920000
# 50%                                             6.140000
# 75%                                            20.895000
# max                                          6517.100000
#
#        Unemployment rate  Youth unemployment ages 15-24  ...  \
# count         364.000000                     364.000000  ...
# mean            8.355731                      17.108196  ...
# std             5.965278                      11.863513  ...
# min             0.522000                       0.764000  ...
# 25%             4.182000                       8.120500  ...
# 50%             7.339859                      15.571000  ...
# 75%            10.756250                      22.336500  ...
# max            30.744000                      68.710000  ...
#
#        Factionalized elites index 0 (low) - 10 (high)  \
# count                                      364.000000
# mean                                         6.597622
# std                                          2.360369
# min                                         -2.194983
# 25%                                          5.288029
# 50%                                          7.030856
# 75%                                          8.247887
# max                                         11.149388
#
#        Group grievance index 0 (low) - 10 (high)  \
# count                                 364.000000
# mean                                    6.064465
# std                                     2.503643
# min                                   -15.509039
# 25%                                     5.099409
# 50%                                     6.224549
# 75%                                     7.331088
# max                                    11.949638
#
#        Economic decline index 0 (low) - 10 (high)  \
# count                                  364.000000
# mean                                     6.303137
# std                                      1.834887
# min                                      0.753590
# 25%                                      5.259630
# 50%                                      6.550000
# 75%                                      7.523333
# max                                     10.000000
#
#        Uneven economic development index 0 (low) - 10 (high)  \
# count                                         364.000000
# mean                                            6.855149
# std                                             1.453094
# min                                             1.720000
# 25%                                             6.108254
# 50%                                             7.098830
# 75%                                             7.831229
# max                                             9.915305
#
#        State legitimacy index 0 (high) - 10 (low)  \
# count                                  364.000000
# mean                                     6.849028
# std                                      2.200479
# min                                      0.381466
# 25%                                      5.994261
# 50%                                      7.244347
# 75%                                      8.527453
# max                                     11.070327
#
#        Human rights and rule of law index 0 (high) - 10 (low)  \
# count                                         364.000000
# mean                                            6.459570
# std                                             2.170595
# min                                             0.903845
# 25%                                             4.973379
# 50%                                             6.650000
# 75%                                             8.254288
# max                                            11.394976
#
#        Demographic pressures 0 (low) - 10 (high)  \
# count                                 364.000000
# mean                                    6.820011
# std                                     1.899543
# min                                    -1.532770
# 25%                                     5.712503
# 50%                                     7.000000
# 75%                                     8.316573
# max                                     9.940000
#
#        Refugees and displaced persons index 0 (low) - 10 (high)  \
# count                                         364.000000
# mean                                            5.353883
# std                                             2.589000
# min                                           -15.661482
# 25%                                             4.275000
# 50%                                             5.594911
# 75%                                             6.712667
# max                                            12.121062
#
#        External interventions index 0 (low) - 10 (high)      target
# count                                        364.000000  364.000000
# mean                                           6.501870    0.258242
# std                                            2.210900    0.438270
# min                                           -5.171762    0.000000
# 25%                                            5.558579    0.000000
# 50%                                            6.839561    0.000000
# 75%                                            8.003855    1.000000
# max                                           11.256844    1.000000
#
# [8 rows x 63 columns]

# %% [markdown]
# # Scaler on whole dataset

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
full_dataset_scaled = pd.DataFrame(scaler.fit_transform(imputed_final_df), columns=imputed_final_df.columns)

# %% [markdown]
# # LET'S MODEL

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV


X = full_dataset_scaled.drop(columns=['target'])
y = full_dataset_scaled['target']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state=5)

# %%
y_train.value_counts()
# Out:
# 0.0    191
# 1.0     63
# Name: target, dtype: int64

# %%
bst = XGBClassifier(n_estimators=100,max_depth=30,learning_rate=1, 
                    objective='binary:logistic')

# %%
bst.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=30, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
preds = bst.predict(X_test)

accuracy_score(preds,y_test)
bst.predict_proba(X_test)
accuracy_score(preds,y_test)
# Out:
# 0.7090909090909091

# %%
import pandas as pd

features = bst.get_booster().feature_names
importances = bst.feature_importances_
feature_importances_df = pd.DataFrame(zip(features, importances), columns=['feature', 'importance']).set_index('feature')
feature_importances_df.sort_values('importance', ascending=False).head(10)
# Out:
#                                                     importance
# feature
# Political stability index (-2.5 weak; 2.5 strong)     0.156833
# State legitimacy index 0 (high) - 10 (low)            0.145027
# Human rights and rule of law index 0 (high) - 1...    0.060807
# Banking system z-scores                               0.059761
# Death rate per 1000 people                            0.051263
# External interventions index 0 (low) - 10 (high)      0.044969
# Economic globalization index (0-100)                  0.040372
# Foreign aid and official development assistance...    0.036613
# Voice and accountability index (-2.5 weak; 2.5 ...    0.029222
# Control of corruption (-2.5 weak; 2.5 strong)         0.028421

# %%
def get_imputed_df(country,year,lookback=5):
    df = get_hist_data(country,year,lookback).groupby('country_all').mean(numeric_only=True)
    df.drop(columns=[col for col in df if col not in columns_to_keep],inplace=True)
    df['target'] = 0.5
    imputed_df = pd.DataFrame(imputer.transform(df),columns=df.columns)
    imputed_df.drop(columns='target',inplace=True)
    
    
    return imputed_df




def get_prob(country,year,lookback=5):
    
    prob = bst.predict_proba(get_imputed_df(country,year,lookback))[0][1]
    return prob

def prob_series(country,start_year,end_year,lookback=5):
    my_list =[]
    for year in range(start_year,end_year+1):
        my_list.append(get_prob(country,year,lookback))
    return my_list

# NEXT STEPS:
#     - FINE TUNE MODEL PARAMS WITH GRID SEARCH / FEATURE SET TO IMPROVE PERFORMANCE 
#     - DELETE FEATURES SO LESS IMPUTATION/SOME ACTUAL TIME PROGRESS
#     - MORE STREAMLIT/START PUTTING PRESENTATION TOGETHER
#     - TRY GET GRAPH WORKING
#     - LOOK AT OTHER METRICS FOR MODEL - RECALL AND PRECISION
# AUTOML For hyperparams
# delete pre 1990 data
# add more non conflicts.. 1:3 or 1:4 - but be sure to look at recall and precision as well

    
prob_series('USA',1990,2020)
get_imputed_df('Iran',2019)
# Out:
#    Military spending percent of total government spending   \
# 0                                             15.084
#
#    Arms imports million constant U.S. dollars  \
# 0                                        89.4
#
#    Human Development Index (0 - 1)  \
# 0                           0.7944
#
#    Economic growth: the rate of change of real GDP  \
# 0                                            2.578
#
#    GDP per capita current U.S. dollars  \
# 0                             5395.586
#
#    GDP per capita Purchasing Power Parity  \
# 0                                15294.85
#
#    Capital investment as percent of GDP  \
# 0                                32.274
#
#    Inflation: percent change in the Consumer Price Index  Unemployment rate  \
# 0                                              12.46                 11.778
#
#    Youth unemployment ages 15-24  ...  \
# 0                         27.074  ...
#
#    Security threats index 0 (low) - 10 (high)  \
# 0                                        7.74
#
#    Factionalized elites index 0 (low) - 10 (high)  \
# 0                                            9.52
#
#    Group grievance index 0 (low) - 10 (high)  \
# 0                                       8.94
#
#    Economic decline index 0 (low) - 10 (high)  \
# 0                                        6.54
#
#    Uneven economic development index 0 (low) - 10 (high)  \
# 0                                                5.9
#
#    State legitimacy index 0 (high) - 10 (low)  \
# 0                                         9.0
#
#    Human rights and rule of law index 0 (high) - 10 (low)  \
# 0                                               9.36
#
#    Demographic pressures 0 (low) - 10 (high)  \
# 0                                       5.14
#
#    Refugees and displaced persons index 0 (low) - 10 (high)  \
# 0                                               6.54
#
#    External interventions index 0 (low) - 10 (high)
# 0                                               6.7
#
# [1 rows x 62 columns]

# %%
def plot_prob_series(country,start_year,end_year,lookback=5):
    
    sns.lineplot(x = list(range(start_year,end_year+1)),y=prob_series(country,start_year,end_year,lookback))
    
plot_prob_series('Switzerland',1990,2020)

# %%
def lambda_prob(row, i):
    
    prob_value = get_prob(row['Country from our model'],i)
    
    return prob_value

# %%
codes = pd.read_csv('../raw_data/country_code_example.csv')
codes.head()

code_dict = pd.Series(codes['Country from our model'].values,index=codes.Code).to_dict()
code_dict2 = pd.Series(codes.Code,index=['Country from our model']).to_dict()
codes2 = codes[['Country from our model', 'Code']].dropna()

codes2['prob'] = codes2.apply(lambda x: lambda_prob(x),axis=1)
codes2
# codes2['next_year_prob'] = get_prob(codes2['Country from our model'],2022)
# Out:
#       Country from our model Code      prob
# 0                Afghanistan  AFG  0.231645
# 1                    Albania  ALB  0.209206
# 2                    Algeria  DZA  0.656950
# 3                    Andorra  AND  0.780066
# 4                     Angola  AGO  0.133679
# ..                       ...  ...       ...
# 197                   Monaco  MCO  0.133018
# 198            New Caledonia  NCL  0.227900
# 199               San Marino  SMR  0.608731
# 200           Norfolk Island  NIU  0.231645
# 201  Holy See (Vatican City)  HTI  0.656950
#
# [202 rows x 3 columns]

# %% [markdown]
# # Downloading the data

# %%
csv_full['year_all'] = csv_full.apply(lambda x: get_year(x),axis=1)
